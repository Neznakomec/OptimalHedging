# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import gc
from IPython.display import clear_output
from collections import defaultdict
import os

from functools import lru_cache

def sum_2_tuples(a, b):
    return tuple(map(sum, zip(a, b)))

# %% [markdown]
# File paths:

# %%
TRADES_DIR = '../TRADES/USD_TOM_trades_Micex_02_10.feather'
LOB_DIR = '../Data_lob/'

SIGNATURE_FILE = './signature.db3'

TOXIC_BUY_MOMENTS_PATH = '../0_CommonFiles/toxic/toxic_buy_moments_1m_02_06.feather'
TOXIC_SELL_MOMENTS_PATH = '../0_CommonFiles/toxic/toxic_sell_moments_1m_02_06.feather'

TOXIC_SELL_SIGNATURE_PATH = '../0_CommonFiles/toxic/toxic_sign_sell.npy'
TOXIC_BUY_SIGNATURE_PATH = '../0_CommonFiles/toxic/toxic_sign.npy'

# %% [markdown]
# Experiment details:

# %%
# Signature hedger
volume = 10_000 # in contracts

look_back_time = np.timedelta64(30, 's')

hedge_params_df = pd.DataFrame({
    'zone_number': [1, 2, 3],
    'distance': [1, 5, 10],
    'proportion': [0.3, 0.2, 0.1]
})

# %% [markdown]
# # 1. Generate 1m trades of toxic client

# %%
trades = pd.read_feather(TRADES_DIR)
trades = trades[0:0]
trades
# Out:
# Empty DataFrame
# Columns: [Time, PRICE, SIZE, AGGRESSOR_SIDE, TRADE_VALUE]
# Index: []

# %%
toxic_buy_moments = pd.read_feather(TOXIC_BUY_MOMENTS_PATH)

# %%
toxic_buy_moments_2 = pd.DataFrame(index=toxic_buy_moments['Time']).between_time('10:00', '23:50')

# %%
toxic_buy_moments_2
# Out:
# Empty DataFrame
# Columns: []
# Index: [2021-02-01 10:01:36.771000, 2021-02-01 10:05:02.883000, 2021-02-01 10:05:11.061000, 2021-02-01 10:05:23.526000, 2021-02-01 10:07:27.929000, 2021-02-01 10:11:51.521000, 2021-02-01 10:12:14.647000, 2021-02-01 10:13:16.218000, 2021-02-01 10:13:16.224000, 2021-02-01 10:13:18.165000, 2021-02-01 10:14:31.507000, 2021-02-01 10:15:58.571000, 2021-02-01 10:17:42.974000, 2021-02-01 10:17:51.119000, 2021-02-01 10:19:06.504000, 2021-02-01 10:22:57.488000, 2021-02-01 10:24:58.090000, 2021-02-01 10:27:49.696000, 2021-02-01 10:30:01.974000, 2021-02-01 10:30:02.098000, 2021-02-01 10:31:15.367000, 2021-02-01 10:32:18.384000, 2021-02-01 10:37:27.007000, 2021-02-01 10:42:43.364000, 2021-02-01 10:52:34.417000, 2021-02-01 10:52:38.896000, 2021-02-01 10:55:37.357000, 2021-02-01 11:01:06.880000, 2021-02-01 11:04:29.349000, 2021-02-01 11:05:53.373000, 2021-02-01 11:06:04.940000, 2021-02-01 11:06:58.043000, 2021-02-01 11:15:56.976000, 2021-02-01 11:16:44.315000, 2021-02-01 11:18:34.530000, 2021-02-01 11:18:34.628000, 2021-02-01 11:18:58.292000, 2021-02-01 11:19:01.596000, 2021-02-01 11:19:05.220000, 2021-02-01 11:19:44.308000, 2021-02-01 11:24:23.049000, 2021-02-01 11:25:47.783000, 2021-02-01 11:27:47.729000, 2021-02-01 11:27:50.163000, 2021-02-01 11:27:56.932000, 2021-02-01 11:32:49.922000, 2021-02-01 11:37:51.598000, 2021-02-01 11:42:24.587000, 2021-02-01 11:43:13.941000, 2021-02-01 11:43:45.193000, 2021-02-01 11:44:14.344000, 2021-02-01 11:44:17.277000, 2021-02-01 11:44:17.336000, 2021-02-01 11:44:35.768000, 2021-02-01 11:44:49.418000, 2021-02-01 11:48:40.309000, 2021-02-01 11:48:41.844000, 2021-02-01 11:49:49.378000, 2021-02-01 11:49:54.515000, 2021-02-01 11:50:01.676000, 2021-02-01 11:51:12.884000, 2021-02-01 11:51:12.956000, 2021-02-01 11:51:51.525000, 2021-02-01 11:52:41.612000, 2021-02-01 11:52:46.658000, 2021-02-01 11:52:52.590000, 2021-02-01 11:58:14.161000, 2021-02-01 11:59:18.842000, 2021-02-01 12:01:05.342000, 2021-02-01 12:10:29.248000, 2021-02-01 12:18:28.914000, 2021-02-01 12:18:29.013000, 2021-02-01 12:19:43.057000, 2021-02-01 12:21:11.289000, 2021-02-01 12:25:25.957000, 2021-02-01 12:37:27.364000, 2021-02-01 12:38:04.263000, 2021-02-01 12:38:04.318000, 2021-02-01 12:44:59.995000, 2021-02-01 12:54:20.511000, 2021-02-01 13:23:00.494000, 2021-02-01 13:38:26.810000, 2021-02-01 13:39:43.996000, 2021-02-01 13:49:32.829000, 2021-02-01 13:49:42.871000, 2021-02-01 14:11:12.336000, 2021-02-01 14:23:28.334000, 2021-02-01 14:27:28.749000, 2021-02-01 14:27:35.146000, 2021-02-01 14:32:58.819000, 2021-02-01 14:35:06.538000, 2021-02-01 14:39:49.564000, 2021-02-01 14:42:51.323000, 2021-02-01 14:46:10.914000, 2021-02-01 14:46:12.879000, 2021-02-01 14:46:48.004000, 2021-02-01 14:58:28.530000, 2021-02-01 15:10:27.344000, 2021-02-01 15:11:05.538000, 2021-02-01 15:20:44.103000, ...]
#
# [15682 rows x 0 columns]

# %%
toxic_buy_moments_2_index = toxic_buy_moments_2.index

# %%
# https://stackoverflow.com/questions/43408621/add-a-row-at-top-in-pandas-dataframe
for mom in toxic_buy_moments_2_index:
    trades.loc[-1, ('Time', 'AGGRESSOR_SIDE', 'PRICE', 'SIZE', 'TRADE_VALUE')] = [mom, 'B', -1, 1000, -1000]
    trades.index = trades.index - 1

# %%
trades
# Out:
#                           Time  PRICE    SIZE AGGRESSOR_SIDE  TRADE_VALUE
# -15683 2021-02-01 10:01:36.771   -1.0  1000.0              B      -1000.0
# -15682 2021-02-01 10:05:02.883   -1.0  1000.0              B      -1000.0
# -15681 2021-02-01 10:05:11.061   -1.0  1000.0              B      -1000.0
# -15680 2021-02-01 10:05:23.526   -1.0  1000.0              B      -1000.0
# -15679 2021-02-01 10:07:27.929   -1.0  1000.0              B      -1000.0
# ...                        ...    ...     ...            ...          ...
# -6     2021-06-30 19:17:20.554   -1.0  1000.0              B      -1000.0
# -5     2021-06-30 19:30:16.189   -1.0  1000.0              B      -1000.0
# -4     2021-06-30 19:31:46.414   -1.0  1000.0              B      -1000.0
# -3     2021-06-30 19:41:04.630   -1.0  1000.0              B      -1000.0
# -2     2021-06-30 19:41:04.636   -1.0  1000.0              B      -1000.0
#
# [15682 rows x 5 columns]

# %%
toxic_sell_moments = pd.read_feather(TOXIC_SELL_MOMENTS_PATH)

# %%
toxic_sell_moments_2 = pd.DataFrame(index=toxic_sell_moments['Time']).between_time('10:00', '23:50')

# %%
toxic_sell_moments_2
# Out:
# Empty DataFrame
# Columns: []
# Index: [2021-02-01 10:00:09.015000, 2021-02-01 10:04:36.332000, 2021-02-01 10:04:57.946000, 2021-02-01 10:05:19.015000, 2021-02-01 10:08:27.788000, 2021-02-01 10:10:53.579000, 2021-02-01 10:10:53.673000, 2021-02-01 10:11:41.916000, 2021-02-01 10:13:20.089000, 2021-02-01 10:13:21.070000, 2021-02-01 10:22:46.632000, 2021-02-01 10:22:50.382000, 2021-02-01 10:30:14.513000, 2021-02-01 10:32:14.630000, 2021-02-01 10:33:07.039000, 2021-02-01 10:39:57.097000, 2021-02-01 10:40:53.923000, 2021-02-01 10:48:21.597000, 2021-02-01 10:50:49.157000, 2021-02-01 10:53:39.875000, 2021-02-01 10:55:54.725000, 2021-02-01 10:58:56.008000, 2021-02-01 11:08:44.875000, 2021-02-01 11:09:45.586000, 2021-02-01 11:15:02.616000, 2021-02-01 11:22:39.009000, 2021-02-01 11:22:57.550000, 2021-02-01 11:25:47.452000, 2021-02-01 11:30:56.099000, 2021-02-01 11:32:51.371000, 2021-02-01 11:44:24.263000, 2021-02-01 12:09:41.865000, 2021-02-01 12:13:21.090000, 2021-02-01 12:13:21.153000, 2021-02-01 12:15:37.438000, 2021-02-01 12:16:36.536000, 2021-02-01 12:20:58.503000, 2021-02-01 12:23:19.249000, 2021-02-01 12:23:54.538000, 2021-02-01 12:24:39.786000, 2021-02-01 12:26:18.819000, 2021-02-01 12:27:52.322000, 2021-02-01 12:29:41.274000, 2021-02-01 12:30:07.840000, 2021-02-01 12:32:04.281000, 2021-02-01 12:32:28.846000, 2021-02-01 12:32:33.614000, 2021-02-01 12:32:36.746000, 2021-02-01 12:40:40.357000, 2021-02-01 12:40:44.031000, 2021-02-01 12:42:22.532000, 2021-02-01 12:42:40.676000, 2021-02-01 12:52:00.804000, 2021-02-01 12:58:51.665000, 2021-02-01 13:00:18.641000, 2021-02-01 13:11:57.712000, 2021-02-01 13:18:14.107000, 2021-02-01 13:18:14.213000, 2021-02-01 13:35:10.132000, 2021-02-01 13:46:48.052000, 2021-02-01 13:47:34.993000, 2021-02-01 13:47:39.732000, 2021-02-01 13:47:39.790000, 2021-02-01 13:49:29.590000, 2021-02-01 13:53:42.770000, 2021-02-01 13:55:18.587000, 2021-02-01 13:59:03.909000, 2021-02-01 14:03:57.776000, 2021-02-01 14:04:37.143000, 2021-02-01 14:04:46.569000, 2021-02-01 14:10:42.146000, 2021-02-01 14:11:24.889000, 2021-02-01 14:14:10.419000, 2021-02-01 14:15:09.078000, 2021-02-01 14:15:13.437000, 2021-02-01 14:16:57.198000, 2021-02-01 14:17:44.700000, 2021-02-01 14:17:48.433000, 2021-02-01 14:21:37.878000, 2021-02-01 14:21:52.624000, 2021-02-01 14:22:17.173000, 2021-02-01 14:24:03.721000, 2021-02-01 14:24:03.776000, 2021-02-01 14:26:49.098000, 2021-02-01 14:26:53.892000, 2021-02-01 14:31:48.558000, 2021-02-01 14:53:57.886000, 2021-02-01 15:00:48.053000, 2021-02-01 15:10:38.128000, 2021-02-01 15:13:11.226000, 2021-02-01 15:14:36.510000, 2021-02-01 15:14:56.938000, 2021-02-01 15:17:30.322000, 2021-02-01 15:18:55.036000, 2021-02-01 15:29:03.145000, 2021-02-01 15:29:07.352000, 2021-02-01 15:30:33.019000, 2021-02-01 15:31:56.655000, 2021-02-01 15:32:37.890000, 2021-02-01 15:34:05.649000, ...]
#
# [15448 rows x 0 columns]

# %%
toxic_sell_moments_2_index = toxic_sell_moments_2.index

# %%
# https://stackoverflow.com/questions/43408621/add-a-row-at-top-in-pandas-dataframe
for mom in toxic_sell_moments_2_index:
    trades.loc[-1, ('Time', 'AGGRESSOR_SIDE', 'PRICE', 'SIZE', 'TRADE_VALUE')] = [mom, 'S', -1, 1000, -1000]
    trades.index = trades.index - 1

# %%
trades.sort_values(by = 'Time', inplace=True)
trades.reset_index(drop = True, inplace=True)

# %%
trades
# Out:
#                          Time  PRICE    SIZE AGGRESSOR_SIDE  TRADE_VALUE
# 0     2021-02-01 10:00:09.015   -1.0  1000.0              S      -1000.0
# 1     2021-02-01 10:01:36.771   -1.0  1000.0              B      -1000.0
# 2     2021-02-01 10:04:36.332   -1.0  1000.0              S      -1000.0
# 3     2021-02-01 10:04:57.946   -1.0  1000.0              S      -1000.0
# 4     2021-02-01 10:05:02.883   -1.0  1000.0              B      -1000.0
# ...                       ...    ...     ...            ...          ...
# 31125 2021-06-30 19:30:16.189   -1.0  1000.0              B      -1000.0
# 31126 2021-06-30 19:31:46.414   -1.0  1000.0              B      -1000.0
# 31127 2021-06-30 19:40:36.010   -1.0  1000.0              S      -1000.0
# 31128 2021-06-30 19:41:04.630   -1.0  1000.0              B      -1000.0
# 31129 2021-06-30 19:41:04.636   -1.0  1000.0              B      -1000.0
#
# [31130 rows x 5 columns]

# %% [markdown]
# # 2. Prepare signature (t0 + 1sec, t0 + 2 sec, ..., t0 + 30 sec)

# %%
arr_b = np.load(TOXIC_BUY_SIGNATURE_PATH)

# %%
arr_b
# Out:
# array([0.        , 0.00060652, 0.00076583, 0.00084845, 0.00092663,
#        0.00097044, 0.00101048, 0.00105958, 0.00112067, 0.00118184,
#        0.00122941, 0.00128676, 0.00131879, 0.00137308, 0.00138769,
#        0.00141246, 0.00144499, 0.00147672, 0.00151539, 0.00154786,
#        0.00155572, 0.00156564, 0.00157389, 0.00160786, 0.00162569,
#        0.00163014, 0.00164679, 0.00167861, 0.00171992, 0.0017324 ,
#        0.00174107, 0.00175855, 0.00178216, 0.00181039, 0.00186252,
#        0.00188851, 0.00191741, 0.00190683, 0.00193289, 0.00198366,
#        0.00200462, 0.00202701, 0.00205765, 0.00209319, 0.00213083,
#        0.00215138, 0.00216443, 0.00218651, 0.00221448, 0.00221694,
#        0.00222681, 0.00225959, 0.00225123, 0.00227095, 0.00229199,
#        0.00229888, 0.00232601, 0.00232881, 0.00234191, 0.00235477,
#        0.00240601, 0.0024529 , 0.00246497, 0.00248385, 0.00249143,
#        0.00251261, 0.0025324 , 0.00254368, 0.00254669, 0.00253681,
#        0.00257654, 0.00262445, 0.00263123, 0.00263597, 0.00262484,
#        0.00262157, 0.00267463, 0.00269191, 0.00270485, 0.00271538,
#        0.0027564 , 0.00277063, 0.00278337, 0.00279051, 0.00278913,
#        0.00275969, 0.00278335, 0.00280792, 0.00279782, 0.00282163,
#        0.00285221, 0.00288269, 0.0028872 , 0.00290416, 0.00290668,
#        0.00290595, 0.00290402, 0.00292011, 0.00292329, 0.00292325,
#        0.00295124, 0.00296068, 0.00295473, 0.00296862, 0.0029886 ,
#        0.00300575, 0.00301252, 0.00300845, 0.00303545, 0.0030366 ,
#        0.00302431, 0.00305281, 0.0030752 , 0.00309944, 0.00311374,
#        0.00312018, 0.00313344, 0.00311994, 0.00312391, 0.00311594,
#        0.00310406, 0.00313178, 0.00314185, 0.00317261, 0.00317787,
#        0.00316234, 0.00316936, 0.00317492, 0.00318218, 0.00318768,
#        0.00320044, 0.00320121, 0.00320876, 0.00319262, 0.00319322,
#        0.00319025, 0.00321109, 0.00321857, 0.00323025, 0.00325923,
#        0.00328492, 0.0033015 , 0.00331721, 0.00329718, 0.00328976,
#        0.00327805, 0.00330573, 0.00331839, 0.00333165, 0.00335048,
#        0.00336969, 0.00340528, 0.00340524, 0.00342867, 0.00344737,
#        0.00344281, 0.00344157, 0.00344876, 0.00346291, 0.00348653,
#        0.00350408, 0.00350149, 0.00351475, 0.00351068, 0.00350553,
#        0.0035117 , 0.00351934, 0.00352442, 0.00352799, 0.00354057,
#        0.00354444, 0.00354547, 0.00355642, 0.00352753, 0.00353511,
#        0.00352973, 0.00353833, 0.00355703, 0.00355063, 0.00353709,
#        0.00355494, 0.00354687, 0.00356804, 0.00357278, 0.00357752,
#        0.00356643, 0.0035657 , 0.00357529, 0.00355138, 0.00356097,
#        0.00360453, 0.00361154, 0.00363573, 0.00363905, 0.00367745,
#        0.00368174, 0.00368657, 0.0036626 , 0.00366147, 0.00366931,
#        0.00366172, 0.00369046, 0.00369365, 0.003695  , 0.00370765,
#        0.00369128, 0.00370994, 0.0037261 , 0.00373554, 0.00377686,
#        0.00378119, 0.00376889, 0.00377059, 0.00378205, 0.00377616,
#        0.00378015, 0.00379613, 0.00380635, 0.00379351, 0.00380939,
#        0.00379114, 0.00378388, 0.00379477, 0.0038068 , 0.0038275 ,
#        0.00385422, 0.00385105, 0.00388109, 0.00385074, 0.00385991,
#        0.00391182, 0.00396057, 0.00396157, 0.00394842, 0.00397341,
#        0.00398719, 0.00398857, 0.00398624, 0.00399518, 0.00396978,
#        0.00397997, 0.0039736 , 0.00398572, 0.00398439, 0.0039597 ,
#        0.00397055, 0.00397188, 0.00397163, 0.00397672, 0.00396983,
#        0.00397663, 0.00395851, 0.0039669 , 0.00397825, 0.00400016,
#        0.00399832, 0.00400114, 0.00399697, 0.00398423, 0.00400562,
#        0.00400152, 0.00403308, 0.00404887, 0.00404923, 0.00407533,
#        0.00406737, 0.00407443, 0.00405977, 0.00406667, 0.00405894])

# %%
arr_b = arr_b[::3]

# %%
arr_b = arr_b[1:31]

# %%
arr_b
# Out:
# array([0.00118184, 0.00151539, 0.00167861, 0.00191741, 0.00215138,
#        0.00229199, 0.00248385, 0.00263123, 0.00277063, 0.00285221,
#        0.00292325, 0.00303545, 0.00311994, 0.00316936, 0.00319025,
#        0.00328976, 0.00342867, 0.00351475, 0.00354547, 0.00355494,
#        0.00356097, 0.00366147, 0.0037261 , 0.00379613, 0.00385422,
#        0.00397341, 0.00398439, 0.0039669 , 0.00403308])

# %%
arr_s = np.load(TOXIC_SELL_SIGNATURE_PATH)
arr_s = arr_s[::3]
arr_s = arr_s[1:31]
arr_s
# Out:
# array([-0.00103321, -0.00126052, -0.00144338, -0.00159671, -0.00169068,
#        -0.00183257, -0.0020072 , -0.00211205, -0.00225794, -0.00236021,
#        -0.00244329, -0.0025295 , -0.00264395, -0.00282395, -0.0029191 ,
#        -0.00298147, -0.00300586, -0.00300877, -0.00307504, -0.00312307,
#        -0.00319003, -0.00323405, -0.00331353, -0.00332765, -0.00339945,
#        -0.00338945, -0.00344584, -0.00354666, -0.00357928, -0.00356825])

# %%
print({
    'B': {(1000, 1001): arr_b},
    'S': {(1000, 1001): arr_s}
    })
# Out:
# {'B': {(1000, 1001): array([0.00118184, 0.00151539, 0.00167861, 0.00191741, 0.00215138,
#        0.00229199, 0.00248385, 0.00263123, 0.00277063, 0.00285221,
#        0.00292325, 0.00303545, 0.00311994, 0.00316936, 0.00319025,
#        0.00328976, 0.00342867, 0.00351475, 0.00354547, 0.00355494,
#        0.00356097, 0.00366147, 0.0037261 , 0.00379613, 0.00385422,
#        0.00397341, 0.00398439, 0.0039669 , 0.00403308])}, 'S': {(1000, 1001): array([-0.00103321, -0.00126052, -0.00144338, -0.00159671, -0.00169068,
#        -0.00183257, -0.0020072 , -0.00211205, -0.00225794, -0.00236021,
#        -0.00244329, -0.0025295 , -0.00264395, -0.00282395, -0.0029191 ,
#        -0.00298147, -0.00300586, -0.00300877, -0.00307504, -0.00312307,
#        -0.00319003, -0.00323405, -0.00331353, -0.00332765, -0.00339945,
#        -0.00338945, -0.00344584, -0.00354666, -0.00357928, -0.00356825])}}

# %% [markdown]
# # 3. Build signature functions

# %%
signature_table = {
    'B': {
        # toxic signature
        (1000, 1001): [0.00084845, 0.00101048, 0.00118184, 0.00131879, 0.00141246,
       0.00151539, 0.00156564, 0.00162569, 0.00167861, 0.00174107,
       0.00181039, 0.00191741, 0.00198366, 0.00205765, 0.00215138,
       0.00221448, 0.00225959, 0.00229199, 0.00232881, 0.00240601,
       0.00248385, 0.0025324 , 0.00253681, 0.00263123, 0.00262157,
       0.00270485, 0.00277063, 0.00278913, 0.00280792, 0.00285221],
    },
    'S': {
        # toxic signature
        (1000, 1001): [-0.00103321, -0.00126052, -0.00144338, -0.00159671, -0.00169068,
       -0.00183257, -0.0020072 , -0.00211205, -0.00225794, -0.00236021,
       -0.00244329, -0.0025295 , -0.00264395, -0.00282395, -0.0029191 ,
       -0.00298147, -0.00300586, -0.00300877, -0.00307504, -0.00312307,
       -0.00319003, -0.00323405, -0.00331353, -0.00332765, -0.00339945,
       -0.00338945, -0.00344584, -0.00354666, -0.00357928, -0.00356825]
    }
}


def build_delta_signature(signature_table):
    output = {}
    for side in signature_table:
        if side not in output:
            output[side] = {}
        
        for size, array in signature_table[side].items():
            # for 1..N we store only delta - change from previous moment
            delta_signature = np.array(array[1:]) - np.array(array[:-1])
            
            '''
            for initial time T0 we store array[0],
            price jump before deal and after deal
            '''
            delta_signature = np.insert(delta_signature, obj=0, values=array[0]) 
            
            output[side][size] = delta_signature
            
    return output

delta_signature_table = build_delta_signature(signature_table)

# %%
def build_multitrades_signature(trades_before):
    signature = defaultdict(float)

    for trade in trades_before.itertuples():
        side = trade.AGGRESSOR_SIDE
        for size_range in signature_table[side]:
            if size_range[0] <= trade.SIZE <= size_range[1]:
                break

        delta_signature = delta_signature_table[side][size_range]

        times = {trade.Time + np.timedelta64(sec, 's') : delta_signature[sec] 
               for sec in range(30)}

        for k, v in times.items():
            signature[k] += v
        
    signature = (sorted(signature.items()))

    reconstructed_signature = []
    total = 0

    for (k,v) in signature:
        total += v
        reconstructed_signature.append((k, total))

    return reconstructed_signature

# %% [markdown]
# # 3. Hedge functions

# %%
def get_trades_before(moment):
    global look_back_time, trades
    moment_before = moment - look_back_time
    index1 = trades.Time.searchsorted(moment_before, side='left')
    index2 = trades.Time.searchsorted(moment, side='right')
    trades_before = trades.iloc[index1 : index2]
    return trades_before

# %%
'''
@returns 
zone1time - time, when zone1 ends and zone2 starts
zone2time - time, when zone2 ends and zone3 starts
'''
def get_zone_times(moment, side, skip_empty_trades = False):
    #1 get trades before our trade
    trades_before = get_trades_before(moment)
    
    if len(trades_before) == 0:
        if skip_empty_trades == False:
            #Columns: [Time, AGGRESSOR_SIDE, PRICE, SIZE, TRADE_VALUE]
            trades_before.loc[-1] = [moment, side, -1.0, 1000, -1000.0]  # adding a row
            trades_before.index = trades_before.index + 1  # shifting index
            trades_before = trades_before.sort_index()  # sorting by index
        else:
            return None, None

    #2 mix them into signature
    reference_signature = build_multitrades_signature(trades_before)
    #3 find three zones
    mmax = max(reference_signature, key = lambda item: item[1])
    mmin = min(reference_signature, key = lambda item: item[1])
    
    if side == 'B':
        zone1price = mmin[1] + (mmax[1] - mmin[1]) * 0.33
        zone2price = mmin[1] + (mmax[1] - mmin[1]) * 0.66
    
        for (k, v) in reference_signature:
            if v >= zone1price:
                #print(k)
                zone1time = k
                break
            
        for (k, v) in reference_signature:
            if v >= zone2price:
                #print(k)
                zone2time = k
                break
    else:
        zone1price = mmax[1] - (mmax[1] - mmin[1]) * 0.33
        zone2price = mmax[1] - (mmax[1] - mmin[1]) * 0.66
        
        for (k, v) in reference_signature:
            if v <= zone1price:
                #print(k)
                zone1time = k
                break
            
        for (k, v) in reference_signature:
            if v <= zone2price:
                #print(k)
                zone2time = k
                break
                
    #4 return result
    return zone1time, zone2time

# %%
def make_hedge(lob, datetime, size, side):
    #lob = lob[lob['Time'] >= datetime]
    time_index = lob['Time'].searchsorted(datetime, side='right')
        
    if time_index >= len(lob):
        return (0, 0.0)
    row = lob.iloc[time_index] # first timestamp >= datetime
    
    quote_side = 'BID' if (side == 'S') else 'ASK'
    
    maxsize = sum([row[quote_side + '_SIZE' + str(level)] for level in range(1, 11)])
        
    if maxsize < size:
        raise ValueError(f'size {size} is greater than available {maxsize}')
    
    size_hedged, sum_hedged = 0, 0.0
    level = 1
    while size_hedged < size and level < 11:
        portion = min(size - size_hedged, row[quote_side + '_SIZE' + str(level)])
        price = row[quote_side + '_PRICE' + str(level)]
        size_hedged += portion
        sum_hedged += portion * price
        print(f'added {portion} by {price}')
        level += 1
        
    print('HEDGE ended')
    return (size_hedged, sum_hedged)

# %%
class LOBCache:
    def __init__(self):
        pass
    
    def get_lob(self, datetime):
        #print(datetime)
        filename = datetime.strftime('LOB_%m%d.feather')
        return self.__get_lob_by_filename(filename)
        pass
    
    @lru_cache(maxsize=1)
    def __get_lob_by_filename(self, filename):
        print(filename)
        lob = pd.read_feather(LOB_DIR + filename).dropna()
        lob['BID_SIZE10'] = 99_999_999
        lob['ASK_SIZE10'] = 99_999_999
        return lob

# %%
cache = LOBCache()

# %%
def calc_hedge_signature(cache, moment, hedge_params_df):
    curr_moment = moment
    print(hedge_params_df)

    lob = cache.get_lob(curr_moment)
    remain = volume
    total = None
    
    zone1time, zone2time = get_zone_times(curr_moment, side, skip_empty_trades = True)
    print('zone1time, zone2time','\n',zone1time,'\n', zone2time)
    if zone1time is None:
        remain = 0
        total = (-2, -2.0)
    while remain > 0:
        print(curr_moment)
        
        # select our zone
        if moment <= curr_moment <= zone1time:
            print('we are in 1st zone')
            zone = 1
        elif zone1time < curr_moment <= zone2time:
            print('we are in 2nd zone')
            zone = 2
        else:
            print('we are in 3rd zone')
            zone = 3
        
        row = hedge_params_df[hedge_params_df['zone_number'] == zone]
        size_contracts = int(volume * row['proportion'])
        size_contracts = min(size_contracts, remain)

        hedge_result = make_hedge(lob, curr_moment, size = size_contracts, side = side)

        interval =  row['distance'].iloc[0]
        curr_moment = curr_moment + np.timedelta64(interval, 's')
        if hedge_result is None:
            break
        
        if hedge_result[0] == 0:
            return (-1, -1.0)
        
        if total is None:
            total = hedge_result
        else:
            total = sum_2_tuples(total, hedge_result)
            
        print(hedge_result)
        remain -= hedge_result[0]
        if remain == 0:
            break
            
    del lob
            
    if remain > 0:
        return None
    else:
        return total

# %% [markdown]
# # 5. Calculate and save results in DB

# %%
#CREATE TABLE RESULT(MOMENT TEXT, SIDE TEXT, QUANTITY INTEGER, SUM REAL, PRIMARY KEY(MOMENT,SIDE));
sign_sql = sqlite3.connect(SIGNATURE_FILE)
sign_sql.execute('CREATE TABLE IF NOT EXISTS RESULT(MOMENT TEXT, SIDE TEXT, QUANTITY INTEGER, SUM REAL, PRIMARY KEY(MOMENT,SIDE));')
cur=sign_sql.cursor()

# %%
records = []

for side in ('B', 'S'):
    if side == 'B':
        moments = toxic_buy_moments_2_index
    elif side == 'S':
        moments = toxic_sell_moments_2_index

    for moment in moments:
        record = (str(moment),side)
        query='select exists(select 1 from result where moment=? and side=? collate nocase) limit 1'
        # 'query' RETURNS 1 IF USERNAME EXISTS OR 0 IF NOT, AS INTEGER(MAYBE). 'collate nocase'= CASE INSENSITIVE, IT'S OPTIONAL
        check=cur.execute(query,record) 
        if check.fetchone()[0]==1:
            print(f'Moment already available ' + str(record))
            continue

        print('calculating for moment', moment)
        result = calc_hedge_signature(cache, moment, hedge_params_df)

        query='INSERT OR REPLACE INTO result(moment, side, quantity, sum) VALUES(?, ?, ?, ?);'
        if result:
            record = (str(moment), side, int(result[0]), result[1])
        else:
            record = (str(moment), side, -1, -1)

        print(record)
        cur.execute(query, record)
        records.append(record)

        gc.collect()

        if len(records) % 100 == 0:
            clear_output(wait=False)
# Out:
# calculating for moment 2021-06-30 15:00:59.309000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:00:51.524000
#  2021-06-30 15:01:04.309000
# 2021-06-30 15:00:59.309000
# we are in 2nd zone
# added 553 by 72.93
# added 612 by 72.9275
# added 520 by 72.925
# added 315 by 72.9225
# HEDGE ended
# (2000, 145853.5075)
# 2021-06-30 15:01:04.309000
# we are in 2nd zone
# added 94 by 72.9325
# added 903 by 72.93
# added 512 by 72.9275
# added 491 by 72.925
# HEDGE ended
# (2000, 145856.5)
# 2021-06-30 15:01:09.309000
# we are in 3rd zone
# added 738 by 72.93
# added 262 by 72.9275
# HEDGE ended
# (1000, 72929.345)
# 2021-06-30 15:01:19.309000
# we are in 3rd zone
# added 44 by 72.9325
# added 741 by 72.93
# added 215 by 72.9275
# HEDGE ended
# (1000, 72929.57250000001)
# 2021-06-30 15:01:29.309000
# we are in 3rd zone
# added 500 by 72.9325
# added 212 by 72.93
# added 288 by 72.9275
# HEDGE ended
# (1000, 72930.53)
# 2021-06-30 15:01:39.309000
# we are in 3rd zone
# added 445 by 72.9325
# added 262 by 72.93
# added 293 by 72.9275
# HEDGE ended
# (1000, 72930.38)
# 2021-06-30 15:01:49.309000
# we are in 3rd zone
# added 300 by 72.935
# added 695 by 72.9325
# added 5 by 72.93
# HEDGE ended
# (1000, 72933.23749999999)
# 2021-06-30 15:01:59.309000
# we are in 3rd zone
# added 197 by 72.9375
# added 600 by 72.935
# added 203 by 72.9325
# HEDGE ended
# (1000, 72934.985)
# ('2021-06-30 15:00:59.309000', 'S', 10000, 729298.0575)
# calculating for moment 2021-06-30 15:15:36.235000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:15:42.235000
#  2021-06-30 15:15:49.235000
# 2021-06-30 15:15:36.235000
# we are in 1st zone
# added 100 by 72.9925
# added 312 by 72.99
# added 300 by 72.9875
# added 450 by 72.985
# added 437 by 72.9825
# added 551 by 72.98
# added 850 by 72.9775
# HEDGE ended
# (3000, 218947.83750000002)
# 2021-06-30 15:15:37.235000
# we are in 1st zone
# added 50 by 72.995
# added 200 by 72.9925
# added 212 by 72.99
# added 400 by 72.9875
# added 450 by 72.985
# added 437 by 72.9825
# added 451 by 72.98
# added 800 by 72.9775
# HEDGE ended
# (3000, 218949.71250000002)
# 2021-06-30 15:15:38.235000
# we are in 1st zone
# added 12 by 72.99
# added 300 by 72.9875
# added 300 by 72.985
# added 501 by 72.9825
# added 371 by 72.98
# added 350 by 72.9775
# added 420 by 72.975
# added 200 by 72.9725
# added 546 by 72.97
# HEDGE ended
# (3000, 218935.1875)
# 2021-06-30 15:15:39.235000
# we are in 1st zone
# added 160 by 72.9875
# added 300 by 72.985
# added 251 by 72.9825
# added 289 by 72.98
# HEDGE ended
# (1000, 72983.3275)
# ('2021-06-30 15:15:36.235000', 'S', 10000, 729816.0650000001)
# calculating for moment 2021-06-30 15:17:00.774000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:17:06.774000
#  2021-06-30 15:17:13.774000
# 2021-06-30 15:17:00.774000
# we are in 1st zone
# added 100 by 72.99
# added 400 by 72.9875
# added 260 by 72.985
# added 521 by 72.9825
# added 1719 by 72.98
# HEDGE ended
# (3000, 218946.6025)
# 2021-06-30 15:17:01.774000
# we are in 1st zone
# added 100 by 72.99
# added 400 by 72.9875
# added 410 by 72.985
# added 421 by 72.9825
# added 1669 by 72.98
# HEDGE ended
# (3000, 218947.10250000004)
# 2021-06-30 15:17:02.774000
# we are in 1st zone
# added 100 by 72.99
# added 300 by 72.9875
# added 360 by 72.985
# added 471 by 72.9825
# added 1769 by 72.98
# HEDGE ended
# (3000, 218946.2275)
# 2021-06-30 15:17:03.774000
# we are in 1st zone
# added 100 by 72.99
# added 300 by 72.9875
# added 360 by 72.985
# added 240 by 72.9825
# HEDGE ended
# (1000, 72985.65)
# ('2021-06-30 15:17:00.774000', 'S', 10000, 729825.5825000001)
# calculating for moment 2021-06-30 15:19:21.173000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:19:27.173000
#  2021-06-30 15:19:34.173000
# 2021-06-30 15:19:21.173000
# we are in 1st zone
# added 250 by 72.9475
# added 400 by 72.945
# added 402 by 72.9425
# added 428 by 72.94
# added 310 by 72.9375
# added 810 by 72.935
# added 400 by 72.9325
# HEDGE ended
# (3000, 218817.055)
# 2021-06-30 15:19:22.173000
# we are in 1st zone
# added 150 by 72.9475
# added 501 by 72.945
# added 402 by 72.9425
# added 428 by 72.94
# added 310 by 72.9375
# added 710 by 72.935
# added 439 by 72.9325
# added 60 by 72.93
# HEDGE ended
# (3000, 218816.41749999998)
# 2021-06-30 15:19:23.173000
# we are in 1st zone
# added 100 by 72.9475
# added 351 by 72.945
# added 452 by 72.9425
# added 528 by 72.94
# added 360 by 72.9375
# added 710 by 72.935
# added 499 by 72.9325
# HEDGE ended
# (3000, 218815.4425)
# 2021-06-30 15:19:24.173000
# we are in 1st zone
# added 101 by 72.945
# added 552 by 72.9425
# added 347 by 72.94
# HEDGE ended
# (1000, 72941.885)
# ('2021-06-30 15:19:21.173000', 'S', 10000, 729390.8)
# calculating for moment 2021-06-30 15:19:36.987000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:19:36.987000
#  2021-06-30 15:19:42.987000
# 2021-06-30 15:19:36.987000
# we are in 1st zone
# added 250 by 72.945
# added 486 by 72.9425
# added 478 by 72.94
# added 510 by 72.9375
# added 660 by 72.935
# added 439 by 72.9325
# added 177 by 72.93
# HEDGE ended
# (3000, 218812.8275)
# 2021-06-30 15:19:37.987000
# we are in 2nd zone
# added 200 by 72.945
# added 486 by 72.9425
# added 478 by 72.94
# added 510 by 72.9375
# added 326 by 72.935
# HEDGE ended
# (2000, 145879.31)
# 2021-06-30 15:19:42.987000
# we are in 2nd zone
# added 50 by 72.9425
# added 528 by 72.94
# added 660 by 72.9375
# added 560 by 72.935
# added 202 by 72.9325
# HEDGE ended
# (2000, 145874.16)
# 2021-06-30 15:19:47.987000
# we are in 3rd zone
# added 428 by 72.94
# added 572 by 72.9375
# HEDGE ended
# (1000, 72938.57)
# 2021-06-30 15:19:57.987000
# we are in 3rd zone
# added 50 by 72.9525
# added 550 by 72.95
# added 400 by 72.9475
# HEDGE ended
# (1000, 72949.125)
# 2021-06-30 15:20:07.987000
# we are in 3rd zone
# added 98 by 72.945
# added 400 by 72.9425
# added 502 by 72.94
# HEDGE ended
# (1000, 72941.48999999999)
# ('2021-06-30 15:19:36.987000', 'S', 10000, 729395.4824999999)
# calculating for moment 2021-06-30 15:27:20.951000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:27:26.951000
#  2021-06-30 15:27:33.951000
# 2021-06-30 15:27:20.951000
# we are in 1st zone
# added 101 by 72.98
# added 404 by 72.9775
# added 250 by 72.975
# added 500 by 72.9725
# added 553 by 72.97
# added 450 by 72.9675
# added 742 by 72.965
# HEDGE ended
# (3000, 218911.70500000002)
# 2021-06-30 15:27:21.951000
# we are in 1st zone
# added 204 by 72.9775
# added 350 by 72.975
# added 350 by 72.9725
# added 753 by 72.97
# added 300 by 72.9675
# added 1043 by 72.965
# HEDGE ended
# (3000, 218908.19)
# 2021-06-30 15:27:22.951000
# we are in 1st zone
# added 204 by 72.9775
# added 350 by 72.975
# added 350 by 72.9725
# added 753 by 72.97
# added 400 by 72.9675
# added 943 by 72.965
# HEDGE ended
# (3000, 218908.44)
# 2021-06-30 15:27:23.951000
# we are in 1st zone
# added 354 by 72.9775
# added 200 by 72.975
# added 446 by 72.9725
# HEDGE ended
# (1000, 72974.77)
# ('2021-06-30 15:27:20.951000', 'S', 10000, 729703.105)
# calculating for moment 2021-06-30 15:28:59.852000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:29:05.852000
#  2021-06-30 15:29:12.852000
# 2021-06-30 15:28:59.852000
# we are in 1st zone
# added 218 by 73.0275
# added 150 by 73.025
# added 1189 by 73.0225
# added 850 by 73.02
# added 400 by 73.0175
# added 193 by 73.015
# HEDGE ended
# (3000, 219063.3925)
# 2021-06-30 15:29:00.852000
# we are in 1st zone
# added 218 by 73.0275
# added 150 by 73.025
# added 1189 by 73.0225
# added 800 by 73.02
# added 400 by 73.0175
# added 243 by 73.015
# HEDGE ended
# (3000, 219063.1425)
# 2021-06-30 15:29:01.852000
# we are in 1st zone
# added 100 by 73.025
# added 1139 by 73.0225
# added 300 by 73.02
# added 800 by 73.0175
# added 359 by 73.015
# added 302 by 73.0125
# HEDGE ended
# (3000, 219057.2875)
# 2021-06-30 15:29:02.852000
# we are in 1st zone
# added 100 by 73.025
# added 900 by 73.0225
# HEDGE ended
# (1000, 73022.75)
# ('2021-06-30 15:28:59.852000', 'S', 10000, 730206.5725)
# calculating for moment 2021-06-30 15:32:16.059000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:32:22.059000
#  2021-06-30 15:32:29.059000
# 2021-06-30 15:32:16.059000
# we are in 1st zone
# added 160 by 72.98
# added 400 by 72.9775
# added 509 by 72.975
# added 400 by 72.9725
# added 723 by 72.97
# added 503 by 72.9675
# added 305 by 72.965
# HEDGE ended
# (3000, 218915.36250000002)
# 2021-06-30 15:32:17.059000
# we are in 1st zone
# added 160 by 72.98
# added 350 by 72.9775
# added 609 by 72.975
# added 400 by 72.9725
# added 673 by 72.97
# added 503 by 72.9675
# added 305 by 72.965
# HEDGE ended
# (3000, 218915.48750000002)
# 2021-06-30 15:32:18.059000
# we are in 1st zone
# added 160 by 72.98
# added 450 by 72.9775
# added 459 by 72.975
# added 400 by 72.9725
# added 873 by 72.97
# added 403 by 72.9675
# added 255 by 72.965
# HEDGE ended
# (3000, 218915.98750000002)
# 2021-06-30 15:32:19.059000
# we are in 1st zone
# added 260 by 72.98
# added 515 by 72.9775
# added 225 by 72.975
# HEDGE ended
# (1000, 72977.58750000001)
# ('2021-06-30 15:32:16.059000', 'S', 10000, 729724.425)
# calculating for moment 2021-06-30 15:32:23.507000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:32:24.059000
#  2021-06-30 15:32:30.507000
# 2021-06-30 15:32:23.507000
# we are in 1st zone
# added 208 by 72.98
# added 565 by 72.9775
# added 359 by 72.975
# added 605 by 72.9725
# added 1168 by 72.97
# added 95 by 72.9675
# HEDGE ended
# (3000, 218919.38749999998)
# 2021-06-30 15:32:24.507000
# we are in 2nd zone
# added 208 by 72.98
# added 565 by 72.9775
# added 359 by 72.975
# added 605 by 72.9725
# added 263 by 72.97
# HEDGE ended
# (2000, 145949.625)
# 2021-06-30 15:32:29.507000
# we are in 2nd zone
# added 708 by 72.985
# added 500 by 72.9825
# added 358 by 72.98
# added 434 by 72.9775
# HEDGE ended
# (2000, 145963.70500000002)
# 2021-06-30 15:32:34.507000
# we are in 3rd zone
# added 162 by 72.985
# added 350 by 72.9825
# added 258 by 72.98
# added 230 by 72.9775
# HEDGE ended
# (1000, 72981.11)
# 2021-06-30 15:32:44.507000
# we are in 3rd zone
# added 200 by 72.9825
# added 158 by 72.98
# added 625 by 72.9775
# added 17 by 72.975
# HEDGE ended
# (1000, 72978.85250000001)
# 2021-06-30 15:32:54.507000
# we are in 3rd zone
# added 215 by 72.9775
# added 309 by 72.975
# added 476 by 72.9725
# HEDGE ended
# (1000, 72974.3475)
# ('2021-06-30 15:32:23.507000', 'S', 10000, 729767.0275000001)
# calculating for moment 2021-06-30 15:32:40.819000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:32:29.507000
#  2021-06-30 15:32:43.059000
# 2021-06-30 15:32:40.819000
# we are in 2nd zone
# added 200 by 72.9825
# added 358 by 72.98
# added 575 by 72.9775
# added 559 by 72.975
# added 308 by 72.9725
# HEDGE ended
# (2000, 145953.9575)
# 2021-06-30 15:32:45.819000
# we are in 3rd zone
# added 200 by 72.9825
# added 158 by 72.98
# added 515 by 72.9775
# added 127 by 72.975
# HEDGE ended
# (1000, 72978.5775)
# 2021-06-30 15:32:55.819000
# we are in 3rd zone
# added 765 by 72.9775
# added 235 by 72.975
# HEDGE ended
# (1000, 72976.9125)
# 2021-06-30 15:33:05.819000
# we are in 3rd zone
# added 300 by 72.9725
# added 310 by 72.97
# added 390 by 72.9675
# HEDGE ended
# (1000, 72969.775)
# 2021-06-30 15:33:15.819000
# we are in 3rd zone
# added 3 by 72.9675
# added 100 by 72.965
# added 550 by 72.9625
# added 347 by 72.96
# HEDGE ended
# (1000, 72961.89749999999)
# 2021-06-30 15:33:25.819000
# we are in 3rd zone
# added 187 by 72.9725
# added 551 by 72.97
# added 262 by 72.9675
# HEDGE ended
# (1000, 72969.8125)
# 2021-06-30 15:33:35.819000
# we are in 3rd zone
# added 200 by 72.975
# added 450 by 72.9725
# added 350 by 72.97
# HEDGE ended
# (1000, 72972.125)
# 2021-06-30 15:33:45.819000
# we are in 3rd zone
# added 200 by 72.9825
# added 800 by 72.98
# HEDGE ended
# (1000, 72980.5)
# 2021-06-30 15:33:55.819000
# we are in 3rd zone
# added 300 by 72.97
# added 550 by 72.9675
# added 150 by 72.965
# HEDGE ended
# (1000, 72967.875)
# ('2021-06-30 15:32:40.819000', 'S', 10000, 729731.4325)
# calculating for moment 2021-06-30 15:33:39.685000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:33:45.685000
#  2021-06-30 15:33:52.685000
# 2021-06-30 15:33:39.685000
# we are in 1st zone
# added 50 by 72.985
# added 453 by 72.98
# added 450 by 72.9775
# added 450 by 72.975
# added 350 by 72.9725
# added 650 by 72.97
# added 510 by 72.9675
# added 87 by 72.965
# HEDGE ended
# (3000, 218920.06999999998)
# 2021-06-30 15:33:40.685000
# we are in 1st zone
# added 853 by 72.98
# added 550 by 72.9775
# added 400 by 72.975
# added 570 by 72.9725
# added 627 by 72.97
# HEDGE ended
# (3000, 218926.08000000002)
# 2021-06-30 15:33:41.685000
# we are in 1st zone
# added 853 by 72.98
# added 500 by 72.9775
# added 450 by 72.975
# added 570 by 72.9725
# added 627 by 72.97
# HEDGE ended
# (3000, 218925.95500000002)
# 2021-06-30 15:33:42.685000
# we are in 1st zone
# added 853 by 72.98
# added 147 by 72.9775
# HEDGE ended
# (1000, 72979.6325)
# ('2021-06-30 15:33:39.685000', 'S', 10000, 729751.7375)
# calculating for moment 2021-06-30 15:49:34.585000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:49:40.585000
#  2021-06-30 15:49:47.585000
# 2021-06-30 15:49:34.585000
# we are in 1st zone
# added 250 by 72.9425
# added 288 by 72.94
# added 802 by 72.9375
# added 500 by 72.935
# added 658 by 72.9325
# added 502 by 72.93
# HEDGE ended
# (3000, 218806.16499999998)
# 2021-06-30 15:49:35.585000
# we are in 1st zone
# added 50 by 72.9425
# added 288 by 72.94
# added 752 by 72.9375
# added 500 by 72.935
# added 658 by 72.9325
# added 752 by 72.93
# HEDGE ended
# (3000, 218803.29)
# 2021-06-30 15:49:36.585000
# we are in 1st zone
# added 50 by 72.9425
# added 288 by 72.94
# added 752 by 72.9375
# added 500 by 72.935
# added 658 by 72.9325
# added 752 by 72.93
# HEDGE ended
# (3000, 218803.29)
# 2021-06-30 15:49:37.585000
# we are in 1st zone
# added 50 by 72.9425
# added 230 by 72.94
# added 720 by 72.9375
# HEDGE ended
# (1000, 72938.325)
# ('2021-06-30 15:49:34.585000', 'S', 10000, 729351.07)
# calculating for moment 2021-06-30 15:55:10.477000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 15:55:16.477000
#  2021-06-30 15:55:23.477000
# 2021-06-30 15:55:10.477000
# we are in 1st zone
# added 602 by 72.9025
# added 275 by 72.9
# added 726 by 72.8975
# added 250 by 72.895
# added 680 by 72.8925
# added 467 by 72.89
# HEDGE ended
# (3000, 218688.66999999998)
# 2021-06-30 15:55:11.477000
# we are in 1st zone
# added 50 by 72.905
# added 752 by 72.9025
# added 525 by 72.9
# added 776 by 72.8975
# added 550 by 72.895
# added 347 by 72.8925
# HEDGE ended
# (3000, 218694.8375)
# 2021-06-30 15:55:12.477000
# we are in 1st zone
# added 712 by 72.9025
# added 373 by 72.9
# added 450 by 72.8975
# added 500 by 72.895
# added 330 by 72.8925
# added 635 by 72.89
# HEDGE ended
# (3000, 218689.33)
# 2021-06-30 15:55:13.477000
# we are in 1st zone
# added 712 by 72.9025
# added 288 by 72.9
# HEDGE ended
# (1000, 72901.78)
# ('2021-06-30 15:55:10.477000', 'S', 10000, 728974.6174999999)
# calculating for moment 2021-06-30 16:04:31.941000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 16:04:37.941000
#  2021-06-30 16:04:44.941000
# 2021-06-30 16:04:31.941000
# we are in 1st zone
# added 2 by 72.8725
# added 212 by 72.87
# added 500 by 72.8675
# added 600 by 72.865
# added 480 by 72.8625
# added 512 by 72.86
# added 250 by 72.8575
# added 444 by 72.855
# HEDGE ended
# (3000, 218587.25)
# 2021-06-30 16:04:32.941000
# we are in 1st zone
# added 2 by 72.8725
# added 212 by 72.87
# added 500 by 72.8675
# added 350 by 72.865
# added 500 by 72.8625
# added 612 by 72.86
# added 250 by 72.8575
# added 574 by 72.855
# HEDGE ended
# (3000, 218585.40000000002)
# 2021-06-30 16:04:33.941000
# we are in 1st zone
# added 2 by 72.8725
# added 212 by 72.87
# added 500 by 72.8675
# added 350 by 72.865
# added 500 by 72.8625
# added 612 by 72.86
# added 250 by 72.8575
# added 574 by 72.855
# HEDGE ended
# (3000, 218585.40000000002)
# 2021-06-30 16:04:34.941000
# we are in 1st zone
# added 2 by 72.8725
# added 212 by 72.87
# added 500 by 72.8675
# added 286 by 72.865
# HEDGE ended
# (1000, 72867.325)
# ('2021-06-30 16:04:31.941000', 'S', 10000, 728625.375)
# calculating for moment 2021-06-30 16:05:05.211000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 16:05:11.211000
#  2021-06-30 16:05:18.211000
# 2021-06-30 16:05:05.211000
# we are in 1st zone
# added 312 by 72.86
# added 250 by 72.8575
# added 500 by 72.855
# added 671 by 72.8525
# added 754 by 72.85
# added 400 by 72.8475
# added 113 by 72.845
# HEDGE ended
# (3000, 218557.60749999998)
# 2021-06-30 16:05:06.211000
# we are in 1st zone
# added 162 by 72.86
# added 200 by 72.8575
# added 300 by 72.855
# added 571 by 72.8525
# added 504 by 72.85
# added 450 by 72.8475
# added 480 by 72.845
# added 333 by 72.8425
# HEDGE ended
# (3000, 218550.025)
# 2021-06-30 16:05:07.211000
# we are in 1st zone
# added 162 by 72.86
# added 350 by 72.8575
# added 250 by 72.855
# added 621 by 72.8525
# added 654 by 72.85
# added 350 by 72.8475
# added 613 by 72.845
# HEDGE ended
# (3000, 218553.10749999998)
# 2021-06-30 16:05:08.211000
# we are in 1st zone
# added 162 by 72.86
# added 350 by 72.8575
# added 300 by 72.855
# added 188 by 72.8525
# HEDGE ended
# (1000, 72856.215)
# ('2021-06-30 16:05:05.211000', 'S', 10000, 728516.955)
# calculating for moment 2021-06-30 16:09:44.515000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 16:09:50.515000
#  2021-06-30 16:09:57.515000
# 2021-06-30 16:09:44.515000
# we are in 1st zone
# added 350 by 72.9075
# added 351 by 72.905
# added 2000 by 72.9025
# added 299 by 72.9
# HEDGE ended
# (3000, 218709.38)
# 2021-06-30 16:09:45.515000
# we are in 1st zone
# added 300 by 72.9075
# added 351 by 72.905
# added 2000 by 72.9025
# added 349 by 72.9
# HEDGE ended
# (3000, 218709.005)
# 2021-06-30 16:09:46.515000
# we are in 1st zone
# added 250 by 72.9075
# added 451 by 72.905
# added 2000 by 72.9025
# added 299 by 72.9
# HEDGE ended
# (3000, 218709.13)
# 2021-06-30 16:09:47.515000
# we are in 1st zone
# added 200 by 72.9075
# added 501 by 72.905
# added 299 by 72.9025
# HEDGE ended
# (1000, 72904.7525)
# ('2021-06-30 16:09:44.515000', 'S', 10000, 729032.2675000001)
# calculating for moment 2021-06-30 16:32:03.575000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 16:32:09.575000
#  2021-06-30 16:32:16.575000
# 2021-06-30 16:32:03.575000
# we are in 1st zone
# added 150 by 72.905
# added 460 by 72.9025
# added 1412 by 72.9
# added 400 by 72.8975
# added 350 by 72.895
# added 228 by 72.8925
# HEDGE ended
# (3000, 218697.44)
# 2021-06-30 16:32:04.575000
# we are in 1st zone
# added 150 by 72.905
# added 360 by 72.9025
# added 1512 by 72.9
# added 500 by 72.8975
# added 450 by 72.895
# added 28 by 72.8925
# HEDGE ended
# (3000, 218697.94)
# 2021-06-30 16:32:05.575000
# we are in 1st zone
# added 150 by 72.905
# added 460 by 72.9025
# added 1462 by 72.9
# added 450 by 72.8975
# added 478 by 72.895
# HEDGE ended
# (3000, 218698.385)
# 2021-06-30 16:32:06.575000
# we are in 1st zone
# added 150 by 72.905
# added 460 by 72.9025
# added 390 by 72.9
# HEDGE ended
# (1000, 72901.90000000001)
# ('2021-06-30 16:32:03.575000', 'S', 10000, 728995.665)
# calculating for moment 2021-06-30 16:47:08.656000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 16:47:14.656000
#  2021-06-30 16:47:21.656000
# 2021-06-30 16:47:08.656000
# we are in 1st zone
# added 344 by 72.9625
# added 500 by 72.96
# added 600 by 72.9575
# added 500 by 72.955
# added 400 by 72.9525
# added 502 by 72.95
# added 154 by 72.9475
# HEDGE ended
# (3000, 218866.915)
# 2021-06-30 16:47:09.656000
# we are in 1st zone
# added 394 by 72.9625
# added 450 by 72.96
# added 600 by 72.9575
# added 450 by 72.955
# added 400 by 72.9525
# added 502 by 72.95
# added 204 by 72.9475
# HEDGE ended
# (3000, 218866.665)
# 2021-06-30 16:47:10.656000
# we are in 1st zone
# added 394 by 72.9625
# added 450 by 72.96
# added 600 by 72.9575
# added 450 by 72.955
# added 400 by 72.9525
# added 502 by 72.95
# added 204 by 72.9475
# HEDGE ended
# (3000, 218866.665)
# 2021-06-30 16:47:11.656000
# we are in 1st zone
# added 394 by 72.9625
# added 500 by 72.96
# added 106 by 72.9575
# HEDGE ended
# (1000, 72960.72)
# ('2021-06-30 16:47:08.656000', 'S', 10000, 729560.965)
# calculating for moment 2021-06-30 16:57:34.437000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 16:57:40.437000
#  2021-06-30 16:57:47.437000
# 2021-06-30 16:57:34.437000
# we are in 1st zone
# added 301 by 72.8925
# added 252 by 72.89
# added 500 by 72.8875
# added 950 by 72.885
# added 400 by 72.8825
# added 597 by 72.88
# HEDGE ended
# (3000, 218655.78249999997)
# 2021-06-30 16:57:35.437000
# we are in 1st zone
# added 50 by 72.895
# added 247 by 72.8925
# added 252 by 72.89
# added 400 by 72.8875
# added 300 by 72.885
# added 602 by 72.8825
# added 1149 by 72.88
# HEDGE ended
# (3000, 218652.3625)
# 2021-06-30 16:57:36.437000
# we are in 1st zone
# added 100 by 72.895
# added 297 by 72.8925
# added 352 by 72.89
# added 350 by 72.8875
# added 400 by 72.885
# added 552 by 72.8825
# added 949 by 72.88
# HEDGE ended
# (3000, 218654.7375)
# 2021-06-30 16:57:37.437000
# we are in 1st zone
# added 100 by 72.895
# added 397 by 72.8925
# added 252 by 72.89
# added 251 by 72.8875
# HEDGE ended
# (1000, 72890.86499999999)
# ('2021-06-30 16:57:34.437000', 'S', 10000, 728853.7474999999)
# calculating for moment 2021-06-30 16:59:30.937000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 16:59:36.937000
#  2021-06-30 16:59:43.937000
# 2021-06-30 16:59:30.937000
# we are in 1st zone
# added 47 by 72.8975
# added 244 by 72.895
# added 300 by 72.8925
# added 150 by 72.89
# added 385 by 72.8875
# added 679 by 72.885
# added 350 by 72.8825
# added 845 by 72.88
# HEDGE ended
# (3000, 218656.89)
# 2021-06-30 16:59:31.937000
# we are in 1st zone
# added 47 by 72.8975
# added 244 by 72.895
# added 300 by 72.8925
# added 150 by 72.89
# added 385 by 72.8875
# added 679 by 72.885
# added 350 by 72.8825
# added 845 by 72.88
# HEDGE ended
# (3000, 218656.89)
# 2021-06-30 16:59:32.937000
# we are in 1st zone
# added 47 by 72.8975
# added 244 by 72.895
# added 400 by 72.8925
# added 150 by 72.89
# added 385 by 72.8875
# added 1279 by 72.885
# added 350 by 72.8825
# added 145 by 72.88
# HEDGE ended
# (3000, 218661.14)
# 2021-06-30 16:59:33.937000
# we are in 1st zone
# added 50 by 72.9
# added 247 by 72.8975
# added 294 by 72.895
# added 300 by 72.8925
# added 109 by 72.89
# HEDGE ended
# (1000, 72894.5725)
# ('2021-06-30 16:59:30.937000', 'S', 10000, 728869.4925)
# calculating for moment 2021-06-30 17:11:03.996000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:11:09.996000
#  2021-06-30 17:11:16.996000
# 2021-06-30 17:11:03.996000
# we are in 1st zone
# added 200 by 72.9075
# added 500 by 72.905
# added 350 by 72.9025
# added 250 by 72.9
# added 603 by 72.8975
# added 500 by 72.895
# added 401 by 72.8925
# added 196 by 72.89
# HEDGE ended
# (3000, 218695.9)
# 2021-06-30 17:11:04.996000
# we are in 1st zone
# added 300 by 72.9075
# added 400 by 72.905
# added 350 by 72.9025
# added 250 by 72.9
# added 603 by 72.8975
# added 500 by 72.895
# added 401 by 72.8925
# added 196 by 72.89
# HEDGE ended
# (3000, 218696.15)
# 2021-06-30 17:11:05.996000
# we are in 1st zone
# added 300 by 72.9075
# added 350 by 72.905
# added 350 by 72.9025
# added 250 by 72.9
# added 603 by 72.8975
# added 500 by 72.895
# added 401 by 72.8925
# added 246 by 72.89
# HEDGE ended
# (3000, 218695.4)
# 2021-06-30 17:11:06.996000
# we are in 1st zone
# added 300 by 72.9075
# added 450 by 72.905
# added 250 by 72.9025
# HEDGE ended
# (1000, 72905.125)
# ('2021-06-30 17:11:03.996000', 'S', 10000, 728992.575)
# calculating for moment 2021-06-30 17:32:55.386000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:33:01.386000
#  2021-06-30 17:33:08.386000
# 2021-06-30 17:32:55.386000
# we are in 1st zone
# added 149 by 72.9675
# added 568 by 72.965
# added 1102 by 72.9625
# added 601 by 72.96
# added 580 by 72.9575
# HEDGE ended
# (3000, 218885.2625)
# 2021-06-30 17:32:56.386000
# we are in 1st zone
# added 50 by 72.9675
# added 150 by 72.965
# added 1102 by 72.9625
# added 501 by 72.96
# added 351 by 72.9575
# added 600 by 72.955
# added 246 by 72.9525
# HEDGE ended
# (3000, 218878.1575)
# 2021-06-30 17:32:57.386000
# we are in 1st zone
# added 50 by 72.965
# added 1052 by 72.9625
# added 551 by 72.96
# added 451 by 72.9575
# added 550 by 72.955
# added 346 by 72.9525
# HEDGE ended
# (3000, 218876.4075)
# 2021-06-30 17:32:58.386000
# we are in 1st zone
# added 50 by 72.965
# added 950 by 72.9625
# HEDGE ended
# (1000, 72962.625)
# ('2021-06-30 17:32:55.386000', 'S', 10000, 729602.4525)
# calculating for moment 2021-06-30 17:33:53.218000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:33:59.218000
#  2021-06-30 17:34:06.218000
# 2021-06-30 17:33:53.218000
# we are in 1st zone
# added 50 by 72.955
# added 200 by 72.9525
# added 537 by 72.95
# added 400 by 72.9475
# added 350 by 72.945
# added 447 by 72.9425
# added 881 by 72.94
# added 135 by 72.9375
# HEDGE ended
# (3000, 218834.15000000002)
# 2021-06-30 17:33:54.218000
# we are in 1st zone
# added 150 by 72.9525
# added 337 by 72.95
# added 600 by 72.9475
# added 350 by 72.945
# added 447 by 72.9425
# added 881 by 72.94
# added 235 by 72.9375
# HEDGE ended
# (3000, 218832.02499999997)
# 2021-06-30 17:33:55.218000
# we are in 1st zone
# added 150 by 72.9525
# added 337 by 72.95
# added 600 by 72.9475
# added 350 by 72.945
# added 447 by 72.9425
# added 781 by 72.94
# added 300 by 72.9375
# added 35 by 72.935
# HEDGE ended
# (3000, 218831.68749999997)
# 2021-06-30 17:33:56.218000
# we are in 1st zone
# added 150 by 72.9525
# added 337 by 72.95
# added 513 by 72.9475
# HEDGE ended
# (1000, 72949.0925)
# ('2021-06-30 17:33:53.218000', 'S', 10000, 729446.955)
# calculating for moment 2021-06-30 17:37:22.895000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:37:28.895000
#  2021-06-30 17:37:35.895000
# 2021-06-30 17:37:22.895000
# we are in 1st zone
# added 100 by 72.905
# added 626 by 72.9025
# added 618 by 72.9
# added 537 by 72.8975
# added 688 by 72.895
# added 380 by 72.8925
# added 51 by 72.89
# HEDGE ended
# (3000, 218693.92250000002)
# 2021-06-30 17:37:23.895000
# we are in 1st zone
# added 100 by 72.905
# added 326 by 72.9025
# added 668 by 72.9
# added 637 by 72.8975
# added 638 by 72.895
# added 380 by 72.8925
# added 251 by 72.89
# HEDGE ended
# (3000, 218691.1725)
# 2021-06-30 17:37:24.895000
# we are in 1st zone
# added 100 by 72.905
# added 226 by 72.9025
# added 668 by 72.9
# added 587 by 72.8975
# added 638 by 72.895
# added 430 by 72.8925
# added 351 by 72.89
# HEDGE ended
# (3000, 218689.6725)
# 2021-06-30 17:37:25.895000
# we are in 1st zone
# added 100 by 72.905
# added 226 by 72.9025
# added 668 by 72.9
# added 6 by 72.8975
# HEDGE ended
# (1000, 72901.05)
# ('2021-06-30 17:37:22.895000', 'S', 10000, 728975.8175)
# calculating for moment 2021-06-30 17:40:01.838000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:40:07.838000
#  2021-06-30 17:40:14.838000
# 2021-06-30 17:40:01.838000
# we are in 1st zone
# added 100 by 72.9025
# added 563 by 72.9
# added 550 by 72.8975
# added 738 by 72.895
# added 480 by 72.8925
# added 569 by 72.89
# HEDGE ended
# (3000, 218685.89500000002)
# 2021-06-30 17:40:02.838000
# we are in 1st zone
# added 150 by 72.9025
# added 663 by 72.9
# added 500 by 72.8975
# added 638 by 72.895
# added 462 by 72.8925
# added 587 by 72.89
# HEDGE ended
# (3000, 218686.6)
# 2021-06-30 17:40:03.838000
# we are in 1st zone
# added 250 by 72.9025
# added 563 by 72.9
# added 500 by 72.8975
# added 638 by 72.895
# added 562 by 72.8925
# added 487 by 72.89
# HEDGE ended
# (3000, 218687.1)
# 2021-06-30 17:40:04.838000
# we are in 1st zone
# added 150 by 72.9175
# added 350 by 72.915
# added 450 by 72.9125
# added 50 by 72.91
# HEDGE ended
# (1000, 72914.0)
# ('2021-06-30 17:40:01.838000', 'S', 10000, 728973.595)
# calculating for moment 2021-06-30 17:40:07.211000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:40:08.211000
#  2021-06-30 17:40:15.211000
# 2021-06-30 17:40:07.211000
# we are in 1st zone
# added 50 by 72.9125
# added 300 by 72.91
# added 600 by 72.9075
# added 600 by 72.905
# added 682 by 72.9025
# added 663 by 72.9
# added 105 by 72.8975
# HEDGE ended
# (3000, 218712.5675)
# 2021-06-30 17:40:08.211000
# we are in 1st zone
# added 100 by 72.9075
# added 400 by 72.905
# added 582 by 72.9025
# added 713 by 72.9
# added 650 by 72.8975
# added 555 by 72.895
# HEDGE ended
# (3000, 218699.80500000002)
# 2021-06-30 17:40:09.211000
# we are in 2nd zone
# added 100 by 72.9075
# added 400 by 72.905
# added 582 by 72.9025
# added 713 by 72.9
# added 205 by 72.8975
# HEDGE ended
# (2000, 145803.6925)
# 2021-06-30 17:40:14.211000
# we are in 2nd zone
# added 300 by 72.9025
# added 663 by 72.9
# added 500 by 72.8975
# added 537 by 72.895
# HEDGE ended
# (2000, 145796.815)
# ('2021-06-30 17:40:07.211000', 'S', 10000, 729012.8800000001)
# calculating for moment 2021-06-30 17:40:42.290000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:40:48.290000
#  2021-06-30 17:40:55.290000
# 2021-06-30 17:40:42.290000
# we are in 1st zone
# added 50 by 72.905
# added 150 by 72.9025
# added 669 by 72.9
# added 527 by 72.8975
# added 688 by 72.895
# added 480 by 72.8925
# added 436 by 72.89
# HEDGE ended
# (3000, 218687.9075)
# 2021-06-30 17:40:43.290000
# we are in 1st zone
# added 100 by 72.905
# added 150 by 72.9025
# added 769 by 72.9
# added 527 by 72.8975
# added 738 by 72.895
# added 580 by 72.8925
# added 136 by 72.89
# HEDGE ended
# (3000, 218690.1575)
# 2021-06-30 17:40:44.290000
# we are in 1st zone
# added 300 by 72.905
# added 550 by 72.9025
# added 619 by 72.9
# added 677 by 72.8975
# added 638 by 72.895
# added 216 by 72.8925
# HEDGE ended
# (3000, 218696.37250000003)
# 2021-06-30 17:40:45.290000
# we are in 1st zone
# added 300 by 72.905
# added 450 by 72.9025
# added 250 by 72.9
# HEDGE ended
# (1000, 72902.625)
# ('2021-06-30 17:40:42.290000', 'S', 10000, 728977.0625)
# calculating for moment 2021-06-30 17:45:19.116000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:45:25.116000
#  2021-06-30 17:45:32.116000
# 2021-06-30 17:45:19.116000
# we are in 1st zone
# added 100 by 72.9425
# added 450 by 72.94
# added 350 by 72.9375
# added 250 by 72.935
# added 550 by 72.9325
# added 950 by 72.93
# added 300 by 72.9275
# added 50 by 72.925
# HEDGE ended
# (3000, 218800.0)
# 2021-06-30 17:45:20.116000
# we are in 1st zone
# added 150 by 72.9425
# added 400 by 72.94
# added 350 by 72.9375
# added 250 by 72.935
# added 650 by 72.9325
# added 850 by 72.93
# added 300 by 72.9275
# added 50 by 72.925
# HEDGE ended
# (3000, 218800.375)
# 2021-06-30 17:45:21.116000
# we are in 1st zone
# added 150 by 72.9425
# added 455 by 72.94
# added 350 by 72.9375
# added 250 by 72.935
# added 650 by 72.9325
# added 850 by 72.93
# added 295 by 72.9275
# HEDGE ended
# (3000, 218801.1875)
# 2021-06-30 17:45:22.116000
# we are in 1st zone
# added 150 by 72.9425
# added 455 by 72.94
# added 350 by 72.9375
# added 45 by 72.935
# HEDGE ended
# (1000, 72939.275)
# ('2021-06-30 17:45:19.116000', 'S', 10000, 729340.8375)
# calculating for moment 2021-06-30 17:59:09.116000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:59:15.116000
#  2021-06-30 17:59:22.116000
# 2021-06-30 17:59:09.116000
# we are in 1st zone
# added 150 by 73.0725
# added 150 by 73.07
# added 400 by 73.0675
# added 900 by 73.065
# added 600 by 73.0625
# added 200 by 73.06
# added 330 by 73.0575
# added 270 by 73.055
# HEDGE ended
# (3000, 219190.2)
# 2021-06-30 17:59:10.116000
# we are in 1st zone
# added 406 by 73.065
# added 450 by 73.0625
# added 200 by 73.06
# added 450 by 73.0575
# added 500 by 73.055
# added 250 by 73.0525
# added 744 by 73.05
# HEDGE ended
# (3000, 219170.21500000003)
# 2021-06-30 17:59:11.116000
# we are in 1st zone
# added 456 by 73.065
# added 500 by 73.0625
# added 150 by 73.06
# added 350 by 73.0575
# added 600 by 73.055
# added 350 by 73.0525
# added 594 by 73.05
# HEDGE ended
# (3000, 219171.09000000003)
# 2021-06-30 17:59:12.116000
# we are in 1st zone
# added 456 by 73.065
# added 500 by 73.0625
# added 44 by 73.06
# HEDGE ended
# (1000, 73063.53)
# ('2021-06-30 17:59:09.116000', 'S', 10000, 730595.0350000001)
# calculating for moment 2021-06-30 17:59:09.173000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:59:12.173000
#  2021-06-30 17:59:21.116000
# 2021-06-30 17:59:09.173000
# we are in 1st zone
# added 148 by 73.0675
# added 706 by 73.065
# added 550 by 73.0625
# added 400 by 73.06
# added 350 by 73.0575
# added 300 by 73.055
# added 250 by 73.0525
# added 296 by 73.05
# HEDGE ended
# (3000, 219178.805)
# 2021-06-30 17:59:10.173000
# we are in 1st zone
# added 406 by 73.065
# added 450 by 73.0625
# added 200 by 73.06
# added 450 by 73.0575
# added 500 by 73.055
# added 250 by 73.0525
# added 744 by 73.05
# HEDGE ended
# (3000, 219170.21500000003)
# 2021-06-30 17:59:11.173000
# we are in 1st zone
# added 456 by 73.065
# added 500 by 73.0625
# added 150 by 73.06
# added 350 by 73.0575
# added 600 by 73.055
# added 350 by 73.0525
# added 594 by 73.05
# HEDGE ended
# (3000, 219171.09000000003)
# 2021-06-30 17:59:12.173000
# we are in 1st zone
# added 456 by 73.065
# added 500 by 73.0625
# added 44 by 73.06
# HEDGE ended
# (1000, 73063.53)
# ('2021-06-30 17:59:09.173000', 'S', 10000, 730583.6400000001)
# calculating for moment 2021-06-30 17:59:13.704000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:59:13.704000
#  2021-06-30 17:59:21.704000
# 2021-06-30 17:59:13.704000
# we are in 1st zone
# added 406 by 73.065
# added 400 by 73.0625
# added 250 by 73.06
# added 300 by 73.0575
# added 650 by 73.055
# added 350 by 73.0525
# added 644 by 73.05
# HEDGE ended
# (3000, 219169.96500000003)
# 2021-06-30 17:59:14.704000
# we are in 2nd zone
# added 200 by 73.0625
# added 450 by 73.06
# added 250 by 73.0575
# added 350 by 73.055
# added 450 by 73.0525
# added 300 by 73.05
# HEDGE ended
# (2000, 146111.75)
# 2021-06-30 17:59:19.704000
# we are in 2nd zone
# added 200 by 73.06
# added 300 by 73.0575
# added 400 by 73.055
# added 450 by 73.0525
# added 650 by 73.05
# HEDGE ended
# (2000, 146107.375)
# 2021-06-30 17:59:24.704000
# we are in 3rd zone
# added 150 by 73.0325
# added 350 by 73.03
# added 500 by 73.0275
# HEDGE ended
# (1000, 73029.125)
# 2021-06-30 17:59:34.704000
# we are in 3rd zone
# added 50 by 73.0325
# added 350 by 73.03
# added 450 by 73.0275
# added 150 by 73.025
# HEDGE ended
# (1000, 73028.25)
# 2021-06-30 17:59:44.704000
# we are in 3rd zone
# added 101 by 73.05
# added 250 by 73.0475
# added 395 by 73.045
# added 250 by 73.0425
# added 4 by 73.04
# HEDGE ended
# (1000, 73045.485)
# ('2021-06-30 17:59:13.704000', 'S', 10000, 730491.9500000001)
# calculating for moment 2021-06-30 17:59:21.893000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 17:59:15.704000
#  2021-06-30 17:59:24.116000
# 2021-06-30 17:59:21.893000
# we are in 2nd zone
# added 100 by 73.0425
# added 350 by 73.04
# added 400 by 73.0375
# added 760 by 73.035
# added 390 by 73.0325
# HEDGE ended
# (2000, 146072.525)
# 2021-06-30 17:59:26.893000
# we are in 3rd zone
# added 450 by 73.0325
# added 450 by 73.03
# added 100 by 73.0275
# HEDGE ended
# (1000, 73030.875)
# 2021-06-30 17:59:36.893000
# we are in 3rd zone
# added 150 by 73.045
# added 400 by 73.0425
# added 450 by 73.04
# HEDGE ended
# (1000, 73041.75)
# 2021-06-30 17:59:46.893000
# we are in 3rd zone
# added 100 by 73.05
# added 250 by 73.0475
# added 545 by 73.045
# added 105 by 73.0425
# HEDGE ended
# (1000, 73045.8625)
# 2021-06-30 17:59:56.893000
# we are in 3rd zone
# added 150 by 73.0375
# added 300 by 73.035
# added 400 by 73.0325
# added 150 by 73.03
# HEDGE ended
# (1000, 73033.625)
# 2021-06-30 18:00:06.893000
# we are in 3rd zone
# added 101 by 73.0375
# added 500 by 73.035
# added 300 by 73.0325
# added 99 by 73.03
# HEDGE ended
# (1000, 73034.0075)
# 2021-06-30 18:00:16.893000
# we are in 3rd zone
# added 400 by 73.0475
# added 300 by 73.045
# added 300 by 73.0425
# HEDGE ended
# (1000, 73045.25)
# 2021-06-30 18:00:26.893000
# we are in 3rd zone
# added 350 by 73.045
# added 650 by 73.0425
# HEDGE ended
# (1000, 73043.375)
# 2021-06-30 18:00:36.893000
# we are in 3rd zone
# added 199 by 73.05
# added 400 by 73.0475
# added 401 by 73.045
# HEDGE ended
# (1000, 73046.995)
# ('2021-06-30 17:59:21.893000', 'S', 10000, 730394.265)
# calculating for moment 2021-06-30 18:01:55.215000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 18:02:01.215000
#  2021-06-30 18:02:08.215000
# 2021-06-30 18:01:55.215000
# we are in 1st zone
# added 100 by 73.04
# added 700 by 73.0375
# added 550 by 73.035
# added 450 by 73.0325
# added 1100 by 73.03
# added 100 by 73.0275
# HEDGE ended
# (3000, 219099.875)
# 2021-06-30 18:01:56.215000
# we are in 1st zone
# added 150 by 73.03
# added 200 by 73.0275
# added 380 by 73.025
# added 400 by 73.0225
# added 400 by 73.02
# added 200 by 73.0175
# added 600 by 73.015
# added 430 by 73.0125
# added 240 by 73.01
# HEDGE ended
# (3000, 219056.775)
# 2021-06-30 18:01:57.215000
# we are in 1st zone
# added 150 by 73.03
# added 200 by 73.0275
# added 480 by 73.025
# added 400 by 73.0225
# added 400 by 73.02
# added 350 by 73.0175
# added 600 by 73.015
# added 420 by 73.0125
# HEDGE ended
# (3000, 219059.375)
# 2021-06-30 18:01:58.215000
# we are in 1st zone
# added 150 by 73.03
# added 400 by 73.0275
# added 430 by 73.025
# added 20 by 73.0225
# HEDGE ended
# (1000, 73026.7)
# ('2021-06-30 18:01:55.215000', 'S', 10000, 730242.725)
# calculating for moment 2021-06-30 18:02:01.964000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 18:02:02.215000
#  2021-06-30 18:02:09.964000
# 2021-06-30 18:02:01.964000
# we are in 1st zone
# added 347 by 73.04
# added 500 by 73.0375
# added 450 by 73.035
# added 400 by 73.0325
# added 562 by 73.03
# added 350 by 73.0275
# added 391 by 73.025
# HEDGE ended
# (3000, 219097.63999999998)
# 2021-06-30 18:02:02.964000
# we are in 2nd zone
# added 100 by 73.025
# added 200 by 73.0225
# added 250 by 73.02
# added 350 by 73.0175
# added 530 by 73.015
# added 300 by 73.0125
# added 270 by 73.01
# HEDGE ended
# (2000, 146032.525)
# 2021-06-30 18:02:07.964000
# we are in 2nd zone
# added 100 by 73.0225
# added 300 by 73.02
# added 250 by 73.0175
# added 150 by 73.015
# added 350 by 73.0125
# added 850 by 73.01
# HEDGE ended
# (2000, 146027.75)
# 2021-06-30 18:02:12.964000
# we are in 3rd zone
# added 300 by 73.03
# added 495 by 73.0275
# added 205 by 73.025
# HEDGE ended
# (1000, 73027.7375)
# 2021-06-30 18:02:22.964000
# we are in 3rd zone
# added 100 by 73.035
# added 300 by 73.0325
# added 600 by 73.03
# HEDGE ended
# (1000, 73031.25)
# 2021-06-30 18:02:32.964000
# we are in 3rd zone
# added 115 by 73.015
# added 250 by 73.0125
# added 612 by 73.01
# added 23 by 73.0075
# HEDGE ended
# (1000, 73011.1425)
# ('2021-06-30 18:02:01.964000', 'S', 10000, 730228.0449999999)
# calculating for moment 2021-06-30 18:02:16.484000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 18:02:06.964000
#  2021-06-30 18:02:17.484000
# 2021-06-30 18:02:16.484000
# we are in 2nd zone
# added 200 by 73.0375
# added 850 by 73.035
# added 750 by 73.0325
# added 200 by 73.03
# HEDGE ended
# (2000, 146067.625)
# 2021-06-30 18:02:21.484000
# we are in 3rd zone
# added 150 by 73.03
# added 298 by 73.0275
# added 250 by 73.025
# added 250 by 73.0225
# added 52 by 73.02
# HEDGE ended
# (1000, 73025.61)
# 2021-06-30 18:02:31.484000
# we are in 3rd zone
# added 15 by 73.015
# added 350 by 73.0125
# added 635 by 73.01
# HEDGE ended
# (1000, 73010.95000000001)
# 2021-06-30 18:02:41.484000
# we are in 3rd zone
# added 553 by 73.01
# added 100 by 73.0075
# added 347 by 73.005
# HEDGE ended
# (1000, 73008.015)
# 2021-06-30 18:02:51.484000
# we are in 3rd zone
# added 250 by 72.985
# added 374 by 72.9825
# added 235 by 72.98
# added 141 by 72.9775
# HEDGE ended
# (1000, 72981.8325)
# 2021-06-30 18:03:01.484000
# we are in 3rd zone
# added 172 by 72.985
# added 150 by 72.9825
# added 85 by 72.98
# added 100 by 72.9775
# added 350 by 72.975
# added 143 by 72.9725
# HEDGE ended
# (1000, 72978.1625)
# 2021-06-30 18:03:11.484000
# we are in 3rd zone
# added 302 by 72.995
# added 50 by 72.9925
# added 250 by 72.99
# added 100 by 72.9875
# added 298 by 72.985
# HEDGE ended
# (1000, 72989.895)
# 2021-06-30 18:03:21.484000
# we are in 3rd zone
# added 298 by 73.005
# added 300 by 73.0025
# added 300 by 73.0
# added 102 by 72.995
# HEDGE ended
# (1000, 73001.73)
# 2021-06-30 18:03:31.484000
# we are in 3rd zone
# added 100 by 72.995
# added 100 by 72.9925
# added 50 by 72.99
# added 100 by 72.9875
# added 451 by 72.985
# added 199 by 72.9825
# HEDGE ended
# (1000, 72986.7525)
# ('2021-06-30 18:02:16.484000', 'S', 10000, 730050.5725)
# calculating for moment 2021-06-30 18:02:16.493000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 18:02:11.964000
#  2021-06-30 18:02:20.493000
# 2021-06-30 18:02:16.493000
# we are in 2nd zone
# added 100 by 73.035
# added 300 by 73.0325
# added 352 by 73.03
# added 395 by 73.0275
# added 530 by 73.025
# added 323 by 73.0225
# HEDGE ended
# (2000, 146055.19)
# 2021-06-30 18:02:21.493000
# we are in 3rd zone
# added 150 by 73.03
# added 298 by 73.0275
# added 250 by 73.025
# added 250 by 73.0225
# added 52 by 73.02
# HEDGE ended
# (1000, 73025.61)
# 2021-06-30 18:02:31.493000
# we are in 3rd zone
# added 15 by 73.015
# added 350 by 73.0125
# added 635 by 73.01
# HEDGE ended
# (1000, 73010.95000000001)
# 2021-06-30 18:02:41.493000
# we are in 3rd zone
# added 553 by 73.01
# added 100 by 73.0075
# added 347 by 73.005
# HEDGE ended
# (1000, 73008.015)
# 2021-06-30 18:02:51.493000
# we are in 3rd zone
# added 250 by 72.985
# added 374 by 72.9825
# added 235 by 72.98
# added 141 by 72.9775
# HEDGE ended
# (1000, 72981.8325)
# 2021-06-30 18:03:01.493000
# we are in 3rd zone
# added 172 by 72.985
# added 150 by 72.9825
# added 85 by 72.98
# added 100 by 72.9775
# added 350 by 72.975
# added 143 by 72.9725
# HEDGE ended
# (1000, 72978.1625)
# 2021-06-30 18:03:11.493000
# we are in 3rd zone
# added 302 by 72.995
# added 50 by 72.9925
# added 250 by 72.99
# added 100 by 72.9875
# added 298 by 72.985
# HEDGE ended
# (1000, 72989.895)
# 2021-06-30 18:03:21.493000
# we are in 3rd zone
# added 298 by 73.005
# added 300 by 73.0025
# added 300 by 73.0
# added 102 by 72.995
# HEDGE ended
# (1000, 73001.73)
# 2021-06-30 18:03:31.493000
# we are in 3rd zone
# added 100 by 72.995
# added 100 by 72.9925
# added 50 by 72.99
# added 100 by 72.9875
# added 451 by 72.985
# added 199 by 72.9825
# HEDGE ended
# (1000, 72986.7525)
# ('2021-06-30 18:02:16.493000', 'S', 10000, 730038.1375)
# calculating for moment 2021-06-30 18:02:27.892000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 18:02:17.493000
#  2021-06-30 18:02:28.892000
# 2021-06-30 18:02:27.892000
# we are in 2nd zone
# added 350 by 73.02
# added 200 by 73.0175
# added 545 by 73.015
# added 300 by 73.0125
# added 605 by 73.01
# HEDGE ended
# (2000, 146028.475)
# 2021-06-30 18:02:32.892000
# we are in 3rd zone
# added 115 by 73.015
# added 250 by 73.0125
# added 612 by 73.01
# added 23 by 73.0075
# HEDGE ended
# (1000, 73011.1425)
# 2021-06-30 18:02:42.892000
# we are in 3rd zone
# added 453 by 73.01
# added 200 by 73.0075
# added 347 by 73.005
# HEDGE ended
# (1000, 73007.765)
# 2021-06-30 18:02:52.892000
# we are in 3rd zone
# added 200 by 72.9875
# added 200 by 72.985
# added 374 by 72.9825
# added 185 by 72.98
# added 41 by 72.9775
# HEDGE ended
# (1000, 72983.3325)
# 2021-06-30 18:03:02.892000
# we are in 3rd zone
# added 172 by 72.985
# added 150 by 72.9825
# added 85 by 72.98
# added 100 by 72.9775
# added 300 by 72.975
# added 193 by 72.9725
# HEDGE ended
# (1000, 72978.0375)
# 2021-06-30 18:03:12.892000
# we are in 3rd zone
# added 100 by 73.005
# added 150 by 73.0025
# added 150 by 73.0
# added 150 by 72.9975
# added 350 by 72.995
# added 100 by 72.9925
# HEDGE ended
# (1000, 72998.0)
# 2021-06-30 18:03:22.892000
# we are in 3rd zone
# added 100 by 72.9925
# added 200 by 72.99
# added 251 by 72.985
# added 449 by 72.9825
# HEDGE ended
# (1000, 72985.6275)
# 2021-06-30 18:03:32.892000
# we are in 3rd zone
# added 150 by 72.9925
# added 50 by 72.99
# added 100 by 72.9875
# added 700 by 72.985
# HEDGE ended
# (1000, 72986.625)
# 2021-06-30 18:03:42.892000
# we are in 3rd zone
# added 200 by 72.9925
# added 200 by 72.99
# added 150 by 72.9875
# added 450 by 72.985
# HEDGE ended
# (1000, 72987.875)
# ('2021-06-30 18:02:27.892000', 'S', 10000, 729966.8800000001)
# calculating for moment 2021-06-30 18:18:42.935000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 18:18:19.776000
#  2021-06-30 18:18:52.935000
# 2021-06-30 18:18:42.935000
# we are in 2nd zone
# added 260 by 73.065
# added 300 by 73.0625
# added 350 by 73.06
# added 350 by 73.0575
# added 720 by 73.055
# added 20 by 73.0525
# HEDGE ended
# (2000, 146117.425)
# 2021-06-30 18:18:47.935000
# we are in 2nd zone
# added 101 by 73.06
# added 300 by 73.0575
# added 370 by 73.055
# added 300 by 73.0525
# added 622 by 73.05
# added 307 by 73.0475
# HEDGE ended
# (2000, 146105.0925)
# 2021-06-30 18:18:52.935000
# we are in 2nd zone
# added 100 by 73.06
# added 442 by 73.0575
# added 320 by 73.055
# added 350 by 73.0525
# added 572 by 73.05
# added 216 by 73.0475
# HEDGE ended
# (2000, 146106.25)
# 2021-06-30 18:18:57.935000
# we are in 3rd zone
# added 110 by 73.06
# added 442 by 73.0575
# added 320 by 73.055
# added 128 by 73.0525
# HEDGE ended
# (1000, 73056.335)
# 2021-06-30 18:19:07.935000
# we are in 3rd zone
# added 242 by 73.0575
# added 170 by 73.055
# added 450 by 73.0525
# added 138 by 73.05
# HEDGE ended
# (1000, 73053.79)
# 2021-06-30 18:19:17.935000
# we are in 3rd zone
# added 146 by 73.055
# added 250 by 73.0525
# added 422 by 73.05
# added 182 by 73.0475
# HEDGE ended
# (1000, 73050.9)
# 2021-06-30 18:19:27.935000
# we are in 3rd zone
# added 379 by 73.0525
# added 422 by 73.05
# added 199 by 73.0475
# HEDGE ended
# (1000, 73050.45)
# ('2021-06-30 18:18:42.935000', 'S', 10000, 730540.2424999999)
# calculating for moment 2021-06-30 18:24:49.652000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 18:24:55.652000
#  2021-06-30 18:25:02.652000
# 2021-06-30 18:24:49.652000
# we are in 1st zone
# added 400 by 73.1275
# added 495 by 73.125
# added 350 by 73.1225
# added 950 by 73.12
# added 500 by 73.1175
# added 305 by 73.115
# HEDGE ended
# (3000, 219363.575)
# 2021-06-30 18:24:50.652000
# we are in 1st zone
# added 50 by 73.125
# added 200 by 73.1225
# added 200 by 73.12
# added 300 by 73.1175
# added 700 by 73.115
# added 500 by 73.1125
# added 930 by 73.11
# added 120 by 73.1075
# HEDGE ended
# (3000, 219341.94999999998)
# 2021-06-30 18:24:51.652000
# we are in 1st zone
# added 100 by 73.125
# added 300 by 73.1225
# added 350 by 73.12
# added 400 by 73.1175
# added 750 by 73.115
# added 450 by 73.1125
# added 650 by 73.11
# HEDGE ended
# (3000, 219346.625)
# 2021-06-30 18:24:52.652000
# we are in 1st zone
# added 100 by 73.125
# added 300 by 73.1225
# added 350 by 73.12
# added 250 by 73.1175
# HEDGE ended
# (1000, 73120.625)
# ('2021-06-30 18:24:49.652000', 'S', 10000, 731172.775)
# calculating for moment 2021-06-30 18:24:53.082000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 18:24:54.082000
#  2021-06-30 18:25:01.652000
# 2021-06-30 18:24:53.082000
# we are in 1st zone
# added 200 by 73.1275
# added 350 by 73.125
# added 350 by 73.1225
# added 550 by 73.12
# added 400 by 73.1175
# added 700 by 73.115
# added 350 by 73.1125
# added 100 by 73.11
# HEDGE ended
# (3000, 219356.0)
# 2021-06-30 18:24:54.082000
# we are in 1st zone
# added 300 by 73.1275
# added 250 by 73.125
# added 350 by 73.1225
# added 550 by 73.12
# added 400 by 73.1175
# added 700 by 73.115
# added 450 by 73.1125
# HEDGE ended
# (3000, 219356.5)
# 2021-06-30 18:24:55.082000
# we are in 2nd zone
# added 48 by 73.1325
# added 250 by 73.1275
# added 250 by 73.125
# added 350 by 73.1225
# added 550 by 73.12
# added 400 by 73.1175
# added 152 by 73.115
# HEDGE ended
# (2000, 146242.84000000003)
# 2021-06-30 18:25:00.082000
# we are in 2nd zone
# added 122 by 73.1325
# added 50 by 73.13
# added 400 by 73.1275
# added 250 by 73.125
# added 450 by 73.1225
# added 350 by 73.12
# added 350 by 73.1175
# added 28 by 73.115
# HEDGE ended
# (2000, 146246.385)
# ('2021-06-30 18:24:53.082000', 'S', 10000, 731201.7250000001)
# calculating for moment 2021-06-30 18:44:38.684000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 18:44:44.684000
#  2021-06-30 18:44:51.684000
# 2021-06-30 18:44:38.684000
# we are in 1st zone
# added 1620 by 73.135
# added 100 by 73.1325
# added 200 by 73.13
# added 200 by 73.1275
# added 349 by 73.125
# added 500 by 73.1225
# added 31 by 73.12
# HEDGE ended
# (3000, 219392.045)
# 2021-06-30 18:44:39.684000
# we are in 1st zone
# added 1620 by 73.135
# added 250 by 73.1325
# added 150 by 73.13
# added 200 by 73.1275
# added 299 by 73.125
# added 481 by 73.1225
# HEDGE ended
# (3000, 219393.1225)
# 2021-06-30 18:44:40.684000
# we are in 1st zone
# added 99 by 73.1375
# added 1620 by 73.135
# added 350 by 73.1325
# added 250 by 73.13
# added 300 by 73.1275
# added 381 by 73.125
# HEDGE ended
# (3000, 219397.0625)
# 2021-06-30 18:44:41.684000
# we are in 1st zone
# added 49 by 73.1375
# added 951 by 73.135
# HEDGE ended
# (1000, 73135.12250000001)
# ('2021-06-30 18:44:38.684000', 'S', 10000, 731317.3525)
# calculating for moment 2021-06-30 19:03:41.640000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 19:03:47.640000
#  2021-06-30 19:03:54.640000
# 2021-06-30 19:03:41.640000
# we are in 1st zone
# added 150 by 73.1825
# added 429 by 73.18
# added 270 by 73.1775
# added 320 by 73.175
# added 380 by 73.1725
# added 466 by 73.17
# added 300 by 73.1675
# added 521 by 73.165
# added 164 by 73.1625
# HEDGE ended
# (3000, 219516.155)
# 2021-06-30 19:03:42.640000
# we are in 1st zone
# added 150 by 73.1825
# added 429 by 73.18
# added 270 by 73.1775
# added 320 by 73.175
# added 380 by 73.1725
# added 466 by 73.17
# added 300 by 73.1675
# added 521 by 73.165
# added 164 by 73.1625
# HEDGE ended
# (3000, 219516.155)
# 2021-06-30 19:03:43.640000
# we are in 1st zone
# added 799 by 73.1775
# added 320 by 73.175
# added 430 by 73.1725
# added 466 by 73.17
# added 350 by 73.1675
# added 521 by 73.165
# added 114 by 73.1625
# HEDGE ended
# (3000, 219514.3325)
# 2021-06-30 19:03:44.640000
# we are in 1st zone
# added 200 by 73.1825
# added 251 by 73.18
# added 549 by 73.1775
# HEDGE ended
# (1000, 73179.1275)
# ('2021-06-30 19:03:41.640000', 'S', 10000, 731725.77)
# calculating for moment 2021-06-30 19:05:10.360000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 19:05:16.360000
#  2021-06-30 19:05:23.360000
# 2021-06-30 19:05:10.360000
# we are in 1st zone
# added 150 by 73.2125
# added 200 by 73.21
# added 300 by 73.2075
# added 300 by 73.205
# added 300 by 73.2025
# added 550 by 73.2
# added 250 by 73.1975
# added 450 by 73.195
# added 412 by 73.1925
# added 88 by 73.19
# HEDGE ended
# (3000, 219601.53)
# 2021-06-30 19:05:11.360000
# we are in 1st zone
# added 250 by 73.2
# added 250 by 73.1975
# added 350 by 73.195
# added 300 by 73.1925
# added 550 by 73.19
# added 400 by 73.1875
# added 500 by 73.185
# added 400 by 73.1825
# HEDGE ended
# (3000, 219570.375)
# 2021-06-30 19:05:12.360000
# we are in 1st zone
# added 200 by 73.2
# added 300 by 73.1975
# added 250 by 73.195
# added 400 by 73.1925
# added 450 by 73.19
# added 500 by 73.1875
# added 400 by 73.185
# added 500 by 73.1825
# HEDGE ended
# (3000, 219569.5)
# 2021-06-30 19:05:13.360000
# we are in 1st zone
# added 250 by 73.2
# added 250 by 73.1975
# added 350 by 73.195
# added 150 by 73.1925
# HEDGE ended
# (1000, 73196.5)
# ('2021-06-30 19:05:10.360000', 'S', 10000, 731937.905)
# calculating for moment 2021-06-30 19:05:24.713000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 19:05:24.713000
#  2021-06-30 19:05:30.713000
# 2021-06-30 19:05:24.713000
# we are in 1st zone
# added 100 by 73.2225
# added 150 by 73.22
# added 200 by 73.2175
# added 250 by 73.215
# added 350 by 73.2125
# added 500 by 73.21
# added 350 by 73.2075
# added 500 by 73.205
# added 350 by 73.2025
# added 250 by 73.2
# HEDGE ended
# (3000, 219627.875)
# 2021-06-30 19:05:25.713000
# we are in 2nd zone
# added 200 by 73.2225
# added 200 by 73.22
# added 200 by 73.2175
# added 150 by 73.215
# added 250 by 73.2125
# added 450 by 73.21
# added 400 by 73.2075
# added 150 by 73.205
# HEDGE ended
# (2000, 146425.625)
# 2021-06-30 19:05:30.713000
# we are in 2nd zone
# added 98 by 73.2125
# added 150 by 73.21
# added 200 by 73.2075
# added 200 by 73.205
# added 300 by 73.2025
# added 484 by 73.2
# added 300 by 73.1975
# added 268 by 73.195
# HEDGE ended
# (2000, 146403.885)
# 2021-06-30 19:05:35.713000
# we are in 3rd zone
# added 451 by 73.2
# added 350 by 73.1975
# added 199 by 73.195
# HEDGE ended
# (1000, 73198.13)
# 2021-06-30 19:05:45.713000
# we are in 3rd zone
# added 100 by 73.2025
# added 401 by 73.2
# added 400 by 73.1975
# added 99 by 73.195
# HEDGE ended
# (1000, 73198.75499999999)
# 2021-06-30 19:05:55.713000
# we are in 3rd zone
# added 201 by 73.2
# added 450 by 73.1975
# added 250 by 73.195
# added 99 by 73.1925
# HEDGE ended
# (1000, 73196.88249999999)
# ('2021-06-30 19:05:24.713000', 'S', 10000, 732051.1525)
# calculating for moment 2021-06-30 19:29:14.314000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 19:29:20.314000
#  2021-06-30 19:29:27.314000
# 2021-06-30 19:29:14.314000
# we are in 1st zone
# added 50 by 73.175
# added 144 by 73.1725
# added 256 by 73.17
# added 351 by 73.1675
# added 550 by 73.165
# added 300 by 73.1625
# added 351 by 73.16
# added 250 by 73.1575
# added 500 by 73.155
# added 248 by 73.1525
# HEDGE ended
# (3000, 219486.2575)
# 2021-06-30 19:29:15.314000
# we are in 1st zone
# added 50 by 73.175
# added 144 by 73.1725
# added 306 by 73.17
# added 351 by 73.1675
# added 650 by 73.165
# added 250 by 73.1625
# added 351 by 73.16
# added 250 by 73.1575
# added 500 by 73.155
# added 148 by 73.1525
# HEDGE ended
# (3000, 219487.8825)
# 2021-06-30 19:29:16.314000
# we are in 1st zone
# added 99 by 73.175
# added 144 by 73.1725
# added 306 by 73.17
# added 451 by 73.1675
# added 550 by 73.165
# added 250 by 73.1625
# added 351 by 73.16
# added 250 by 73.1575
# added 599 by 73.155
# HEDGE ended
# (3000, 219489.4825)
# 2021-06-30 19:29:17.314000
# we are in 1st zone
# added 49 by 73.175
# added 194 by 73.1725
# added 306 by 73.17
# added 451 by 73.1675
# HEDGE ended
# (1000, 73169.60250000001)
# ('2021-06-30 19:29:14.314000', 'S', 10000, 731633.2250000001)
# calculating for moment 2021-06-30 19:40:36.010000
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-06-30 19:40:42.010000
#  2021-06-30 19:40:49.010000
# 2021-06-30 19:40:36.010000
# we are in 1st zone
# added 222 by 73.1375
# added 275 by 73.135
# added 230 by 73.1325
# added 377 by 73.13
# added 450 by 73.1275
# added 439 by 73.125
# added 330 by 73.1225
# added 677 by 73.12
# HEDGE ended
# (3000, 219381.05)
# 2021-06-30 19:40:37.010000
# we are in 1st zone
# added 50 by 73.1375
# added 375 by 73.135
# added 330 by 73.1325
# added 327 by 73.13
# added 350 by 73.1275
# added 389 by 73.125
# added 280 by 73.1225
# added 641 by 73.12
# added 250 by 73.1175
# added 8 by 73.115
# HEDGE ended
# (3000, 219378.5)
# 2021-06-30 19:40:38.010000
# we are in 1st zone
# added 50 by 73.1375
# added 275 by 73.135
# added 330 by 73.1325
# added 327 by 73.13
# added 250 by 73.1275
# added 389 by 73.125
# added 380 by 73.1225
# added 591 by 73.12
# added 300 by 73.1175
# added 108 by 73.115
# HEDGE ended
# (3000, 219375.87500000003)
# 2021-06-30 19:40:39.010000
# we are in 1st zone
# added 50 by 73.1375
# added 275 by 73.135
# added 330 by 73.1325
# added 327 by 73.13
# added 18 by 73.1275
# HEDGE ended
# (1000, 73132.53)
# ('2021-06-30 19:40:36.010000', 'S', 10000, 731267.9550000001)

# %%
sign_sql.commit()

# %%
cur.close()
sign_sql.close()
