# %%
import pandas as pd
import numpy as np
import sqlite3
import pickle
import gc
from IPython.display import clear_output
from collections import defaultdict

from functools import lru_cache

def sum_2_tuples(a, b):
    return tuple(map(sum, zip(a, b)))

# %% [markdown]
# Experiment parameters:

# %%
TRADES_DIR = '../TRADES/USD_TOM_trades_Micex_02_10.feather'
LOB_DIR = '../Data_lob/'

RANDOM_MOMENTS_FILE = '../0_CommonFiles/random_moments_aligned_to_1000_2000.pkl'
SIGNATURE_FILE = './signature.db3'

TRADE_SIZE_MIN_INCLUSIVE = 100
TRADE_SIZE_MAX_EXCLUSIVE = 2000

# %%
# Signature hedger
volume = 5_000 # in contracts

look_back_time = np.timedelta64(30, 's')

hedge_params_df = pd.DataFrame({
    'zone_number': [1, 2, 3],
    'distance': [1, 5, 10],
    'proportion': [0.3, 0.2, 0.1]
})

# %%
with open(RANDOM_MOMENTS_FILE, 'rb') as file:
    moments = pickle.load(file)

# %%
len(moments)
# Out:
# 2712

# %% [markdown]
# # 1. Select big trades

# %%
trades = pd.read_feather(TRADES_DIR)

# %%
trade_temp = trades.groupby(['Time', 'AGGRESSOR_SIDE'], as_index=False).sum()

# %%
volume_weighted_trade_price = trade_temp['TRADE_VALUE'] / trade_temp['SIZE'] / 1000.0

# %%
trade_temp['PRICE'] = volume_weighted_trade_price
# round to 0.01 of cent
trades['PRICE'] = trades['PRICE'].round(4)

# %%
trades = trade_temp

# %%
del trade_temp

# %%
#look only on big trades
trades = trades[(trades.SIZE >= TRADE_SIZE_MIN_INCLUSIVE) & (trades.SIZE < TRADE_SIZE_MAX_EXCLUSIVE)]

# %% [markdown]
# # 2. Build signature

# %%
signature_table = {
    'B': {
        (100, 499):   [0.0024905292322913285, 0.0026433182635482626, 0.002697568954515778, 0.002754871518810317, 0.0027752543082661374, 0.0028078903944222097, 0.0028371652741295862, 0.002847808719280013, 0.0028629920749483452, 0.0028644201398436335, 0.002902226078334742, 0.0029074442675728735, 0.002909906263110637, 0.002920145213701039, 0.0029235891185313977, 0.0029301488175850834, 0.0029372444769760727, 0.0029551045002256904, 0.002967188583503694, 0.0029792892963725706, 0.003030206853470199, 0.0030455028641086295, 0.0030361961146199213, 0.003037642986828899, 0.003047899841558298, 0.0030454963201911197, 0.0030526111305911024, 0.003057226325988928, 0.0030565060371562664, 0.00304376181684737],
        (500, 999):   [0.0026910899881976646, 0.002876574048739949, 0.002954233358535151, 0.003004949016366884, 0.003051637010818458, 0.003155480831982127, 0.0032022998510619623, 0.0032067194415670575, 0.0032198526432204995, 0.0032461271190022552, 0.003316403526027055, 0.003348364191854261, 0.003382860725006834, 0.0033982864133026806, 0.003416631622502073, 0.0034439206651035196, 0.0034502304663365426, 0.0034699038516893947, 0.0034927645055142713, 0.0035066473844458652, 0.003557687851464374, 0.0035595092792224665, 0.0035653776916127, 0.0035530782397924818, 0.0035613312440704622, 0.0035661420643975034, 0.0035718473977402877, 0.0035835479654684537, 0.00360718410967474, 0.0036128712728256715],
        (1000, 1999): [0.004612341943448629, 0.00470303210971194, 0.004739355350991369, 0.004756822374477201, 0.004770824837943304, 0.004812400062769874, 0.0048387798928851145, 0.004828780297409278, 0.0048642111992043355, 0.0048948626351468065, 0.004910218723984043, 0.004887823304729127, 0.004932528527765032, 0.004911338680908534, 0.004911278319943477, 0.004880698744659351, 0.004923283029468591, 0.004910424956089112, 0.004932294400206548, 0.004955211724933123, 0.004963611473046904, 0.005004210988770786, 0.005002578327983672, 0.005010618520081839, 0.0050076751191620965, 0.005044662839871767, 0.005075435694415131, 0.005073996103970367, 0.00508851019301986, 0.005083605829427722],
        (2000, 2999): [0.007666860013730193, 0.007643789023029769, 0.007652402066997683, 0.007613438051744633, 0.007614776792131339, 0.007502060470679352, 0.0075052798384596265, 0.007552209078378696, 0.007517176678966911, 0.007531715385564781, 0.007483064873911523, 0.007428261624852005, 0.007469441111481189, 0.007374616830424646, 0.0073684494057514455, 0.007305188287727694, 0.007232535700494532, 0.007274966262455883, 0.007390991475109071, 0.007427080430026108, 0.007431972843167495, 0.007426670597037147, 0.0073594906840288256, 0.00732305074441914, 0.007278815445096429, 0.007283750842030177, 0.007318336045351533, 0.007320043061559275, 0.007378172975640467, 0.007426300513799741],
        (3000, 3999): [0.009674008146040854, 0.009594498750866546, 0.009523753635455986, 0.009415641260702419, 0.009247837921464483, 0.00933503498220464, 0.009277199524990488, 0.009292350809572029, 0.009209022491318938, 0.009075989417298902, 0.009069096460127404, 0.008942232763600304, 0.009036936492981215, 0.009030853634262365, 0.009053667229322226, 0.009102777991050979, 0.009074072798063661, 0.00918350715436552, 0.0091641956874766, 0.00915439691789643, 0.00905721982629974, 0.009179315898859751, 0.009239740959752309, 0.009123399560758687, 0.009069593964616589, 0.008900625072984975, 0.008930201349958393, 0.008894070702762092, 0.009053905993548605, 0.008901185965190536],
        (4000, 4999): [0.011019889178636652, 0.011441198417186441, 0.011105431809768135, 0.011148529862105707, 0.011417548194302468, 0.011361981369996148, 0.01132618883567955, 0.011368819335707462, 0.011563397010111769, 0.011873061573159035, 0.0117197120970133, 0.01185161970097324, 0.011850805141290345, 0.01188601861527688, 0.0117790126443318, 0.011510710136511828, 0.011644152465413704, 0.011700125096293482, 0.011649358483612466, 0.011687462865742921, 0.011916583861082805, 0.011878289032676563, 0.01207941101879102, 0.012175605618630151, 0.012251549957490634, 0.01243124102886145, 0.012545704816970833, 0.012537714755208915, 0.012456087269594924, 0.012601588499248887],
        (5000, 5999): [0.009752595144464879, 0.009710915814622032, 0.009442979565791883, 0.009568342484458967, 0.009600821152447949, 0.00990578351907795, 0.009932260287593569, 0.009837965853948472, 0.00966540179856852, 0.009673962782141984, 0.009626877350233123, 0.009891261370888119, 0.010099024930627006, 0.01040851357086885, 0.010349333254191075, 0.010325257097068661, 0.01007730186831571, 0.01013435307997328, 0.010072955006161233, 0.010112540519686386, 0.010590693249442219, 0.01102417343108075, 0.011126782049952606, 0.01094982892843211, 0.010941644412129534, 0.011057090625790612, 0.011330102764629818, 0.011472762239011168, 0.011149269176548692, 0.01131296380607968],
        # ??? copy results for 5000-5999
        (6000, 1000000): [0.009752595144464879, 0.009710915814622032, 0.009442979565791883, 0.009568342484458967, 0.009600821152447949, 0.00990578351907795, 0.009932260287593569, 0.009837965853948472, 0.00966540179856852, 0.009673962782141984, 0.009626877350233123, 0.009891261370888119, 0.010099024930627006, 0.01040851357086885, 0.010349333254191075, 0.010325257097068661, 0.01007730186831571, 0.01013435307997328, 0.010072955006161233, 0.010112540519686386, 0.010590693249442219, 0.01102417343108075, 0.011126782049952606, 0.01094982892843211, 0.010941644412129534, 0.011057090625790612, 0.011330102764629818, 0.011472762239011168, 0.011149269176548692, 0.01131296380607968]
    },
    'S': {
        (100, 499):   [-0.002691961920942539, -0.0028218211718799174, -0.0028526589224838624, -0.0028580376926901057, -0.0028554915302185426, -0.0028715145253223814, -0.002892245132825392, -0.002917789041322858, -0.0029401823740718186, -0.0029468314074382472, -0.002966728525845394, -0.002982267277371796, -0.0029956516900289634, -0.0030053244866775257, -0.003014695901351538, -0.0030689010638763146, -0.0030739605354541673, -0.0030778089280789575, -0.003067598021875995, -0.0030704625041084, -0.003097924784737163, -0.0031019103469523404, -0.0031078246667001807, -0.0031344306091877928, -0.0031704390863474194, -0.0031862293510007984, -0.0031799665756465662, -0.0031765049864934634, -0.0031675934803442165, -0.0031961782294462975],
        (500, 999):   [-0.003008004466562672, -0.0031912751646871232, -0.0032467112890713526, -0.0032607366979502087, -0.0032648957081756556, -0.0032709954302336188, -0.00327360221832405, -0.0032897902474548677, -0.003308227730510537, -0.0033210146283061018, -0.003387044834705139, -0.003378095054457927, -0.0033538402745523542, -0.003355872942904236, -0.0033635644305300394, -0.003405175290050012, -0.003403924048792436, -0.0034102931548327, -0.0034047582602718396, -0.0033956189805064733, -0.0034858723031213268, -0.003465391695813379, -0.0034771176678052847, -0.00347568541315807, -0.0034998747813142833, -0.003529806317990441, -0.003506756427493522, -0.0034893681334655694, -0.0034902468507876276, -0.003508570475398435],
        (1000, 1999): [-0.005193527548200116, -0.0053838014627723444, -0.005402806578284014, -0.00543410081791218, -0.005412053312792029, -0.005472204404052999, -0.0054955736618325065, -0.005525343264595411, -0.005548110821957607, -0.005569054210315334, -0.005567431960921996, -0.005554403572277654, -0.005574627243539157, -0.0055716513554180305, -0.005573081132148346, -0.00558488020683325, -0.005629225883774346, -0.00566259193964533, -0.005622225625124084, -0.005608585487945004, -0.005625586022881097, -0.00564591369330999, -0.0056556044406593465, -0.0056854235969587, -0.005713757978951893, -0.005767603214608918, -0.005737164047361523, -0.005750507698046928, -0.005750483826174665, -0.005789134591693843],
        (2000, 2999): [-0.008772532023005432, -0.008736440237200447, -0.00864071731179626, -0.008544224583353096, -0.008405019827083185, -0.00842515509726803, -0.008430296925373905, -0.008388579154313961, -0.008475364452445133, -0.008514497085523693, -0.008438669567902289, -0.00845897993666488, -0.008502637468935552, -0.008537800517944014, -0.008599350476616795, -0.008595145849275823, -0.008548945261920009, -0.008548854374433073, -0.00856299259324292, -0.008578076602230776, -0.00860636546575176, -0.008546389272189526, -0.008434613305679736, -0.008461867077007376, -0.008513358115444467, -0.00851437134906376, -0.008506239865189079, -0.008559544883079565, -0.008537952615015552, -0.008550979625147002],
        (3000, 3999): [-0.011650249871759721, -0.011652507980316522, -0.011428646460492638, -0.011296664818182872, -0.011108769959144116, -0.010753379840007862, -0.010904103664097662, -0.010850310322040264, -0.010937717759928717, -0.011050993124673659, -0.010912228212921427, -0.011021726452862606, -0.011204422983069303, -0.011344730432164172, -0.011289843640146834, -0.011298736762360055, -0.011488414631182322, -0.01138611127223616, -0.0113674158517282, -0.011492847772814367, -0.011416581505829937, -0.011391728273509281, -0.011444262948521505, -0.01137037579692953, -0.011301540836656656, -0.011478391220936683, -0.01160197606041419, -0.011795934700036221, -0.011818350553284658, -0.011633203311841384],
        (4000, 4999): [-0.01114950631995241, -0.011162250593862581, -0.011277315685737942, -0.011209797128188783, -0.011291138714941919, -0.01130973134553277, -0.011351357282652547, -0.01177774409391618, -0.011679075618075754, -0.011799609730924856, -0.011860618116177024, -0.011917534319117894, -0.011961431612554935, -0.011983307015411214, -0.011982966390406156, -0.012080630394631866, -0.01200226885101033, -0.011999803941175459, -0.011898603325597674, -0.012018945611891872, -0.012245730524373012, -0.012279839944683716, -0.012227665359045589, -0.012035700438750357, -0.011993569730108572, -0.01203636668121768, -0.012261569331689435, -0.012357793037477716, -0.012332823490384233, -0.012573643228148244],
        (5000, 5999): [-0.010886281841212774, -0.010909766916686381, -0.01084644532848205, -0.010833785438672647, -0.01090003835236758, -0.010924942169616725, -0.010740406167922462, -0.010668919209943352, -0.01079079193381028, -0.010737813976872946, -0.010938418645686548, -0.010975720465114053, -0.010862777731241006, -0.010468382338453026, -0.01049630362309003, -0.010400533002998109, -0.010530070150458842, -0.01048533193953031, -0.010392612827167066, -0.010397852353878892, -0.010575881143408163, -0.01078093641122272, -0.010823641380151126, -0.011011893532463452, -0.011201870383060286, -0.011250730937168022, -0.011125539631192187, -0.01093584323456253, -0.010944043691882706, -0.011085875722578327],
#         # ??? copy results for 5000-5999
         (6000, 1000000): [-0.010886281841212774, -0.010909766916686381, -0.01084644532848205, -0.010833785438672647, -0.01090003835236758, -0.010924942169616725, -0.010740406167922462, -0.010668919209943352, -0.01079079193381028, -0.010737813976872946, -0.010938418645686548, -0.010975720465114053, -0.010862777731241006, -0.010468382338453026, -0.01049630362309003, -0.010400533002998109, -0.010530070150458842, -0.01048533193953031, -0.010392612827167066, -0.010397852353878892, -0.010575881143408163, -0.01078093641122272, -0.010823641380151126, -0.011011893532463452, -0.011201870383060286, -0.011250730937168022, -0.011125539631192187, -0.01093584323456253, -0.010944043691882706, -0.011085875722578327]
    }
}


'''
Convert signature table
into signature table with diffs 
delta(t) = signature(t+1) - signature(t)
'''
def build_delta_signature(signature_table):
    output = {}
    for side in signature_table:
        if side not in output:
            output[side] = {}
        
        for size, array in signature_table[side].items():
            # for 1..N we store only delta - change from previous moment
            delta_signature = np.array(array[1:]) - np.array(array[:-1])
            
            '''
            for initial time T0 we store array[0],
            price jump before deal and after deal
            '''
            delta_signature = np.insert(delta_signature, obj=0, values=array[0]) 
            
            output[side][size] = delta_signature
            
    return output

delta_signature_table = build_delta_signature(signature_table)

# %%
'''
aggregate multiple signatures
into one
'''
def build_multitrades_signature(trades_before):
    signature = defaultdict(float)

    for trade in trades_before.itertuples():
        side = trade.AGGRESSOR_SIDE
        for size_range in signature_table[side]:
            if size_range[0] <= trade.SIZE <= size_range[1]:
                break

        delta_signature = delta_signature_table[side][size_range]

        times = {trade.Time + np.timedelta64(sec, 's') : delta_signature[sec] 
               for sec in range(30)}

        for k, v in times.items():
            signature[k] += v
        
    signature = (sorted(signature.items()))

    reconstructed_signature = []
    total = 0

    for (k,v) in signature:
        total += v
        reconstructed_signature.append((k, total))

    return reconstructed_signature

# %% [markdown]
# # 3. Hedge functions

# %%
def get_trades_before(moment):
    global look_back_time, trades
    moment_before = moment - look_back_time
    index1 = trades.Time.searchsorted(moment_before, side='left')
    index2 = trades.Time.searchsorted(moment, side='right')
    trades_before = trades.iloc[index1 : index2]
    return trades_before

# %%
'''
@returns 
zone1time - time, when zone1 ends and zone2 starts
zone2time - time, when zone2 ends and zone3 starts
'''
def get_zone_times(moment, side, skip_empty_trades = False):
    #1 get trades before our trade
    trades_before = get_trades_before(moment)
    
    if len(trades_before) == 0:
        if skip_empty_trades == False:
            #Columns: [Time, AGGRESSOR_SIDE, PRICE, SIZE, TRADE_VALUE]
            trades_before.loc[-1] = [moment, side, -1.0, 1000, -1000.0]  # adding a row
            trades_before.index = trades_before.index + 1  # shifting index
            trades_before = trades_before.sort_index()  # sorting by index
        else:
            return None, None

    #2 mix them into signature
    reference_signature = build_multitrades_signature(trades_before)
    #3 find three zones
    mmax = max(reference_signature, key = lambda item: item[1])
    mmin = min(reference_signature, key = lambda item: item[1])
    
    if side == 'B':
        zone1price = mmin[1] + (mmax[1] - mmin[1]) * 0.33
        zone2price = mmin[1] + (mmax[1] - mmin[1]) * 0.66
    
        for (k, v) in reference_signature:
            if v >= zone1price:
                #print(k)
                zone1time = k
                break
            
        for (k, v) in reference_signature:
            if v >= zone2price:
                #print(k)
                zone2time = k
                break
    else:
        zone1price = mmax[1] - (mmax[1] - mmin[1]) * 0.33
        zone2price = mmax[1] - (mmax[1] - mmin[1]) * 0.66
        
        for (k, v) in reference_signature:
            if v <= zone1price:
                #print(k)
                zone1time = k
                break
            
        for (k, v) in reference_signature:
            if v <= zone2price:
                #print(k)
                zone2time = k
                break
                
    #4 return result
    return zone1time, zone2time

# %%
def make_hedge(lob, datetime, size, side):
    #lob = lob[lob['Time'] >= datetime]
    time_index = lob['Time'].searchsorted(datetime, side='right')
        
    if time_index >= len(lob):
        return (0, 0.0)
    row = lob.iloc[time_index] # first timestamp >= datetime
    
    quote_side = 'BID' if (side == 'S') else 'ASK'
    
    maxsize = sum([row[quote_side + '_SIZE' + str(level)] for level in range(1, 11)])
        
    if maxsize < size:
        raise ValueError(f'size {size} is greater than available {maxsize}')
    
    size_hedged, sum_hedged = 0, 0.0
    level = 1
    while size_hedged < size and level < 11:
        portion = min(size - size_hedged, row[quote_side + '_SIZE' + str(level)])
        price = row[quote_side + '_PRICE' + str(level)]
        size_hedged += portion
        sum_hedged += portion * price
        print(f'added {portion} by {price}')
        level += 1
        
    print('HEDGE ended')
    return (size_hedged, sum_hedged)

# %%
class LOBCache:
    def __init__(self):
        pass
    
    def get_lob(self, datetime):
        #print(datetime)
        filename = datetime.strftime('LOB_%m%d.feather')
        return self.__get_lob_by_filename(filename)
        pass
    
    @lru_cache(maxsize=4)
    def __get_lob_by_filename(self, filename):
        print(filename)
        lob = pd.read_feather(LOB_DIR + filename).dropna()
        lob['BID_SIZE1'] = 99_999_999
        lob['ASK_SIZE1'] = 99_999_999
        return lob

# %%
cache = LOBCache()

# %%
def calc_hedge_signature(cache, moment, hedge_params_df):
    curr_moment = moment
    print(hedge_params_df)

    lob = cache.get_lob(curr_moment)
    remain = volume
    total = None
    
    zone1time, zone2time = get_zone_times(curr_moment, side, skip_empty_trades = True)
    print('zone1time, zone2time','\n',zone1time,'\n', zone2time)
    if zone1time is None:
        remain = 0
        total = (-2, -2.0)
    while remain > 0:
        print(curr_moment)
        
        # select our zone
        if moment <= curr_moment <= zone1time:
            print('we are in 1st zone')
            zone = 1
        elif zone1time < curr_moment <= zone2time:
            print('we are in 2nd zone')
            zone = 2
        else:
            print('we are in 3rd zone')
            zone = 3
        
        row = hedge_params_df[hedge_params_df['zone_number'] == zone]
        size_contracts = int(volume * row['proportion'])
        size_contracts = min(size_contracts, remain)

        hedge_result = make_hedge(lob, curr_moment, size = size_contracts, side = side)

        interval =  row['distance'].iloc[0]
        curr_moment = curr_moment + np.timedelta64(interval, 's')
        if hedge_result is None:
            break
        
        if hedge_result[0] == 0:
            return (-1, -1.0)
        
        if total is None:
            total = hedge_result
        else:
            total = sum_2_tuples(total, hedge_result)
            
        print(hedge_result)
        remain -= hedge_result[0]
        if remain == 0:
            break
            
    del lob
            
    if remain > 0:
        return None
    else:
        return total

# %% [markdown]
# # 4. Calculation

# %%
#CREATE TABLE RESULT(MOMENT TEXT, SIDE TEXT, QUANTITY INTEGER, SUM REAL, PRIMARY KEY(MOMENT,SIDE));
sign_sql = sqlite3.connect(SIGNATURE_FILE)
sign_sql.execute('CREATE TABLE IF NOT EXISTS RESULT(MOMENT TEXT, SIDE TEXT, QUANTITY INTEGER, SUM REAL, PRIMARY KEY(MOMENT,SIDE));')
cur=sign_sql.cursor()

# %%
records = []

for moment in moments:
    for side in ('B', 'S'):
        record = (str(moment),side)
        query='select exists(select 1 from result where moment=? and side=? collate nocase) limit 1'
        # 'query' RETURNS 1 IF USERNAME EXISTS OR 0 IF NOT, AS INTEGER(MAYBE). 'collate nocase'= CASE INSENSITIVE, IT'S OPTIONAL
        check=cur.execute(query,record) 
        if check.fetchone()[0]==1:
            print(f'Moment already available ' + str(record))
            continue

        print('calculating for moment', moment)
        result = calc_hedge_signature(cache, moment, hedge_params_df)

        query='INSERT OR REPLACE INTO result(moment, side, quantity, sum) VALUES(?, ?, ?, ?);'
        if result:
            record = (str(moment), side, int(result[0]), result[1])
        else:
            record = (str(moment), side, -1, -1)

        print(record)
        cur.execute(query, record)
        records.append(record)

        gc.collect()

        if len(records) % 100 == 0:
            clear_output(wait=False)
# Out:
# Moment already available ('2021-02-01 18:10:15.611222', 'B')
# Moment already available ('2021-02-01 18:10:15.611222', 'S')
# Moment already available ('2021-02-01 22:20:17.074682', 'B')
# Moment already available ('2021-02-01 22:20:17.074682', 'S')
# Moment already available ('2021-02-01 23:31:08.196003', 'B')
# Moment already available ('2021-02-01 23:31:08.196003', 'S')
# Moment already available ('2021-02-01 13:23:14.931749', 'B')
# Moment already available ('2021-02-01 13:23:14.931749', 'S')
# Moment already available ('2021-02-01 13:31:09.506345', 'B')
# Moment already available ('2021-02-01 13:31:09.506345', 'S')
# Moment already available ('2021-02-01 11:23:02.279950', 'B')
# Moment already available ('2021-02-01 11:23:02.279950', 'S')
# Moment already available ('2021-02-01 12:12:26.394156', 'B')
# Moment already available ('2021-02-01 12:12:26.394156', 'S')
# Moment already available ('2021-02-01 12:23:23.321660', 'B')
# Moment already available ('2021-02-01 12:23:23.321660', 'S')
# Moment already available ('2021-02-01 12:34:16.916168', 'B')
# Moment already available ('2021-02-01 12:34:16.916168', 'S')
# Moment already available ('2021-02-01 16:31:21.180792', 'B')
# Moment already available ('2021-02-01 16:31:21.180792', 'S')
# Moment already available ('2021-02-01 17:10:51.083060', 'B')
# Moment already available ('2021-02-01 17:10:51.083060', 'S')
# Moment already available ('2021-02-01 17:33:43.900099', 'B')
# Moment already available ('2021-02-01 17:33:43.900099', 'S')
# Moment already available ('2021-02-02 19:10:04.621620', 'B')
# Moment already available ('2021-02-02 19:10:04.621620', 'S')
# Moment already available ('2021-02-02 23:34:13.063881', 'B')
# Moment already available ('2021-02-02 23:34:13.063881', 'S')
# Moment already available ('2021-02-02 14:19:32.303616', 'B')
# Moment already available ('2021-02-02 14:19:32.303616', 'S')
# Moment already available ('2021-02-02 12:08:21.873407', 'B')
# Moment already available ('2021-02-02 12:08:21.873407', 'S')
# Moment already available ('2021-02-02 12:33:22.669540', 'B')
# Moment already available ('2021-02-02 12:33:22.669540', 'S')
# Moment already available ('2021-02-02 13:08:56.870705', 'B')
# Moment already available ('2021-02-02 13:08:56.870705', 'S')
# Moment already available ('2021-02-02 13:20:08.272736', 'B')
# Moment already available ('2021-02-02 13:20:08.272736', 'S')
# Moment already available ('2021-02-02 13:32:27.706510', 'B')
# Moment already available ('2021-02-02 13:32:27.706510', 'S')
# Moment already available ('2021-02-02 10:12:20.698970', 'B')
# Moment already available ('2021-02-02 10:12:20.698970', 'S')
# Moment already available ('2021-02-02 10:23:21.168553', 'B')
# Moment already available ('2021-02-02 10:23:21.168553', 'S')
# Moment already available ('2021-02-02 10:33:01.549783', 'B')
# Moment already available ('2021-02-02 10:33:01.549783', 'S')
# Moment already available ('2021-02-02 20:23:43.402557', 'B')
# Moment already available ('2021-02-02 20:23:43.402557', 'S')
# Moment already available ('2021-02-02 20:33:15.278902', 'B')
# Moment already available ('2021-02-02 20:33:15.278902', 'S')
# Moment already available ('2021-02-02 16:12:27.110565', 'B')
# Moment already available ('2021-02-02 16:12:27.110565', 'S')
# Moment already available ('2021-02-02 16:19:59.900793', 'B')
# Moment already available ('2021-02-02 16:19:59.900793', 'S')
# Moment already available ('2021-02-02 22:12:14.939357', 'B')
# Moment already available ('2021-02-02 22:12:14.939357', 'S')
# Moment already available ('2021-02-03 11:10:05.788678', 'B')
# Moment already available ('2021-02-03 11:10:05.788678', 'S')
# Moment already available ('2021-02-03 11:23:16.330379', 'B')
# Moment already available ('2021-02-03 11:23:16.330379', 'S')
# Moment already available ('2021-02-03 11:33:07.622720', 'B')
# Moment already available ('2021-02-03 11:33:07.622720', 'S')
# Moment already available ('2021-02-03 17:08:33.829709', 'B')
# Moment already available ('2021-02-03 17:08:33.829709', 'S')
# Moment already available ('2021-02-03 17:21:40.551259', 'B')
# Moment already available ('2021-02-03 17:21:40.551259', 'S')
# Moment already available ('2021-02-03 16:12:29.570341', 'B')
# Moment already available ('2021-02-03 16:12:29.570341', 'S')
# Moment already available ('2021-02-03 16:31:57.073142', 'B')
# Moment already available ('2021-02-03 16:31:57.073142', 'S')
# Moment already available ('2021-02-03 12:12:13.331147', 'B')
# Moment already available ('2021-02-03 12:12:13.331147', 'S')
# Moment already available ('2021-02-03 12:21:55.051689', 'B')
# Moment already available ('2021-02-03 12:21:55.051689', 'S')
# Moment already available ('2021-02-03 12:31:17.322091', 'B')
# Moment already available ('2021-02-03 12:31:17.322091', 'S')
# Moment already available ('2021-02-04 22:23:14.149688', 'B')
# Moment already available ('2021-02-04 22:23:14.149688', 'S')
# Moment already available ('2021-02-04 22:33:16.189629', 'B')
# Moment already available ('2021-02-04 22:33:16.189629', 'S')
# Moment already available ('2021-02-04 15:09:19.377150', 'B')
# Moment already available ('2021-02-04 15:09:19.377150', 'S')
# Moment already available ('2021-02-04 20:19:14.427853', 'B')
# Moment already available ('2021-02-04 20:19:14.427853', 'S')
# Moment already available ('2021-02-04 20:34:00.493274', 'B')
# Moment already available ('2021-02-04 20:34:00.493274', 'S')
# Moment already available ('2021-02-04 12:11:23.696761', 'B')
# Moment already available ('2021-02-04 12:11:23.696761', 'S')
# Moment already available ('2021-02-04 12:23:19.079482', 'B')
# Moment already available ('2021-02-04 12:23:19.079482', 'S')
# Moment already available ('2021-02-04 19:10:46.617476', 'B')
# Moment already available ('2021-02-04 19:10:46.617476', 'S')
# Moment already available ('2021-02-04 23:20:51.437683', 'B')
# Moment already available ('2021-02-04 23:20:51.437683', 'S')
# Moment already available ('2021-02-04 16:21:08.455238', 'B')
# Moment already available ('2021-02-04 16:21:08.455238', 'S')
# Moment already available ('2021-02-04 14:34:19.288622', 'B')
# Moment already available ('2021-02-04 14:34:19.288622', 'S')
# Moment already available ('2021-02-05 13:33:41.456034', 'B')
# Moment already available ('2021-02-05 13:33:41.456034', 'S')
# Moment already available ('2021-02-05 15:33:00.732570', 'B')
# Moment already available ('2021-02-05 15:33:00.732570', 'S')
# Moment already available ('2021-02-05 18:33:33.861377', 'B')
# Moment already available ('2021-02-05 18:33:33.861377', 'S')
# Moment already available ('2021-02-05 22:34:13.951808', 'B')
# Moment already available ('2021-02-05 22:34:13.951808', 'S')
# Moment already available ('2021-02-05 17:29:58.999052', 'B')
# Moment already available ('2021-02-05 17:29:58.999052', 'S')
# Moment already available ('2021-02-05 19:11:10.522200', 'B')
# Moment already available ('2021-02-05 19:11:10.522200', 'S')
# Moment already available ('2021-02-05 19:22:49.525826', 'B')
# Moment already available ('2021-02-05 19:22:49.525826', 'S')
# Moment already available ('2021-02-05 11:07:44.026535', 'B')
# Moment already available ('2021-02-05 11:07:44.026535', 'S')
# Moment already available ('2021-02-05 11:19:26.031516', 'B')
# Moment already available ('2021-02-05 11:19:26.031516', 'S')
# Moment already available ('2021-02-05 11:34:28.210411', 'B')
# Moment already available ('2021-02-05 11:34:28.210411', 'S')
# Moment already available ('2021-02-05 23:12:10.737970', 'B')
# Moment already available ('2021-02-05 23:12:10.737970', 'S')
# Moment already available ('2021-02-05 23:21:16.048320', 'B')
# Moment already available ('2021-02-05 23:21:16.048320', 'S')
# Moment already available ('2021-02-08 13:12:29.017672', 'B')
# Moment already available ('2021-02-08 13:12:29.017672', 'S')
# Moment already available ('2021-02-08 13:30:55.481157', 'B')
# Moment already available ('2021-02-08 13:30:55.481157', 'S')
# Moment already available ('2021-02-08 16:08:15.004811', 'B')
# Moment already available ('2021-02-08 16:08:15.004811', 'S')
# Moment already available ('2021-02-08 16:32:58.443346', 'B')
# Moment already available ('2021-02-08 16:32:58.443346', 'S')
# Moment already available ('2021-02-08 18:11:45.771519', 'B')
# Moment already available ('2021-02-08 18:11:45.771519', 'S')
# Moment already available ('2021-02-08 20:07:34.283660', 'B')
# Moment already available ('2021-02-08 20:07:34.283660', 'S')
# Moment already available ('2021-02-08 12:10:59.804660', 'B')
# Moment already available ('2021-02-08 12:10:59.804660', 'S')
# Moment already available ('2021-02-08 12:23:19.704000', 'B')
# Moment already available ('2021-02-08 12:23:19.704000', 'S')
# Moment already available ('2021-02-08 12:33:31.287529', 'B')
# Moment already available ('2021-02-08 12:33:31.287529', 'S')
# Moment already available ('2021-02-08 10:12:25.793292', 'B')
# Moment already available ('2021-02-08 10:12:25.793292', 'S')
# Moment already available ('2021-02-08 10:20:46.019463', 'B')
# Moment already available ('2021-02-08 10:20:46.019463', 'S')
# Moment already available ('2021-02-08 10:30:27.061179', 'B')
# Moment already available ('2021-02-08 10:30:27.061179', 'S')
# Moment already available ('2021-02-08 15:23:06.466362', 'B')
# Moment already available ('2021-02-08 15:23:06.466362', 'S')
# Moment already available ('2021-02-09 22:21:52.931132', 'B')
# Moment already available ('2021-02-09 22:21:52.931132', 'S')
# Moment already available ('2021-02-09 14:09:40.283666', 'B')
# Moment already available ('2021-02-09 14:09:40.283666', 'S')
# Moment already available ('2021-02-09 14:21:56.432235', 'B')
# Moment already available ('2021-02-09 14:21:56.432235', 'S')
# Moment already available ('2021-02-09 14:31:50.495520', 'B')
# Moment already available ('2021-02-09 14:31:50.495520', 'S')
# Moment already available ('2021-02-09 17:09:03.439594', 'B')
# Moment already available ('2021-02-09 17:09:03.439594', 'S')
# Moment already available ('2021-02-09 17:34:46.329894', 'B')
# Moment already available ('2021-02-09 17:34:46.329894', 'S')
# Moment already available ('2021-02-09 13:12:15.871256', 'B')
# Moment already available ('2021-02-09 13:12:15.871256', 'S')
# Moment already available ('2021-02-09 13:23:04.328036', 'B')
# Moment already available ('2021-02-09 13:23:04.328036', 'S')
# Moment already available ('2021-02-09 13:30:35.799796', 'B')
# Moment already available ('2021-02-09 13:30:35.799796', 'S')
# Moment already available ('2021-02-09 10:10:34.117507', 'B')
# Moment already available ('2021-02-09 10:10:34.117507', 'S')
# Moment already available ('2021-02-09 10:18:59.420136', 'B')
# Moment already available ('2021-02-09 10:18:59.420136', 'S')
# Moment already available ('2021-02-09 10:32:29.726559', 'B')
# Moment already available ('2021-02-09 10:32:29.726559', 'S')
# Moment already available ('2021-02-09 18:22:49.927749', 'B')
# Moment already available ('2021-02-09 18:22:49.927749', 'S')
# Moment already available ('2021-02-09 18:34:04.246837', 'B')
# Moment already available ('2021-02-09 18:34:04.246837', 'S')
# Moment already available ('2021-02-09 19:20:07.696114', 'B')
# Moment already available ('2021-02-09 19:20:07.696114', 'S')
# Moment already available ('2021-02-09 19:31:40.542220', 'B')
# Moment already available ('2021-02-09 19:31:40.542220', 'S')
# Moment already available ('2021-02-09 11:11:41.920546', 'B')
# Moment already available ('2021-02-09 11:11:41.920546', 'S')
# Moment already available ('2021-02-09 11:22:34.190712', 'B')
# Moment already available ('2021-02-09 11:22:34.190712', 'S')
# Moment already available ('2021-02-09 11:34:38.217077', 'B')
# Moment already available ('2021-02-09 11:34:38.217077', 'S')
# Moment already available ('2021-02-10 12:10:29.347997', 'B')
# Moment already available ('2021-02-10 12:10:29.347997', 'S')
# Moment already available ('2021-02-10 12:21:40.782339', 'B')
# Moment already available ('2021-02-10 12:21:40.782339', 'S')
# Moment already available ('2021-02-10 22:23:31.364043', 'B')
# Moment already available ('2021-02-10 22:23:31.364043', 'S')
# Moment already available ('2021-02-10 22:30:28.602456', 'B')
# Moment already available ('2021-02-10 22:30:28.602456', 'S')
# Moment already available ('2021-02-10 18:23:12.931798', 'B')
# Moment already available ('2021-02-10 18:23:12.931798', 'S')
# Moment already available ('2021-02-10 18:33:50.438915', 'B')
# Moment already available ('2021-02-10 18:33:50.438915', 'S')
# Moment already available ('2021-02-10 14:23:11.754499', 'B')
# Moment already available ('2021-02-10 14:23:11.754499', 'S')
# Moment already available ('2021-02-10 15:09:42.643356', 'B')
# Moment already available ('2021-02-10 15:09:42.643356', 'S')
# Moment already available ('2021-02-10 15:21:57.357524', 'B')
# Moment already available ('2021-02-10 15:21:57.357524', 'S')
# Moment already available ('2021-02-10 11:12:29.739454', 'B')
# Moment already available ('2021-02-10 11:12:29.739454', 'S')
# Moment already available ('2021-02-10 11:20:38.846861', 'B')
# Moment already available ('2021-02-10 11:20:38.846861', 'S')
# Moment already available ('2021-02-10 11:31:03.943278', 'B')
# Moment already available ('2021-02-10 11:31:03.943278', 'S')
# Moment already available ('2021-02-11 11:12:12.815969', 'B')
# Moment already available ('2021-02-11 11:12:12.815969', 'S')
# Moment already available ('2021-02-11 11:21:03.599843', 'B')
# Moment already available ('2021-02-11 11:21:03.599843', 'S')
# Moment already available ('2021-02-11 11:32:33.513709', 'B')
# Moment already available ('2021-02-11 11:32:33.513709', 'S')
# Moment already available ('2021-02-11 18:21:31.223876', 'B')
# Moment already available ('2021-02-11 18:21:31.223876', 'S')
# Moment already available ('2021-02-11 16:11:04.912957', 'B')
# Moment already available ('2021-02-11 16:11:04.912957', 'S')
# Moment already available ('2021-02-11 16:33:55.960364', 'B')
# Moment already available ('2021-02-11 16:33:55.960364', 'S')
# Moment already available ('2021-02-11 13:12:24.521029', 'B')
# Moment already available ('2021-02-11 13:12:24.521029', 'S')
# Moment already available ('2021-02-11 13:23:04.786160', 'B')
# Moment already available ('2021-02-11 13:23:04.786160', 'S')
# Moment already available ('2021-02-11 14:09:00.788202', 'B')
# Moment already available ('2021-02-11 14:09:00.788202', 'S')
# Moment already available ('2021-02-11 14:23:20.310026', 'B')
# Moment already available ('2021-02-11 14:23:20.310026', 'S')
# Moment already available ('2021-02-11 14:32:53.583343', 'B')
# Moment already available ('2021-02-11 14:32:53.583343', 'S')
# Moment already available ('2021-02-11 21:12:17.709460', 'B')
# Moment already available ('2021-02-11 21:12:17.709460', 'S')
# Moment already available ('2021-02-11 15:11:58.692898', 'B')
# Moment already available ('2021-02-11 15:11:58.692898', 'S')
# Moment already available ('2021-02-11 15:32:51.139219', 'B')
# Moment already available ('2021-02-11 15:32:51.139219', 'S')
# Moment already available ('2021-02-11 23:20:00.822128', 'B')
# Moment already available ('2021-02-11 23:20:00.822128', 'S')
# Moment already available ('2021-02-11 23:30:33.677657', 'B')
# Moment already available ('2021-02-11 23:30:33.677657', 'S')
# Moment already available ('2021-02-11 19:21:02.163438', 'B')
# Moment already available ('2021-02-11 19:21:02.163438', 'S')
# Moment already available ('2021-02-12 15:08:23.483710', 'B')
# Moment already available ('2021-02-12 15:08:23.483710', 'S')
# Moment already available ('2021-02-12 15:21:18.036147', 'B')
# Moment already available ('2021-02-12 15:21:18.036147', 'S')
# Moment already available ('2021-02-12 15:33:18.652089', 'B')
# Moment already available ('2021-02-12 15:33:18.652089', 'S')
# Moment already available ('2021-02-12 14:09:50.459876', 'B')
# Moment already available ('2021-02-12 14:09:50.459876', 'S')
# Moment already available ('2021-02-12 14:33:51.992353', 'B')
# Moment already available ('2021-02-12 14:33:51.992353', 'S')
# Moment already available ('2021-02-12 11:09:43.076499', 'B')
# Moment already available ('2021-02-12 11:09:43.076499', 'S')
# Moment already available ('2021-02-12 11:19:55.310683', 'B')
# Moment already available ('2021-02-12 11:19:55.310683', 'S')
# Moment already available ('2021-02-12 11:33:48.690515', 'B')
# Moment already available ('2021-02-12 11:33:48.690515', 'S')
# Moment already available ('2021-02-12 22:19:43.335920', 'B')
# Moment already available ('2021-02-12 22:19:43.335920', 'S')
# Moment already available ('2021-02-12 22:31:50.832895', 'B')
# Moment already available ('2021-02-12 22:31:50.832895', 'S')
# Moment already available ('2021-02-12 21:12:19.702564', 'B')
# Moment already available ('2021-02-12 21:12:19.702564', 'S')
# Moment already available ('2021-02-12 21:23:03.646253', 'B')
# Moment already available ('2021-02-12 21:23:03.646253', 'S')
# Moment already available ('2021-02-12 21:33:33.726574', 'B')
# Moment already available ('2021-02-12 21:33:33.726574', 'S')
# Moment already available ('2021-02-12 13:10:25.059572', 'B')
# Moment already available ('2021-02-12 13:10:25.059572', 'S')
# Moment already available ('2021-02-12 13:23:08.973138', 'B')
# Moment already available ('2021-02-12 13:23:08.973138', 'S')
# Moment already available ('2021-02-12 13:31:38.762725', 'B')
# Moment already available ('2021-02-12 13:31:38.762725', 'S')
# Moment already available ('2021-02-12 18:10:48.097115', 'B')
# Moment already available ('2021-02-12 18:10:48.097115', 'S')
# Moment already available ('2021-02-12 18:21:02.971057', 'B')
# Moment already available ('2021-02-12 18:21:02.971057', 'S')
# Moment already available ('2021-02-12 18:30:42.923474', 'B')
# Moment already available ('2021-02-12 18:30:42.923474', 'S')
# Moment already available ('2021-02-12 12:10:01.021847', 'B')
# Moment already available ('2021-02-12 12:10:01.021847', 'S')
# Moment already available ('2021-02-12 12:23:33.017593', 'B')
# Moment already available ('2021-02-12 12:23:33.017593', 'S')
# Moment already available ('2021-02-12 12:34:30.220625', 'B')
# Moment already available ('2021-02-12 12:34:30.220625', 'S')
# Moment already available ('2021-02-12 10:12:32.996157', 'B')
# Moment already available ('2021-02-12 10:12:32.996157', 'S')
# Moment already available ('2021-02-12 10:23:14.262360', 'B')
# Moment already available ('2021-02-12 10:23:14.262360', 'S')
# Moment already available ('2021-02-12 10:32:34.209027', 'B')
# Moment already available ('2021-02-12 10:32:34.209027', 'S')
# Moment already available ('2021-02-15 16:12:08.751120', 'B')
# Moment already available ('2021-02-15 16:12:08.751120', 'S')
# Moment already available ('2021-02-15 16:22:50.208281', 'B')
# Moment already available ('2021-02-15 16:22:50.208281', 'S')
# Moment already available ('2021-02-15 12:10:58.143791', 'B')
# Moment already available ('2021-02-15 12:10:58.143791', 'S')
# Moment already available ('2021-02-15 12:21:02.956140', 'B')
# Moment already available ('2021-02-15 12:21:02.956140', 'S')
# Moment already available ('2021-02-15 12:34:39.197893', 'B')
# Moment already available ('2021-02-15 12:34:39.197893', 'S')
# Moment already available ('2021-02-15 15:10:27.037252', 'B')
# Moment already available ('2021-02-15 15:10:27.037252', 'S')
# Moment already available ('2021-02-15 15:34:29.225673', 'B')
# Moment already available ('2021-02-15 15:34:29.225673', 'S')
# Moment already available ('2021-02-15 17:09:32.338785', 'B')
# Moment already available ('2021-02-15 17:09:32.338785', 'S')
# Moment already available ('2021-02-15 10:10:06.859547', 'B')
# Moment already available ('2021-02-15 10:10:06.859547', 'S')
# Moment already available ('2021-02-15 10:21:54.431415', 'B')
# Moment already available ('2021-02-15 10:21:54.431415', 'S')
# Moment already available ('2021-02-15 19:19:43.105799', 'B')
# Moment already available ('2021-02-15 19:19:43.105799', 'S')
# Moment already available ('2021-02-15 11:11:13.417511', 'B')
# Moment already available ('2021-02-15 11:11:13.417511', 'S')
# Moment already available ('2021-02-15 11:23:33.188499', 'B')
# Moment already available ('2021-02-15 11:23:33.188499', 'S')
# Moment already available ('2021-02-15 11:34:39.459171', 'B')
# Moment already available ('2021-02-15 11:34:39.459171', 'S')
# Moment already available ('2021-02-16 17:11:29.708920', 'B')
# Moment already available ('2021-02-16 17:11:29.708920', 'S')
# Moment already available ('2021-02-16 17:32:09.811033', 'B')
# Moment already available ('2021-02-16 17:32:09.811033', 'S')
# Moment already available ('2021-02-16 20:19:27.072729', 'B')
# Moment already available ('2021-02-16 20:19:27.072729', 'S')
# Moment already available ('2021-02-16 16:34:21.847728', 'B')
# Moment already available ('2021-02-16 16:34:21.847728', 'S')
# Moment already available ('2021-02-16 10:12:02.463552', 'B')
# Moment already available ('2021-02-16 10:12:02.463552', 'S')
# Moment already available ('2021-02-16 10:23:27.898227', 'B')
# Moment already available ('2021-02-16 10:23:27.898227', 'S')
# Moment already available ('2021-02-16 10:32:05.178834', 'B')
# Moment already available ('2021-02-16 10:32:05.178834', 'S')
# Moment already available ('2021-02-16 15:07:43.481010', 'B')
# Moment already available ('2021-02-16 15:07:43.481010', 'S')
# Moment already available ('2021-02-16 15:22:15.569751', 'B')
# Moment already available ('2021-02-16 15:22:15.569751', 'S')
# Moment already available ('2021-02-16 15:34:28.297583', 'B')
# Moment already available ('2021-02-16 15:34:28.297583', 'S')
# Moment already available ('2021-02-16 19:11:39.755309', 'B')
# Moment already available ('2021-02-16 19:11:39.755309', 'S')
# Moment already available ('2021-02-16 12:10:58.883772', 'B')
# Moment already available ('2021-02-16 12:10:58.883772', 'S')
# Moment already available ('2021-02-16 12:23:32.634040', 'B')
# Moment already available ('2021-02-16 12:23:32.634040', 'S')
# Moment already available ('2021-02-16 14:11:28.997547', 'B')
# Moment already available ('2021-02-16 14:11:28.997547', 'S')
# Moment already available ('2021-02-16 14:21:12.207689', 'B')
# Moment already available ('2021-02-16 14:21:12.207689', 'S')
# Moment already available ('2021-02-16 14:34:42.433405', 'B')
# Moment already available ('2021-02-16 14:34:42.433405', 'S')
# Moment already available ('2021-02-17 23:23:35.622524', 'B')
# Moment already available ('2021-02-17 23:23:35.622524', 'S')
# Moment already available ('2021-02-17 17:12:33.748878', 'B')
# Moment already available ('2021-02-17 17:12:33.748878', 'S')
# Moment already available ('2021-02-17 17:33:55.259252', 'B')
# Moment already available ('2021-02-17 17:33:55.259252', 'S')
# Moment already available ('2021-02-17 13:08:59.032737', 'B')
# Moment already available ('2021-02-17 13:08:59.032737', 'S')
# Moment already available ('2021-02-17 13:23:05.841112', 'B')
# Moment already available ('2021-02-17 13:23:05.841112', 'S')
# Moment already available ('2021-02-17 13:34:48.483260', 'B')
# Moment already available ('2021-02-17 13:34:48.483260', 'S')
# Moment already available ('2021-02-17 11:11:55.699986', 'B')
# Moment already available ('2021-02-17 11:11:55.699986', 'S')
# Moment already available ('2021-02-17 11:23:09.093717', 'B')
# Moment already available ('2021-02-17 11:23:09.093717', 'S')
# Moment already available ('2021-02-17 11:33:43.292488', 'B')
# Moment already available ('2021-02-17 11:33:43.292488', 'S')
# Moment already available ('2021-02-17 14:12:04.777755', 'B')
# Moment already available ('2021-02-17 14:12:04.777755', 'S')
# Moment already available ('2021-02-17 16:22:20.928441', 'B')
# Moment already available ('2021-02-17 16:22:20.928441', 'S')
# Moment already available ('2021-02-17 16:34:21.957211', 'B')
# Moment already available ('2021-02-17 16:34:21.957211', 'S')
# Moment already available ('2021-02-17 10:21:22.706213', 'B')
# Moment already available ('2021-02-17 10:21:22.706213', 'S')
# Moment already available ('2021-02-17 10:31:18.054899', 'B')
# Moment already available ('2021-02-17 10:31:18.054899', 'S')
# Moment already available ('2021-02-17 18:10:12.435466', 'B')
# Moment already available ('2021-02-17 18:10:12.435466', 'S')
# Moment already available ('2021-02-17 18:22:55.683910', 'B')
# Moment already available ('2021-02-17 18:22:55.683910', 'S')
# Moment already available ('2021-02-17 18:32:03.347731', 'B')
# Moment already available ('2021-02-17 18:32:03.347731', 'S')
# Moment already available ('2021-02-17 19:07:55.848928', 'B')
# Moment already available ('2021-02-17 19:07:55.848928', 'S')
# Moment already available ('2021-02-18 16:12:20.297922', 'B')
# Moment already available ('2021-02-18 16:12:20.297922', 'S')
# Moment already available ('2021-02-18 10:12:21.376110', 'B')
# Moment already available ('2021-02-18 10:12:21.376110', 'S')
# Moment already available ('2021-02-18 10:22:49.959367', 'B')
# Moment already available ('2021-02-18 10:22:49.959367', 'S')
# Moment already available ('2021-02-18 10:33:25.536306', 'B')
# Moment already available ('2021-02-18 10:33:25.536306', 'S')
# Moment already available ('2021-02-18 13:21:58.329869', 'B')
# Moment already available ('2021-02-18 13:21:58.329869', 'S')
# Moment already available ('2021-02-18 13:33:43.513027', 'B')
# Moment already available ('2021-02-18 13:33:43.513027', 'S')
# Moment already available ('2021-02-18 12:12:30.279544', 'B')
# Moment already available ('2021-02-18 12:12:30.279544', 'S')
# Moment already available ('2021-02-18 12:21:24.463454', 'B')
# Moment already available ('2021-02-18 12:21:24.463454', 'S')
# Moment already available ('2021-02-18 12:30:22.589689', 'B')
# Moment already available ('2021-02-18 12:30:22.589689', 'S')
# Moment already available ('2021-02-18 19:22:44.822327', 'B')
# Moment already available ('2021-02-18 19:22:44.822327', 'S')
# Moment already available ('2021-02-18 17:10:02.874750', 'B')
# Moment already available ('2021-02-18 17:10:02.874750', 'S')
# Moment already available ('2021-02-18 17:22:30.320591', 'B')
# Moment already available ('2021-02-18 17:22:30.320591', 'S')
# Moment already available ('2021-02-18 17:33:07.700196', 'B')
# Moment already available ('2021-02-18 17:33:07.700196', 'S')
# Moment already available ('2021-02-18 22:21:42.523512', 'B')
# Moment already available ('2021-02-18 22:21:42.523512', 'S')
# Moment already available ('2021-02-18 15:09:16.017410', 'B')
# Moment already available ('2021-02-18 15:09:16.017410', 'S')
# Moment already available ('2021-02-18 15:30:31.427706', 'B')
# Moment already available ('2021-02-18 15:30:31.427706', 'S')
# Moment already available ('2021-02-19 13:10:39.207253', 'B')
# Moment already available ('2021-02-19 13:10:39.207253', 'S')
# Moment already available ('2021-02-19 13:19:18.869391', 'B')
# Moment already available ('2021-02-19 13:19:18.869391', 'S')
# Moment already available ('2021-02-19 13:33:20.978034', 'B')
# Moment already available ('2021-02-19 13:33:20.978034', 'S')
# Moment already available ('2021-02-19 11:23:20.373008', 'B')
# Moment already available ('2021-02-19 11:23:20.373008', 'S')
# Moment already available ('2021-02-19 11:34:05.444691', 'B')
# Moment already available ('2021-02-19 11:34:05.444691', 'S')
# Moment already available ('2021-02-19 19:23:02.616986', 'B')
# Moment already available ('2021-02-19 19:23:02.616986', 'S')
# Moment already available ('2021-02-19 19:31:13.484347', 'B')
# Moment already available ('2021-02-19 19:31:13.484347', 'S')
# Moment already available ('2021-02-19 15:09:31.508652', 'B')
# Moment already available ('2021-02-19 15:09:31.508652', 'S')
# Moment already available ('2021-02-19 15:23:15.566494', 'B')
# Moment already available ('2021-02-19 15:23:15.566494', 'S')
# Moment already available ('2021-02-19 15:30:01.056083', 'B')
# Moment already available ('2021-02-19 15:30:01.056083', 'S')
# Moment already available ('2021-02-19 20:11:39.280393', 'B')
# Moment already available ('2021-02-19 20:11:39.280393', 'S')
# Moment already available ('2021-02-19 20:19:00.444883', 'B')
# Moment already available ('2021-02-19 20:19:00.444883', 'S')
# Moment already available ('2021-02-19 18:11:35.975900', 'B')
# Moment already available ('2021-02-19 18:11:35.975900', 'S')
# Moment already available ('2021-02-19 18:33:41.492096', 'B')
# Moment already available ('2021-02-19 18:33:41.492096', 'S')
# Moment already available ('2021-02-19 12:11:45.643129', 'B')
# Moment already available ('2021-02-19 12:11:45.643129', 'S')
# Moment already available ('2021-02-19 12:22:50.478327', 'B')
# Moment already available ('2021-02-19 12:22:50.478327', 'S')
# Moment already available ('2021-02-19 12:31:58.808590', 'B')
# Moment already available ('2021-02-19 12:31:58.808590', 'S')
# Moment already available ('2021-02-19 17:19:43.472652', 'B')
# Moment already available ('2021-02-19 17:19:43.472652', 'S')
# Moment already available ('2021-02-19 17:33:19.754134', 'B')
# Moment already available ('2021-02-19 17:33:19.754134', 'S')
# Moment already available ('2021-02-19 10:11:52.994753', 'B')
# Moment already available ('2021-02-19 10:11:52.994753', 'S')
# Moment already available ('2021-02-19 10:34:34.401171', 'B')
# Moment already available ('2021-02-19 10:34:34.401171', 'S')
# Moment already available ('2021-02-19 23:07:40.128749', 'B')
# Moment already available ('2021-02-19 23:07:40.128749', 'S')
# Moment already available ('2021-02-19 23:33:36.351180', 'B')
# Moment already available ('2021-02-19 23:33:36.351180', 'S')
# Moment already available ('2021-02-20 11:21:34.688830', 'B')
# Moment already available ('2021-02-20 11:21:34.688830', 'S')
# Moment already available ('2021-02-22 22:21:10.117810', 'B')
# Moment already available ('2021-02-22 22:21:10.117810', 'S')
# Moment already available ('2021-02-22 18:09:01.949108', 'B')
# Moment already available ('2021-02-22 18:09:01.949108', 'S')
# Moment already available ('2021-02-22 10:10:52.118924', 'B')
# Moment already available ('2021-02-22 10:10:52.118924', 'S')
# Moment already available ('2021-02-22 10:22:10.293890', 'B')
# Moment already available ('2021-02-22 10:22:10.293890', 'S')
# Moment already available ('2021-02-22 10:33:15.066275', 'B')
# Moment already available ('2021-02-22 10:33:15.066275', 'S')
# Moment already available ('2021-02-22 11:12:29.608075', 'B')
# Moment already available ('2021-02-22 11:12:29.608075', 'S')
# Moment already available ('2021-02-22 11:22:35.072697', 'B')
# Moment already available ('2021-02-22 11:22:35.072697', 'S')
# Moment already available ('2021-02-22 11:34:38.460581', 'B')
# Moment already available ('2021-02-22 11:34:38.460581', 'S')
# Moment already available ('2021-02-22 12:11:47.832282', 'B')
# Moment already available ('2021-02-22 12:11:47.832282', 'S')
# Moment already available ('2021-02-22 12:34:33.190675', 'B')
# Moment already available ('2021-02-22 12:34:33.190675', 'S')
# Moment already available ('2021-02-22 17:31:54.705559', 'B')
# Moment already available ('2021-02-22 17:31:54.705559', 'S')
# Moment already available ('2021-02-22 13:08:10.116129', 'B')
# Moment already available ('2021-02-22 13:08:10.116129', 'S')
# Moment already available ('2021-02-24 16:10:42.648138', 'B')
# Moment already available ('2021-02-24 16:10:42.648138', 'S')
# Moment already available ('2021-02-24 16:23:41.754480', 'B')
# Moment already available ('2021-02-24 16:23:41.754480', 'S')
# Moment already available ('2021-02-24 16:31:22.893801', 'B')
# Moment already available ('2021-02-24 16:31:22.893801', 'S')
# Moment already available ('2021-02-24 10:12:05.588200', 'B')
# Moment already available ('2021-02-24 10:12:05.588200', 'S')
# Moment already available ('2021-02-24 10:22:48.697594', 'B')
# Moment already available ('2021-02-24 10:22:48.697594', 'S')
# Moment already available ('2021-02-24 10:34:27.680868', 'B')
# Moment already available ('2021-02-24 10:34:27.680868', 'S')
# Moment already available ('2021-02-24 13:11:51.756915', 'B')
# Moment already available ('2021-02-24 13:11:51.756915', 'S')
# Moment already available ('2021-02-24 13:22:28.904713', 'B')
# Moment already available ('2021-02-24 13:22:28.904713', 'S')
# Moment already available ('2021-02-24 18:08:05.778504', 'B')
# Moment already available ('2021-02-24 18:08:05.778504', 'S')
# Moment already available ('2021-02-24 18:34:20.107034', 'B')
# Moment already available ('2021-02-24 18:34:20.107034', 'S')
# Moment already available ('2021-02-24 19:22:48.291149', 'B')
# Moment already available ('2021-02-24 19:22:48.291149', 'S')
# Moment already available ('2021-02-24 22:09:28.609150', 'B')
# Moment already available ('2021-02-24 22:09:28.609150', 'S')
# Moment already available ('2021-02-24 22:22:04.582803', 'B')
# Moment already available ('2021-02-24 22:22:04.582803', 'S')
# Moment already available ('2021-02-24 22:33:54.798298', 'B')
# Moment already available ('2021-02-24 22:33:54.798298', 'S')
# Moment already available ('2021-02-24 17:20:10.976763', 'B')
# Moment already available ('2021-02-24 17:20:10.976763', 'S')
# Moment already available ('2021-02-24 17:33:47.983699', 'B')
# Moment already available ('2021-02-24 17:33:47.983699', 'S')
# Moment already available ('2021-02-24 11:11:21.105466', 'B')
# Moment already available ('2021-02-24 11:11:21.105466', 'S')
# Moment already available ('2021-02-24 11:23:32.766051', 'B')
# Moment already available ('2021-02-24 11:23:32.766051', 'S')
# Moment already available ('2021-02-24 11:34:48.228402', 'B')
# Moment already available ('2021-02-24 11:34:48.228402', 'S')
# Moment already available ('2021-02-25 12:08:33.524255', 'B')
# Moment already available ('2021-02-25 12:08:33.524255', 'S')
# Moment already available ('2021-02-25 12:22:08.822602', 'B')
# Moment already available ('2021-02-25 12:22:08.822602', 'S')
# Moment already available ('2021-02-25 12:34:14.389721', 'B')
# Moment already available ('2021-02-25 12:34:14.389721', 'S')
# Moment already available ('2021-02-25 11:21:33.370427', 'B')
# Moment already available ('2021-02-25 11:21:33.370427', 'S')
# Moment already available ('2021-02-25 11:33:59.183589', 'B')
# Moment already available ('2021-02-25 11:33:59.183589', 'S')
# Moment already available ('2021-02-25 20:11:54.286250', 'B')
# Moment already available ('2021-02-25 20:11:54.286250', 'S')
# Moment already available ('2021-02-25 13:11:01.228632', 'B')
# Moment already available ('2021-02-25 13:11:01.228632', 'S')
# Moment already available ('2021-02-25 13:23:39.481168', 'B')
# Moment already available ('2021-02-25 13:23:39.481168', 'S')
# Moment already available ('2021-02-25 13:34:10.795939', 'B')
# Moment already available ('2021-02-25 13:34:10.795939', 'S')
# Moment already available ('2021-02-25 22:08:16.124961', 'B')
# Moment already available ('2021-02-25 22:08:16.124961', 'S')
# Moment already available ('2021-02-25 22:23:41.482785', 'B')
# Moment already available ('2021-02-25 22:23:41.482785', 'S')
# Moment already available ('2021-02-25 22:33:34.762497', 'B')
# Moment already available ('2021-02-25 22:33:34.762497', 'S')
# Moment already available ('2021-02-25 14:07:48.323778', 'B')
# Moment already available ('2021-02-25 14:07:48.323778', 'S')
# Moment already available ('2021-02-25 14:20:10.284212', 'B')
# Moment already available ('2021-02-25 14:20:10.284212', 'S')
# Moment already available ('2021-02-25 14:34:24.672841', 'B')
# Moment already available ('2021-02-25 14:34:24.672841', 'S')
# Moment already available ('2021-02-25 17:12:17.325558', 'B')
# Moment already available ('2021-02-25 17:12:17.325558', 'S')
# Moment already available ('2021-02-25 17:21:31.251863', 'B')
# Moment already available ('2021-02-25 17:21:31.251863', 'S')
# Moment already available ('2021-02-25 17:33:10.146644', 'B')
# Moment already available ('2021-02-25 17:33:10.146644', 'S')
# Moment already available ('2021-02-25 15:11:03.881546', 'B')
# Moment already available ('2021-02-25 15:11:03.881546', 'S')
# Moment already available ('2021-02-25 15:23:10.682640', 'B')
# Moment already available ('2021-02-25 15:23:10.682640', 'S')
# Moment already available ('2021-02-25 15:34:55.224477', 'B')
# Moment already available ('2021-02-25 15:34:55.224477', 'S')
# Moment already available ('2021-02-25 23:32:17.303518', 'B')
# Moment already available ('2021-02-25 23:32:17.303518', 'S')
# Moment already available ('2021-02-26 19:11:39.788313', 'B')
# Moment already available ('2021-02-26 19:11:39.788313', 'S')
# Moment already available ('2021-02-26 19:21:54.076239', 'B')
# Moment already available ('2021-02-26 19:21:54.076239', 'S')
# Moment already available ('2021-02-26 19:33:31.112580', 'B')
# Moment already available ('2021-02-26 19:33:31.112580', 'S')
# Moment already available ('2021-02-26 15:11:46.607552', 'B')
# Moment already available ('2021-02-26 15:11:46.607552', 'S')
# Moment already available ('2021-02-26 15:21:08.205324', 'B')
# Moment already available ('2021-02-26 15:21:08.205324', 'S')
# Moment already available ('2021-02-26 15:33:16.674963', 'B')
# Moment already available ('2021-02-26 15:33:16.674963', 'S')
# Moment already available ('2021-02-26 17:10:11.530087', 'B')
# Moment already available ('2021-02-26 17:10:11.530087', 'S')
# Moment already available ('2021-02-26 17:22:16.162896', 'B')
# Moment already available ('2021-02-26 17:22:16.162896', 'S')
# Moment already available ('2021-02-26 17:31:57.323664', 'B')
# Moment already available ('2021-02-26 17:31:57.323664', 'S')
# Moment already available ('2021-02-26 10:12:23.844848', 'B')
# Moment already available ('2021-02-26 10:12:23.844848', 'S')
# Moment already available ('2021-02-26 10:21:45.643403', 'B')
# Moment already available ('2021-02-26 10:21:45.643403', 'S')
# Moment already available ('2021-02-26 13:22:10.832680', 'B')
# Moment already available ('2021-02-26 13:22:10.832680', 'S')
# Moment already available ('2021-02-26 13:34:08.808725', 'B')
# Moment already available ('2021-02-26 13:34:08.808725', 'S')
# Moment already available ('2021-02-26 21:12:28.842031', 'B')
# Moment already available ('2021-02-26 21:12:28.842031', 'S')
# Moment already available ('2021-02-26 21:32:44.771437', 'B')
# Moment already available ('2021-02-26 21:32:44.771437', 'S')
# Moment already available ('2021-02-26 11:11:33.571778', 'B')
# Moment already available ('2021-02-26 11:11:33.571778', 'S')
# Moment already available ('2021-02-26 11:21:23.215349', 'B')
# Moment already available ('2021-02-26 11:21:23.215349', 'S')
# Moment already available ('2021-02-26 11:34:40.835638', 'B')
# Moment already available ('2021-02-26 11:34:40.835638', 'S')
# Moment already available ('2021-02-26 12:09:15.494217', 'B')
# Moment already available ('2021-02-26 12:09:15.494217', 'S')
# Moment already available ('2021-02-26 12:23:04.037324', 'B')
# Moment already available ('2021-02-26 12:23:04.037324', 'S')
# Moment already available ('2021-02-26 12:32:09.017612', 'B')
# Moment already available ('2021-02-26 12:32:09.017612', 'S')
# Moment already available ('2021-02-26 16:11:04.287255', 'B')
# Moment already available ('2021-02-26 16:11:04.287255', 'S')
# Moment already available ('2021-02-26 16:32:34.164535', 'B')
# Moment already available ('2021-02-26 16:32:34.164535', 'S')
# Moment already available ('2021-02-26 20:21:12.642028', 'B')
# Moment already available ('2021-02-26 20:21:12.642028', 'S')
# Moment already available ('2021-03-01 17:11:53.147741', 'B')
# Moment already available ('2021-03-01 17:11:53.147741', 'S')
# Moment already available ('2021-03-01 17:22:09.498252', 'B')
# Moment already available ('2021-03-01 17:22:09.498252', 'S')
# Moment already available ('2021-03-01 17:34:04.871371', 'B')
# Moment already available ('2021-03-01 17:34:04.871371', 'S')
# Moment already available ('2021-03-01 14:10:47.196142', 'B')
# Moment already available ('2021-03-01 14:10:47.196142', 'S')
# Moment already available ('2021-03-01 14:34:30.558657', 'B')
# Moment already available ('2021-03-01 14:34:30.558657', 'S')
# Moment already available ('2021-03-01 20:20:06.353439', 'B')
# Moment already available ('2021-03-01 20:20:06.353439', 'S')
# Moment already available ('2021-03-01 11:11:16.664515', 'B')
# Moment already available ('2021-03-01 11:11:16.664515', 'S')
# Moment already available ('2021-03-01 11:23:19.455886', 'B')
# Moment already available ('2021-03-01 11:23:19.455886', 'S')
# Moment already available ('2021-03-01 11:34:51.241293', 'B')
# Moment already available ('2021-03-01 11:34:51.241293', 'S')
# Moment already available ('2021-03-01 22:22:49.718463', 'B')
# Moment already available ('2021-03-01 22:22:49.718463', 'S')
# Moment already available ('2021-03-01 15:11:21.799221', 'B')
# Moment already available ('2021-03-01 15:11:21.799221', 'S')
# Moment already available ('2021-03-01 15:23:35.336518', 'B')
# Moment already available ('2021-03-01 15:23:35.336518', 'S')
# Moment already available ('2021-03-01 15:34:51.443832', 'B')
# Moment already available ('2021-03-01 15:34:51.443832', 'S')
# Moment already available ('2021-03-01 16:11:58.312957', 'B')
# Moment already available ('2021-03-01 16:11:58.312957', 'S')
# Moment already available ('2021-03-01 16:31:44.578018', 'B')
# Moment already available ('2021-03-01 16:31:44.578018', 'S')
# Moment already available ('2021-03-01 13:11:23.309188', 'B')
# Moment already available ('2021-03-01 13:11:23.309188', 'S')
# Moment already available ('2021-03-01 13:23:34.753967', 'B')
# Moment already available ('2021-03-01 13:23:34.753967', 'S')
# Moment already available ('2021-03-01 13:34:34.659705', 'B')
# Moment already available ('2021-03-01 13:34:34.659705', 'S')
# Moment already available ('2021-03-01 12:12:24.605707', 'B')
# Moment already available ('2021-03-01 12:12:24.605707', 'S')
# Moment already available ('2021-03-01 12:21:38.634645', 'B')
# Moment already available ('2021-03-01 12:21:38.634645', 'S')
# Moment already available ('2021-03-01 12:33:37.482878', 'B')
# Moment already available ('2021-03-01 12:33:37.482878', 'S')
# Moment already available ('2021-03-01 21:10:49.464279', 'B')
# Moment already available ('2021-03-01 21:10:49.464279', 'S')
# Moment already available ('2021-03-01 21:32:06.467351', 'B')
# Moment already available ('2021-03-01 21:32:06.467351', 'S')
# Moment already available ('2021-03-02 10:11:27.887815', 'B')
# Moment already available ('2021-03-02 10:11:27.887815', 'S')
# Moment already available ('2021-03-02 10:22:48.003226', 'B')
# Moment already available ('2021-03-02 10:22:48.003226', 'S')
# Moment already available ('2021-03-02 10:32:56.538861', 'B')
# Moment already available ('2021-03-02 10:32:56.538861', 'S')
# Moment already available ('2021-03-02 11:10:37.794066', 'B')
# Moment already available ('2021-03-02 11:10:37.794066', 'S')
# Moment already available ('2021-03-02 13:12:17.968739', 'B')
# Moment already available ('2021-03-02 13:12:17.968739', 'S')
# Moment already available ('2021-03-02 13:22:21.832188', 'B')
# Moment already available ('2021-03-02 13:22:21.832188', 'S')
# Moment already available ('2021-03-02 13:30:49.520598', 'B')
# Moment already available ('2021-03-02 13:30:49.520598', 'S')
# Moment already available ('2021-03-02 16:18:47.158471', 'B')
# Moment already available ('2021-03-02 16:18:47.158471', 'S')
# Moment already available ('2021-03-02 16:34:04.859815', 'B')
# Moment already available ('2021-03-02 16:34:04.859815', 'S')
# Moment already available ('2021-03-02 12:09:50.330461', 'B')
# Moment already available ('2021-03-02 12:09:50.330461', 'S')
# Moment already available ('2021-03-02 12:23:23.252890', 'B')
# Moment already available ('2021-03-02 12:23:23.252890', 'S')
# Moment already available ('2021-03-02 12:34:34.093881', 'B')
# Moment already available ('2021-03-02 12:34:34.093881', 'S')
# Moment already available ('2021-03-02 14:12:29.544228', 'B')
# Moment already available ('2021-03-02 14:12:29.544228', 'S')
# Moment already available ('2021-03-02 14:23:42.673999', 'B')
# Moment already available ('2021-03-02 14:23:42.673999', 'S')
# Moment already available ('2021-03-02 14:30:32.519204', 'B')
# Moment already available ('2021-03-02 14:30:32.519204', 'S')
# Moment already available ('2021-03-02 23:08:39.894096', 'B')
# Moment already available ('2021-03-02 23:08:39.894096', 'S')
# Moment already available ('2021-03-02 23:21:30.223778', 'B')
# Moment already available ('2021-03-02 23:21:30.223778', 'S')
# Moment already available ('2021-03-02 23:30:25.534811', 'B')
# Moment already available ('2021-03-02 23:30:25.534811', 'S')
# Moment already available ('2021-03-02 20:12:08.503546', 'B')
# Moment already available ('2021-03-02 20:12:08.503546', 'S')
# Moment already available ('2021-03-02 17:10:32.172946', 'B')
# Moment already available ('2021-03-02 17:10:32.172946', 'S')
# Moment already available ('2021-03-03 14:22:38.641585', 'B')
# Moment already available ('2021-03-03 14:22:38.641585', 'S')
# Moment already available ('2021-03-03 14:34:38.442508', 'B')
# Moment already available ('2021-03-03 14:34:38.442508', 'S')
# Moment already available ('2021-03-03 19:07:55.721487', 'B')
# Moment already available ('2021-03-03 19:07:55.721487', 'S')
# Moment already available ('2021-03-03 19:34:47.395677', 'B')
# Moment already available ('2021-03-03 19:34:47.395677', 'S')
# Moment already available ('2021-03-03 12:22:57.034015', 'B')
# Moment already available ('2021-03-03 12:22:57.034015', 'S')
# Moment already available ('2021-03-03 17:11:56.131290', 'B')
# Moment already available ('2021-03-03 17:11:56.131290', 'S')
# Moment already available ('2021-03-03 17:23:06.221687', 'B')
# Moment already available ('2021-03-03 17:23:06.221687', 'S')
# Moment already available ('2021-03-03 17:32:24.355822', 'B')
# Moment already available ('2021-03-03 17:32:24.355822', 'S')
# Moment already available ('2021-03-03 18:11:38.553671', 'B')
# Moment already available ('2021-03-03 18:11:38.553671', 'S')
# Moment already available ('2021-03-03 18:33:16.697579', 'B')
# Moment already available ('2021-03-03 18:33:16.697579', 'S')
# Moment already available ('2021-03-03 22:21:43.454843', 'B')
# Moment already available ('2021-03-03 22:21:43.454843', 'S')
# Moment already available ('2021-03-03 22:32:33.905465', 'B')
# Moment already available ('2021-03-03 22:32:33.905465', 'S')
# Moment already available ('2021-03-03 11:09:29.934634', 'B')
# Moment already available ('2021-03-03 11:09:29.934634', 'S')
# Moment already available ('2021-03-03 11:22:07.321731', 'B')
# Moment already available ('2021-03-03 11:22:07.321731', 'S')
# Moment already available ('2021-03-03 11:34:54.535817', 'B')
# Moment already available ('2021-03-03 11:34:54.535817', 'S')
# Moment already available ('2021-03-03 15:34:47.186982', 'B')
# Moment already available ('2021-03-03 15:34:47.186982', 'S')
# Moment already available ('2021-03-04 13:34:03.213576', 'B')
# Moment already available ('2021-03-04 13:34:03.213576', 'S')
# Moment already available ('2021-03-04 14:23:34.603963', 'B')
# Moment already available ('2021-03-04 14:23:34.603963', 'S')
# Moment already available ('2021-03-04 14:30:27.389310', 'B')
# Moment already available ('2021-03-04 14:30:27.389310', 'S')
# Moment already available ('2021-03-04 20:23:17.892408', 'B')
# Moment already available ('2021-03-04 20:23:17.892408', 'S')
# Moment already available ('2021-03-04 20:33:53.029444', 'B')
# Moment already available ('2021-03-04 20:33:53.029444', 'S')
# Moment already available ('2021-03-04 11:12:33.375225', 'B')
# Moment already available ('2021-03-04 11:12:33.375225', 'S')
# Moment already available ('2021-03-04 11:21:22.700440', 'B')
# Moment already available ('2021-03-04 11:21:22.700440', 'S')
# Moment already available ('2021-03-04 11:34:27.416441', 'B')
# Moment already available ('2021-03-04 11:34:27.416441', 'S')
# Moment already available ('2021-03-04 15:12:33.547846', 'B')
# Moment already available ('2021-03-04 15:12:33.547846', 'S')
# Moment already available ('2021-03-04 15:19:11.580647', 'B')
# Moment already available ('2021-03-04 15:19:11.580647', 'S')
# Moment already available ('2021-03-04 18:07:55.627421', 'B')
# Moment already available ('2021-03-04 18:07:55.627421', 'S')
# Moment already available ('2021-03-04 18:19:25.883138', 'B')
# Moment already available ('2021-03-04 18:19:25.883138', 'S')
# Moment already available ('2021-03-04 10:11:18.148742', 'B')
# Moment already available ('2021-03-04 10:11:18.148742', 'S')
# Moment already available ('2021-03-04 10:33:39.526685', 'B')
# Moment already available ('2021-03-04 10:33:39.526685', 'S')
# Moment already available ('2021-03-04 17:12:27.647272', 'B')
# Moment already available ('2021-03-04 17:12:27.647272', 'S')
# Moment already available ('2021-03-04 17:33:20.436700', 'B')
# Moment already available ('2021-03-04 17:33:20.436700', 'S')
# Moment already available ('2021-03-04 22:11:57.225921', 'B')
# Moment already available ('2021-03-04 22:11:57.225921', 'S')
# Moment already available ('2021-03-04 22:21:31.456856', 'B')
# Moment already available ('2021-03-04 22:21:31.456856', 'S')
# Moment already available ('2021-03-04 22:34:29.258022', 'B')
# Moment already available ('2021-03-04 22:34:29.258022', 'S')
# Moment already available ('2021-03-04 16:23:21.176351', 'B')
# Moment already available ('2021-03-04 16:23:21.176351', 'S')
# Moment already available ('2021-03-04 16:33:04.395618', 'B')
# Moment already available ('2021-03-04 16:33:04.395618', 'S')
# Moment already available ('2021-03-05 10:12:06.657491', 'B')
# Moment already available ('2021-03-05 10:12:06.657491', 'S')
# ...
# Moment already available ('2021-09-28 19:11:19.961997', 'B')
# Moment already available ('2021-09-28 19:11:19.961997', 'S')
# Moment already available ('2021-09-28 14:22:46.130146', 'B')
# Moment already available ('2021-09-28 14:22:46.130146', 'S')
# Moment already available ('2021-09-28 14:31:15.863406', 'B')
# Moment already available ('2021-09-28 14:31:15.863406', 'S')
# Moment already available ('2021-09-28 12:08:38.584330', 'B')
# Moment already available ('2021-09-28 12:08:38.584330', 'S')
# Moment already available ('2021-09-28 12:21:44.021092', 'B')
# Moment already available ('2021-09-28 12:21:44.021092', 'S')
# Moment already available ('2021-09-28 12:34:11.437576', 'B')
# Moment already available ('2021-09-28 12:34:11.437576', 'S')
# Moment already available ('2021-09-28 17:12:27.513465', 'B')
# Moment already available ('2021-09-28 17:12:27.513465', 'S')
# Moment already available ('2021-09-28 17:21:43.395344', 'B')
# Moment already available ('2021-09-28 17:21:43.395344', 'S')
# Moment already available ('2021-09-28 17:30:24.887067', 'B')
# Moment already available ('2021-09-28 17:30:24.887067', 'S')
# Moment already available ('2021-09-28 11:11:55.165361', 'B')
# Moment already available ('2021-09-28 11:11:55.165361', 'S')
# Moment already available ('2021-09-28 11:22:58.365074', 'B')
# Moment already available ('2021-09-28 11:22:58.365074', 'S')
# Moment already available ('2021-09-28 23:23:10.157802', 'B')
# Moment already available ('2021-09-28 23:23:10.157802', 'S')
# Moment already available ('2021-09-28 23:34:05.792009', 'B')
# Moment already available ('2021-09-28 23:34:05.792009', 'S')
# Moment already available ('2021-09-29 19:11:51.037016', 'B')
# Moment already available ('2021-09-29 19:11:51.037016', 'S')
# Moment already available ('2021-09-29 19:21:37.899142', 'B')
# Moment already available ('2021-09-29 19:21:37.899142', 'S')
# Moment already available ('2021-09-29 16:07:38.366745', 'B')
# Moment already available ('2021-09-29 16:07:38.366745', 'S')
# Moment already available ('2021-09-29 16:22:37.605282', 'B')
# Moment already available ('2021-09-29 16:22:37.605282', 'S')
# Moment already available ('2021-09-29 16:33:59.274019', 'B')
# Moment already available ('2021-09-29 16:33:59.274019', 'S')
# Moment already available ('2021-09-29 18:11:01.415727', 'B')
# Moment already available ('2021-09-29 18:11:01.415727', 'S')
# Moment already available ('2021-09-29 18:21:49.193982', 'B')
# Moment already available ('2021-09-29 18:21:49.193982', 'S')
# Moment already available ('2021-09-29 15:12:30.606008', 'B')
# Moment already available ('2021-09-29 15:12:30.606008', 'S')
# Moment already available ('2021-09-29 15:20:01.175539', 'B')
# Moment already available ('2021-09-29 15:20:01.175539', 'S')
# Moment already available ('2021-09-29 15:34:01.996527', 'B')
# Moment already available ('2021-09-29 15:34:01.996527', 'S')
# Moment already available ('2021-09-29 14:19:57.043250', 'B')
# Moment already available ('2021-09-29 14:19:57.043250', 'S')
# Moment already available ('2021-09-29 14:30:19.348360', 'B')
# Moment already available ('2021-09-29 14:30:19.348360', 'S')
# Moment already available ('2021-09-29 17:11:31.586085', 'B')
# Moment already available ('2021-09-29 17:11:31.586085', 'S')
# Moment already available ('2021-09-29 12:08:34.099295', 'B')
# Moment already available ('2021-09-29 12:08:34.099295', 'S')
# Moment already available ('2021-09-29 12:22:48.013732', 'B')
# Moment already available ('2021-09-29 12:22:48.013732', 'S')
# Moment already available ('2021-09-29 12:32:20.297246', 'B')
# Moment already available ('2021-09-29 12:32:20.297246', 'S')
# Moment already available ('2021-09-29 21:09:08.867589', 'B')
# Moment already available ('2021-09-29 21:09:08.867589', 'S')
# Moment already available ('2021-09-30 18:12:09.406097', 'B')
# Moment already available ('2021-09-30 18:12:09.406097', 'S')
# Moment already available ('2021-09-30 18:34:54.676050', 'B')
# Moment already available ('2021-09-30 18:34:54.676050', 'S')
# Moment already available ('2021-09-30 12:12:15.034739', 'B')
# Moment already available ('2021-09-30 12:12:15.034739', 'S')
# Moment already available ('2021-09-30 12:23:36.461834', 'B')
# Moment already available ('2021-09-30 12:23:36.461834', 'S')
# Moment already available ('2021-09-30 12:32:34.282676', 'B')
# Moment already available ('2021-09-30 12:32:34.282676', 'S')
# Moment already available ('2021-09-30 13:21:42.322816', 'B')
# Moment already available ('2021-09-30 13:21:42.322816', 'S')
# Moment already available ('2021-09-30 13:32:49.016717', 'B')
# Moment already available ('2021-09-30 13:32:49.016717', 'S')
# Moment already available ('2021-09-30 20:09:28.006496', 'B')
# Moment already available ('2021-09-30 20:09:28.006496', 'S')
# Moment already available ('2021-09-30 20:32:30.585416', 'B')
# Moment already available ('2021-09-30 20:32:30.585416', 'S')
# Moment already available ('2021-09-30 11:08:00.570398', 'B')
# Moment already available ('2021-09-30 11:08:00.570398', 'S')
# Moment already available ('2021-09-30 11:22:42.345436', 'B')
# Moment already available ('2021-09-30 11:22:42.345436', 'S')
# Moment already available ('2021-09-30 17:12:33.890044', 'B')
# Moment already available ('2021-09-30 17:12:33.890044', 'S')
# Moment already available ('2021-09-30 17:22:52.258829', 'B')
# Moment already available ('2021-09-30 17:22:52.258829', 'S')
# Moment already available ('2021-09-30 17:32:26.537043', 'B')
# Moment already available ('2021-09-30 17:32:26.537043', 'S')
# Moment already available ('2021-09-30 14:11:46.240916', 'B')
# Moment already available ('2021-09-30 14:11:46.240916', 'S')
# Moment already available ('2021-09-30 10:11:06.690525', 'B')
# Moment already available ('2021-09-30 10:11:06.690525', 'S')
# Moment already available ('2021-09-30 10:23:39.152997', 'B')
# Moment already available ('2021-09-30 10:23:39.152997', 'S')
# Moment already available ('2021-09-30 10:34:20.482797', 'B')
# Moment already available ('2021-09-30 10:34:20.482797', 'S')
# Moment already available ('2021-10-01 13:11:41.246968', 'B')
# Moment already available ('2021-10-01 13:11:41.246968', 'S')
# Moment already available ('2021-10-01 13:23:28.943770', 'B')
# Moment already available ('2021-10-01 13:23:28.943770', 'S')
# Moment already available ('2021-10-01 13:31:08.009808', 'B')
# Moment already available ('2021-10-01 13:31:08.009808', 'S')
# Moment already available ('2021-10-01 14:11:51.020114', 'B')
# Moment already available ('2021-10-01 14:11:51.020114', 'S')
# Moment already available ('2021-10-01 14:22:53.594526', 'B')
# Moment already available ('2021-10-01 14:22:53.594526', 'S')
# Moment already available ('2021-10-01 14:32:25.604694', 'B')
# Moment already available ('2021-10-01 14:32:25.604694', 'S')
# Moment already available ('2021-10-01 15:20:29.670047', 'B')
# Moment already available ('2021-10-01 15:20:29.670047', 'S')
# Moment already available ('2021-10-01 15:34:19.756117', 'B')
# Moment already available ('2021-10-01 15:34:19.756117', 'S')
# Moment already available ('2021-10-01 16:31:35.386610', 'B')
# Moment already available ('2021-10-01 16:31:35.386610', 'S')
# Moment already available ('2021-10-01 17:12:25.950217', 'B')
# Moment already available ('2021-10-01 17:12:25.950217', 'S')
# Moment already available ('2021-10-01 17:23:25.201331', 'B')
# Moment already available ('2021-10-01 17:23:25.201331', 'S')
# Moment already available ('2021-10-01 17:32:20.305930', 'B')
# Moment already available ('2021-10-01 17:32:20.305930', 'S')
# Moment already available ('2021-10-01 11:23:18.695522', 'B')
# Moment already available ('2021-10-01 11:23:18.695522', 'S')
# Moment already available ('2021-10-01 11:33:42.578356', 'B')
# Moment already available ('2021-10-01 11:33:42.578356', 'S')
# Moment already available ('2021-10-01 19:11:14.068962', 'B')
# Moment already available ('2021-10-01 19:11:14.068962', 'S')
# Moment already available ('2021-10-01 12:12:13.928349', 'B')
# Moment already available ('2021-10-01 12:12:13.928349', 'S')
# Moment already available ('2021-10-01 12:22:25.815739', 'B')
# Moment already available ('2021-10-01 12:22:25.815739', 'S')
# Moment already available ('2021-10-01 12:31:24.264934', 'B')
# Moment already available ('2021-10-01 12:31:24.264934', 'S')
# Moment already available ('2021-10-04 17:12:02.106899', 'B')
# Moment already available ('2021-10-04 17:12:02.106899', 'S')
# Moment already available ('2021-10-04 17:23:35.722528', 'B')
# Moment already available ('2021-10-04 17:23:35.722528', 'S')
# Moment already available ('2021-10-04 17:32:46.185480', 'B')
# Moment already available ('2021-10-04 17:32:46.185480', 'S')
# Moment already available ('2021-10-04 13:12:11.637592', 'B')
# Moment already available ('2021-10-04 13:12:11.637592', 'S')
# Moment already available ('2021-10-04 13:20:11.503200', 'B')
# Moment already available ('2021-10-04 13:20:11.503200', 'S')
# Moment already available ('2021-10-04 13:34:35.851354', 'B')
# Moment already available ('2021-10-04 13:34:35.851354', 'S')
# Moment already available ('2021-10-04 11:12:07.581110', 'B')
# Moment already available ('2021-10-04 11:12:07.581110', 'S')
# Moment already available ('2021-10-04 11:22:03.145519', 'B')
# Moment already available ('2021-10-04 11:22:03.145519', 'S')
# Moment already available ('2021-10-04 16:11:41.298519', 'B')
# Moment already available ('2021-10-04 16:11:41.298519', 'S')
# Moment already available ('2021-10-04 16:22:18.675034', 'B')
# Moment already available ('2021-10-04 16:22:18.675034', 'S')
# Moment already available ('2021-10-04 16:34:32.830261', 'B')
# Moment already available ('2021-10-04 16:34:32.830261', 'S')
# Moment already available ('2021-10-04 10:10:10.216158', 'B')
# Moment already available ('2021-10-04 10:10:10.216158', 'S')
# Moment already available ('2021-10-04 10:23:25.978644', 'B')
# Moment already available ('2021-10-04 10:23:25.978644', 'S')
# Moment already available ('2021-10-04 10:34:07.793096', 'B')
# Moment already available ('2021-10-04 10:34:07.793096', 'S')
# Moment already available ('2021-10-04 20:10:38.074789', 'B')
# Moment already available ('2021-10-04 20:10:38.074789', 'S')
# Moment already available ('2021-10-04 12:11:15.110536', 'B')
# Moment already available ('2021-10-04 12:11:15.110536', 'S')
# Moment already available ('2021-10-04 12:18:46.240271', 'B')
# Moment already available ('2021-10-04 12:18:46.240271', 'S')
# Moment already available ('2021-10-04 12:34:30.447863', 'B')
# Moment already available ('2021-10-04 12:34:30.447863', 'S')
# Moment already available ('2021-10-04 23:30:11.327770', 'B')
# Moment already available ('2021-10-04 23:30:11.327770', 'S')
# Moment already available ('2021-10-04 19:08:02.492164', 'B')
# Moment already available ('2021-10-04 19:08:02.492164', 'S')
# Moment already available ('2021-10-05 17:11:36.459400', 'B')
# Moment already available ('2021-10-05 17:11:36.459400', 'S')
# Moment already available ('2021-10-05 17:21:32.271286', 'B')
# Moment already available ('2021-10-05 17:21:32.271286', 'S')
# Moment already available ('2021-10-05 17:32:02.973211', 'B')
# Moment already available ('2021-10-05 17:32:02.973211', 'S')
# Moment already available ('2021-10-05 18:11:23.744493', 'B')
# Moment already available ('2021-10-05 18:11:23.744493', 'S')
# Moment already available ('2021-10-05 18:34:32.742440', 'B')
# Moment already available ('2021-10-05 18:34:32.742440', 'S')
# Moment already available ('2021-10-05 14:11:45.975550', 'B')
# Moment already available ('2021-10-05 14:11:45.975550', 'S')
# Moment already available ('2021-10-05 14:21:55.678531', 'B')
# Moment already available ('2021-10-05 14:21:55.678531', 'S')
# Moment already available ('2021-10-05 14:31:44.596418', 'B')
# Moment already available ('2021-10-05 14:31:44.596418', 'S')
# Moment already available ('2021-10-05 13:12:30.185190', 'B')
# Moment already available ('2021-10-05 13:12:30.185190', 'S')
# Moment already available ('2021-10-05 13:20:10.150098', 'B')
# Moment already available ('2021-10-05 13:20:10.150098', 'S')
# Moment already available ('2021-10-05 13:32:24.471945', 'B')
# Moment already available ('2021-10-05 13:32:24.471945', 'S')
# Moment already available ('2021-10-05 11:10:04.392347', 'B')
# Moment already available ('2021-10-05 11:10:04.392347', 'S')
# Moment already available ('2021-10-05 11:19:25.132498', 'B')
# Moment already available ('2021-10-05 11:19:25.132498', 'S')
# Moment already available ('2021-10-05 11:33:56.758242', 'B')
# Moment already available ('2021-10-05 11:33:56.758242', 'S')
# Moment already available ('2021-10-05 10:11:32.950335', 'B')
# Moment already available ('2021-10-05 10:11:32.950335', 'S')
# Moment already available ('2021-10-05 10:21:00.949414', 'B')
# Moment already available ('2021-10-05 10:21:00.949414', 'S')
# Moment already available ('2021-10-05 10:32:28.273113', 'B')
# Moment already available ('2021-10-05 10:32:28.273113', 'S')
# Moment already available ('2021-10-05 12:11:16.811240', 'B')
# Moment already available ('2021-10-05 12:11:16.811240', 'S')
# Moment already available ('2021-10-05 12:23:18.441034', 'B')
# Moment already available ('2021-10-05 12:23:18.441034', 'S')
# Moment already available ('2021-10-05 12:34:06.655953', 'B')
# Moment already available ('2021-10-05 12:34:06.655953', 'S')
# Moment already available ('2021-10-05 15:11:41.056651', 'B')
# Moment already available ('2021-10-05 15:11:41.056651', 'S')
# Moment already available ('2021-10-05 15:22:08.086853', 'B')
# Moment already available ('2021-10-05 15:22:08.086853', 'S')
# Moment already available ('2021-10-05 15:31:41.916972', 'B')
# Moment already available ('2021-10-05 15:31:41.916972', 'S')
# Moment already available ('2021-10-06 10:11:51.343179', 'B')
# Moment already available ('2021-10-06 10:11:51.343179', 'S')
# Moment already available ('2021-10-06 10:20:53.000635', 'B')
# Moment already available ('2021-10-06 10:20:53.000635', 'S')
# Moment already available ('2021-10-06 10:31:20.592102', 'B')
# Moment already available ('2021-10-06 10:31:20.592102', 'S')
# Moment already available ('2021-10-06 18:20:37.766656', 'B')
# Moment already available ('2021-10-06 18:20:37.766656', 'S')
# Moment already available ('2021-10-06 11:08:01.737038', 'B')
# Moment already available ('2021-10-06 11:08:01.737038', 'S')
# Moment already available ('2021-10-06 11:22:58.991205', 'B')
# Moment already available ('2021-10-06 11:22:58.991205', 'S')
# Moment already available ('2021-10-06 11:33:59.690918', 'B')
# Moment already available ('2021-10-06 11:33:59.690918', 'S')
# Moment already available ('2021-10-06 17:12:27.014381', 'B')
# Moment already available ('2021-10-06 17:12:27.014381', 'S')
# Moment already available ('2021-10-06 17:22:51.584897', 'B')
# Moment already available ('2021-10-06 17:22:51.584897', 'S')
# Moment already available ('2021-10-06 17:31:59.246569', 'B')
# Moment already available ('2021-10-06 17:31:59.246569', 'S')
# Moment already available ('2021-10-06 13:09:37.144599', 'B')
# Moment already available ('2021-10-06 13:09:37.144599', 'S')
# Moment already available ('2021-10-06 13:23:34.159810', 'B')
# Moment already available ('2021-10-06 13:23:34.159810', 'S')
# Moment already available ('2021-10-06 13:32:36.735909', 'B')
# Moment already available ('2021-10-06 13:32:36.735909', 'S')
# Moment already available ('2021-10-06 12:12:32.064280', 'B')
# Moment already available ('2021-10-06 12:12:32.064280', 'S')
# Moment already available ('2021-10-06 12:21:28.091861', 'B')
# Moment already available ('2021-10-06 12:21:28.091861', 'S')
# Moment already available ('2021-10-06 12:31:54.951635', 'B')
# Moment already available ('2021-10-06 12:31:54.951635', 'S')
# Moment already available ('2021-10-06 16:11:45.281590', 'B')
# Moment already available ('2021-10-06 16:11:45.281590', 'S')
# Moment already available ('2021-10-06 16:22:34.587892', 'B')
# Moment already available ('2021-10-06 16:22:34.587892', 'S')
# Moment already available ('2021-10-06 16:32:02.367660', 'B')
# Moment already available ('2021-10-06 16:32:02.367660', 'S')
# Moment already available ('2021-10-06 15:11:23.178082', 'B')
# Moment already available ('2021-10-06 15:11:23.178082', 'S')
# Moment already available ('2021-10-06 15:22:44.063087', 'B')
# Moment already available ('2021-10-06 15:22:44.063087', 'S')
# Moment already available ('2021-10-06 15:34:35.640399', 'B')
# Moment already available ('2021-10-06 15:34:35.640399', 'S')

# %%
sign_sql.commit()

# %%
cur.close()
sign_sql.close()

# %% [markdown]
# # Temporary

# %% [markdown]
# Checking *searchsorted* function:

# %%
ser = pd.Series([1,2,2,2,3,3,4])

# %%
i1 = ser.searchsorted(4-2, side='left')
i2 = ser.searchsorted(4, side='right')
i1, i2

# %%
ser.iloc[i1:i2]

# %% [markdown]
# Checking calculations for '2021-03-04 22:34:56.123456'

# %%
moment = pd._libs.tslibs.timestamps.Timestamp('2021-03-04 22:34:56.123456')

moment.strftime('LOB_%m%d.feather')

res = cache.get_lob(moment)

#result = make_hedge(res, moment, size = 10000, side='B')
result = calc_hedge_signature(cache, moment, hedge_params_df)
print(result)

# %%
tb = get_trades_before(moment)

# %%
#tb = tb.iloc[0:1, :]
tb

# %% [markdown]
# (start zone №2 - Timestamp('2021-03-04 22:34:28.950866'),
#
#  start zone №3 - Timestamp('2021-03-04 22:34:29.258022'))

# %%
moment = pd._libs.tslibs.timestamps.Timestamp('2021-03-04 22:34:56.123456')

# %%
ms = build_multitrades_signature(tb)

# %%
ms

# %%
get_zone_times(moment, side='B', skip_empty_trades=True)

# %%
res[res.Time >= moment][['Time', 'ASK_PRICE1']].plot(x='Time', y='ASK_PRICE1')

# %%
cache.get_lob(pd._libs.tslibs.timestamps.Timestamp('2021-10-08 18:34:56.123456')).to_csv('20211008.csv', sep=';')

# %%
c = cache.get_lob(moment)

# %%
c

# %%
d

# %%
# %%timeit
d['Time'].searchsorted(moment, side='right')

# %%
# %%timeit
d['Time'] >= moment
