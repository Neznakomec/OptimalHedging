# %%
import pandas as pd
import numpy as np
import sqlite3
import pickle
import gc
from IPython.display import clear_output
from collections import defaultdict

from functools import lru_cache

def sum_2_tuples(a, b):
    return tuple(map(sum, zip(a, b)))

# %% [markdown]
# Experiment parameters:

# %%
TRADES_DIR = '../TRADES/USD_TOM_trades_Micex_02_10.feather'
LOB_DIR = '../Data_lob/'

RANDOM_MOMENTS_FILE = '../0_CommonFiles/random_moments_aligned_to_1000_2000.pkl'
SIGNATURE_FILE = './signature.db3'

TRADE_SIZE_MIN_INCLUSIVE = 100
TRADE_SIZE_MAX_EXCLUSIVE = 2000

# %%
# Signature hedger
volume = 10_000 # in contracts

look_back_time = np.timedelta64(30, 's')

hedge_params_df = pd.DataFrame({
    'zone_number': [1, 2, 3],
    'distance': [1, 5, 10],
    'proportion': [0.3, 0.2, 0.1]
})

# %%
with open(RANDOM_MOMENTS_FILE, 'rb') as file:
    moments = pickle.load(file)

# %%
len(moments)
# Out:
# 2712

# %% [markdown]
# # 1. Select big trades

# %%
trades = pd.read_feather(TRADES_DIR)

# %%
trade_temp = trades.groupby(['Time', 'AGGRESSOR_SIDE'], as_index=False).sum()

# %%
volume_weighted_trade_price = trade_temp['TRADE_VALUE'] / trade_temp['SIZE'] / 1000.0

# %%
trade_temp['PRICE'] = volume_weighted_trade_price
# round to 0.01 of cent
trades['PRICE'] = trades['PRICE'].round(4)

# %%
trades = trade_temp

# %%
del trade_temp

# %%
#look only on big trades
trades = trades[(trades.SIZE >= TRADE_SIZE_MIN_INCLUSIVE) & (trades.SIZE < TRADE_SIZE_MAX_EXCLUSIVE)]

# %% [markdown]
# # 2. Build signature

# %%
signature_table = {
    'B': {
        (100, 499):   [0.0024905292322913285, 0.0026433182635482626, 0.002697568954515778, 0.002754871518810317, 0.0027752543082661374, 0.0028078903944222097, 0.0028371652741295862, 0.002847808719280013, 0.0028629920749483452, 0.0028644201398436335, 0.002902226078334742, 0.0029074442675728735, 0.002909906263110637, 0.002920145213701039, 0.0029235891185313977, 0.0029301488175850834, 0.0029372444769760727, 0.0029551045002256904, 0.002967188583503694, 0.0029792892963725706, 0.003030206853470199, 0.0030455028641086295, 0.0030361961146199213, 0.003037642986828899, 0.003047899841558298, 0.0030454963201911197, 0.0030526111305911024, 0.003057226325988928, 0.0030565060371562664, 0.00304376181684737],
        (500, 999):   [0.0026910899881976646, 0.002876574048739949, 0.002954233358535151, 0.003004949016366884, 0.003051637010818458, 0.003155480831982127, 0.0032022998510619623, 0.0032067194415670575, 0.0032198526432204995, 0.0032461271190022552, 0.003316403526027055, 0.003348364191854261, 0.003382860725006834, 0.0033982864133026806, 0.003416631622502073, 0.0034439206651035196, 0.0034502304663365426, 0.0034699038516893947, 0.0034927645055142713, 0.0035066473844458652, 0.003557687851464374, 0.0035595092792224665, 0.0035653776916127, 0.0035530782397924818, 0.0035613312440704622, 0.0035661420643975034, 0.0035718473977402877, 0.0035835479654684537, 0.00360718410967474, 0.0036128712728256715],
        (1000, 1999): [0.004612341943448629, 0.00470303210971194, 0.004739355350991369, 0.004756822374477201, 0.004770824837943304, 0.004812400062769874, 0.0048387798928851145, 0.004828780297409278, 0.0048642111992043355, 0.0048948626351468065, 0.004910218723984043, 0.004887823304729127, 0.004932528527765032, 0.004911338680908534, 0.004911278319943477, 0.004880698744659351, 0.004923283029468591, 0.004910424956089112, 0.004932294400206548, 0.004955211724933123, 0.004963611473046904, 0.005004210988770786, 0.005002578327983672, 0.005010618520081839, 0.0050076751191620965, 0.005044662839871767, 0.005075435694415131, 0.005073996103970367, 0.00508851019301986, 0.005083605829427722],
        (2000, 2999): [0.007666860013730193, 0.007643789023029769, 0.007652402066997683, 0.007613438051744633, 0.007614776792131339, 0.007502060470679352, 0.0075052798384596265, 0.007552209078378696, 0.007517176678966911, 0.007531715385564781, 0.007483064873911523, 0.007428261624852005, 0.007469441111481189, 0.007374616830424646, 0.0073684494057514455, 0.007305188287727694, 0.007232535700494532, 0.007274966262455883, 0.007390991475109071, 0.007427080430026108, 0.007431972843167495, 0.007426670597037147, 0.0073594906840288256, 0.00732305074441914, 0.007278815445096429, 0.007283750842030177, 0.007318336045351533, 0.007320043061559275, 0.007378172975640467, 0.007426300513799741],
        (3000, 3999): [0.009674008146040854, 0.009594498750866546, 0.009523753635455986, 0.009415641260702419, 0.009247837921464483, 0.00933503498220464, 0.009277199524990488, 0.009292350809572029, 0.009209022491318938, 0.009075989417298902, 0.009069096460127404, 0.008942232763600304, 0.009036936492981215, 0.009030853634262365, 0.009053667229322226, 0.009102777991050979, 0.009074072798063661, 0.00918350715436552, 0.0091641956874766, 0.00915439691789643, 0.00905721982629974, 0.009179315898859751, 0.009239740959752309, 0.009123399560758687, 0.009069593964616589, 0.008900625072984975, 0.008930201349958393, 0.008894070702762092, 0.009053905993548605, 0.008901185965190536],
        (4000, 4999): [0.011019889178636652, 0.011441198417186441, 0.011105431809768135, 0.011148529862105707, 0.011417548194302468, 0.011361981369996148, 0.01132618883567955, 0.011368819335707462, 0.011563397010111769, 0.011873061573159035, 0.0117197120970133, 0.01185161970097324, 0.011850805141290345, 0.01188601861527688, 0.0117790126443318, 0.011510710136511828, 0.011644152465413704, 0.011700125096293482, 0.011649358483612466, 0.011687462865742921, 0.011916583861082805, 0.011878289032676563, 0.01207941101879102, 0.012175605618630151, 0.012251549957490634, 0.01243124102886145, 0.012545704816970833, 0.012537714755208915, 0.012456087269594924, 0.012601588499248887],
        (5000, 5999): [0.009752595144464879, 0.009710915814622032, 0.009442979565791883, 0.009568342484458967, 0.009600821152447949, 0.00990578351907795, 0.009932260287593569, 0.009837965853948472, 0.00966540179856852, 0.009673962782141984, 0.009626877350233123, 0.009891261370888119, 0.010099024930627006, 0.01040851357086885, 0.010349333254191075, 0.010325257097068661, 0.01007730186831571, 0.01013435307997328, 0.010072955006161233, 0.010112540519686386, 0.010590693249442219, 0.01102417343108075, 0.011126782049952606, 0.01094982892843211, 0.010941644412129534, 0.011057090625790612, 0.011330102764629818, 0.011472762239011168, 0.011149269176548692, 0.01131296380607968],
        # ??? copy results for 5000-5999
        (6000, 1000000): [0.009752595144464879, 0.009710915814622032, 0.009442979565791883, 0.009568342484458967, 0.009600821152447949, 0.00990578351907795, 0.009932260287593569, 0.009837965853948472, 0.00966540179856852, 0.009673962782141984, 0.009626877350233123, 0.009891261370888119, 0.010099024930627006, 0.01040851357086885, 0.010349333254191075, 0.010325257097068661, 0.01007730186831571, 0.01013435307997328, 0.010072955006161233, 0.010112540519686386, 0.010590693249442219, 0.01102417343108075, 0.011126782049952606, 0.01094982892843211, 0.010941644412129534, 0.011057090625790612, 0.011330102764629818, 0.011472762239011168, 0.011149269176548692, 0.01131296380607968]
    },
    'S': {
        (100, 499):   [-0.002691961920942539, -0.0028218211718799174, -0.0028526589224838624, -0.0028580376926901057, -0.0028554915302185426, -0.0028715145253223814, -0.002892245132825392, -0.002917789041322858, -0.0029401823740718186, -0.0029468314074382472, -0.002966728525845394, -0.002982267277371796, -0.0029956516900289634, -0.0030053244866775257, -0.003014695901351538, -0.0030689010638763146, -0.0030739605354541673, -0.0030778089280789575, -0.003067598021875995, -0.0030704625041084, -0.003097924784737163, -0.0031019103469523404, -0.0031078246667001807, -0.0031344306091877928, -0.0031704390863474194, -0.0031862293510007984, -0.0031799665756465662, -0.0031765049864934634, -0.0031675934803442165, -0.0031961782294462975],
        (500, 999):   [-0.003008004466562672, -0.0031912751646871232, -0.0032467112890713526, -0.0032607366979502087, -0.0032648957081756556, -0.0032709954302336188, -0.00327360221832405, -0.0032897902474548677, -0.003308227730510537, -0.0033210146283061018, -0.003387044834705139, -0.003378095054457927, -0.0033538402745523542, -0.003355872942904236, -0.0033635644305300394, -0.003405175290050012, -0.003403924048792436, -0.0034102931548327, -0.0034047582602718396, -0.0033956189805064733, -0.0034858723031213268, -0.003465391695813379, -0.0034771176678052847, -0.00347568541315807, -0.0034998747813142833, -0.003529806317990441, -0.003506756427493522, -0.0034893681334655694, -0.0034902468507876276, -0.003508570475398435],
        (1000, 1999): [-0.005193527548200116, -0.0053838014627723444, -0.005402806578284014, -0.00543410081791218, -0.005412053312792029, -0.005472204404052999, -0.0054955736618325065, -0.005525343264595411, -0.005548110821957607, -0.005569054210315334, -0.005567431960921996, -0.005554403572277654, -0.005574627243539157, -0.0055716513554180305, -0.005573081132148346, -0.00558488020683325, -0.005629225883774346, -0.00566259193964533, -0.005622225625124084, -0.005608585487945004, -0.005625586022881097, -0.00564591369330999, -0.0056556044406593465, -0.0056854235969587, -0.005713757978951893, -0.005767603214608918, -0.005737164047361523, -0.005750507698046928, -0.005750483826174665, -0.005789134591693843],
        (2000, 2999): [-0.008772532023005432, -0.008736440237200447, -0.00864071731179626, -0.008544224583353096, -0.008405019827083185, -0.00842515509726803, -0.008430296925373905, -0.008388579154313961, -0.008475364452445133, -0.008514497085523693, -0.008438669567902289, -0.00845897993666488, -0.008502637468935552, -0.008537800517944014, -0.008599350476616795, -0.008595145849275823, -0.008548945261920009, -0.008548854374433073, -0.00856299259324292, -0.008578076602230776, -0.00860636546575176, -0.008546389272189526, -0.008434613305679736, -0.008461867077007376, -0.008513358115444467, -0.00851437134906376, -0.008506239865189079, -0.008559544883079565, -0.008537952615015552, -0.008550979625147002],
        (3000, 3999): [-0.011650249871759721, -0.011652507980316522, -0.011428646460492638, -0.011296664818182872, -0.011108769959144116, -0.010753379840007862, -0.010904103664097662, -0.010850310322040264, -0.010937717759928717, -0.011050993124673659, -0.010912228212921427, -0.011021726452862606, -0.011204422983069303, -0.011344730432164172, -0.011289843640146834, -0.011298736762360055, -0.011488414631182322, -0.01138611127223616, -0.0113674158517282, -0.011492847772814367, -0.011416581505829937, -0.011391728273509281, -0.011444262948521505, -0.01137037579692953, -0.011301540836656656, -0.011478391220936683, -0.01160197606041419, -0.011795934700036221, -0.011818350553284658, -0.011633203311841384],
        (4000, 4999): [-0.01114950631995241, -0.011162250593862581, -0.011277315685737942, -0.011209797128188783, -0.011291138714941919, -0.01130973134553277, -0.011351357282652547, -0.01177774409391618, -0.011679075618075754, -0.011799609730924856, -0.011860618116177024, -0.011917534319117894, -0.011961431612554935, -0.011983307015411214, -0.011982966390406156, -0.012080630394631866, -0.01200226885101033, -0.011999803941175459, -0.011898603325597674, -0.012018945611891872, -0.012245730524373012, -0.012279839944683716, -0.012227665359045589, -0.012035700438750357, -0.011993569730108572, -0.01203636668121768, -0.012261569331689435, -0.012357793037477716, -0.012332823490384233, -0.012573643228148244],
        (5000, 5999): [-0.010886281841212774, -0.010909766916686381, -0.01084644532848205, -0.010833785438672647, -0.01090003835236758, -0.010924942169616725, -0.010740406167922462, -0.010668919209943352, -0.01079079193381028, -0.010737813976872946, -0.010938418645686548, -0.010975720465114053, -0.010862777731241006, -0.010468382338453026, -0.01049630362309003, -0.010400533002998109, -0.010530070150458842, -0.01048533193953031, -0.010392612827167066, -0.010397852353878892, -0.010575881143408163, -0.01078093641122272, -0.010823641380151126, -0.011011893532463452, -0.011201870383060286, -0.011250730937168022, -0.011125539631192187, -0.01093584323456253, -0.010944043691882706, -0.011085875722578327],
#         # ??? copy results for 5000-5999
         (6000, 1000000): [-0.010886281841212774, -0.010909766916686381, -0.01084644532848205, -0.010833785438672647, -0.01090003835236758, -0.010924942169616725, -0.010740406167922462, -0.010668919209943352, -0.01079079193381028, -0.010737813976872946, -0.010938418645686548, -0.010975720465114053, -0.010862777731241006, -0.010468382338453026, -0.01049630362309003, -0.010400533002998109, -0.010530070150458842, -0.01048533193953031, -0.010392612827167066, -0.010397852353878892, -0.010575881143408163, -0.01078093641122272, -0.010823641380151126, -0.011011893532463452, -0.011201870383060286, -0.011250730937168022, -0.011125539631192187, -0.01093584323456253, -0.010944043691882706, -0.011085875722578327]
    }
}


'''
Convert signature table
into signature table with diffs 
delta(t) = signature(t+1) - signature(t)
'''
def build_delta_signature(signature_table):
    output = {}
    for side in signature_table:
        if side not in output:
            output[side] = {}
        
        for size, array in signature_table[side].items():
            # for 1..N we store only delta - change from previous moment
            delta_signature = np.array(array[1:]) - np.array(array[:-1])
            
            '''
            for initial time T0 we store array[0],
            price jump before deal and after deal
            '''
            delta_signature = np.insert(delta_signature, obj=0, values=array[0]) 
            
            output[side][size] = delta_signature
            
    return output

delta_signature_table = build_delta_signature(signature_table)

# %%
'''
aggregate multiple signatures
into one
'''
def build_multitrades_signature(trades_before):
    signature = defaultdict(float)

    for trade in trades_before.itertuples():
        side = trade.AGGRESSOR_SIDE
        for size_range in signature_table[side]:
            if size_range[0] <= trade.SIZE <= size_range[1]:
                break

        delta_signature = delta_signature_table[side][size_range]

        times = {trade.Time + np.timedelta64(sec, 's') : delta_signature[sec] 
               for sec in range(30)}

        for k, v in times.items():
            signature[k] += v
        
    signature = (sorted(signature.items()))

    reconstructed_signature = []
    total = 0

    for (k,v) in signature:
        total += v
        reconstructed_signature.append((k, total))

    return reconstructed_signature

# %% [markdown]
# # 3. Hedge functions

# %%
def get_trades_before(moment):
    global look_back_time, trades
    moment_before = moment - look_back_time
    index1 = trades.Time.searchsorted(moment_before, side='left')
    index2 = trades.Time.searchsorted(moment, side='right')
    trades_before = trades.iloc[index1 : index2]
    return trades_before

# %%
'''
@returns 
zone1time - time, when zone1 ends and zone2 starts
zone2time - time, when zone2 ends and zone3 starts
'''
def get_zone_times(moment, side, skip_empty_trades = False):
    #1 get trades before our trade
    trades_before = get_trades_before(moment)
    
    if len(trades_before) == 0:
        if skip_empty_trades == False:
            #Columns: [Time, AGGRESSOR_SIDE, PRICE, SIZE, TRADE_VALUE]
            trades_before.loc[-1] = [moment, side, -1.0, 1000, -1000.0]  # adding a row
            trades_before.index = trades_before.index + 1  # shifting index
            trades_before = trades_before.sort_index()  # sorting by index
        else:
            return None, None

    #2 mix them into signature
    reference_signature = build_multitrades_signature(trades_before)
    #3 find three zones
    mmax = max(reference_signature, key = lambda item: item[1])
    mmin = min(reference_signature, key = lambda item: item[1])
    
    if side == 'B':
        zone1price = mmin[1] + (mmax[1] - mmin[1]) * 0.33
        zone2price = mmin[1] + (mmax[1] - mmin[1]) * 0.66
    
        for (k, v) in reference_signature:
            if v >= zone1price:
                #print(k)
                zone1time = k
                break
            
        for (k, v) in reference_signature:
            if v >= zone2price:
                #print(k)
                zone2time = k
                break
    else:
        zone1price = mmax[1] - (mmax[1] - mmin[1]) * 0.33
        zone2price = mmax[1] - (mmax[1] - mmin[1]) * 0.66
        
        for (k, v) in reference_signature:
            if v <= zone1price:
                #print(k)
                zone1time = k
                break
            
        for (k, v) in reference_signature:
            if v <= zone2price:
                #print(k)
                zone2time = k
                break
                
    #4 return result
    return zone1time, zone2time

# %%
def make_hedge(lob, datetime, size, side):
    #lob = lob[lob['Time'] >= datetime]
    time_index = lob['Time'].searchsorted(datetime, side='right')
        
    if time_index >= len(lob):
        return (0, 0.0)
    row = lob.iloc[time_index] # first timestamp >= datetime
    
    quote_side = 'BID' if (side == 'S') else 'ASK'
    
    maxsize = sum([row[quote_side + '_SIZE' + str(level)] for level in range(1, 11)])
        
    if maxsize < size:
        raise ValueError(f'size {size} is greater than available {maxsize}')
    
    size_hedged, sum_hedged = 0, 0.0
    level = 1
    while size_hedged < size and level < 11:
        portion = min(size - size_hedged, row[quote_side + '_SIZE' + str(level)])
        price = row[quote_side + '_PRICE' + str(level)]
        size_hedged += portion
        sum_hedged += portion * price
        print(f'added {portion} by {price}')
        level += 1
        
    print('HEDGE ended')
    return (size_hedged, sum_hedged)

# %%
class LOBCache:
    def __init__(self):
        pass
    
    def get_lob(self, datetime):
        #print(datetime)
        filename = datetime.strftime('LOB_%m%d.feather')
        return self.__get_lob_by_filename(filename)
        pass
    
    @lru_cache(maxsize=4)
    def __get_lob_by_filename(self, filename):
        print(filename)
        lob = pd.read_feather(LOB_DIR + filename).dropna()
        lob['BID_SIZE1'] = 99_999_999
        lob['ASK_SIZE1'] = 99_999_999
        return lob

# %%
cache = LOBCache()

# %%
def calc_hedge_signature(cache, moment, hedge_params_df):
    curr_moment = moment
    print(hedge_params_df)

    lob = cache.get_lob(curr_moment)
    remain = volume
    total = None
    
    zone1time, zone2time = get_zone_times(curr_moment, side, skip_empty_trades = True)
    print('zone1time, zone2time','\n',zone1time,'\n', zone2time)
    if zone1time is None:
        remain = 0
        total = (-2, -2.0)
    while remain > 0:
        print(curr_moment)
        
        # select our zone
        if moment <= curr_moment <= zone1time:
            print('we are in 1st zone')
            zone = 1
        elif zone1time < curr_moment <= zone2time:
            print('we are in 2nd zone')
            zone = 2
        else:
            print('we are in 3rd zone')
            zone = 3
        
        row = hedge_params_df[hedge_params_df['zone_number'] == zone]
        size_contracts = int(volume * row['proportion'])
        size_contracts = min(size_contracts, remain)

        hedge_result = make_hedge(lob, curr_moment, size = size_contracts, side = side)

        interval =  row['distance'].iloc[0]
        curr_moment = curr_moment + np.timedelta64(interval, 's')
        if hedge_result is None:
            break
        
        if hedge_result[0] == 0:
            return (-1, -1.0)
        
        if total is None:
            total = hedge_result
        else:
            total = sum_2_tuples(total, hedge_result)
            
        print(hedge_result)
        remain -= hedge_result[0]
        if remain == 0:
            break
            
    del lob
            
    if remain > 0:
        return None
    else:
        return total

# %% [markdown]
# # 4. Calculation

# %%
#CREATE TABLE RESULT(MOMENT TEXT, SIDE TEXT, QUANTITY INTEGER, SUM REAL, PRIMARY KEY(MOMENT,SIDE));
sign_sql = sqlite3.connect(SIGNATURE_FILE)
sign_sql.execute('CREATE TABLE IF NOT EXISTS RESULT(MOMENT TEXT, SIDE TEXT, QUANTITY INTEGER, SUM REAL, PRIMARY KEY(MOMENT,SIDE));')
cur=sign_sql.cursor()

# %%
records = []

for moment in moments:
    for side in ('B', 'S'):
        record = (str(moment),side)
        query='select exists(select 1 from result where moment=? and side=? collate nocase) limit 1'
        # 'query' RETURNS 1 IF USERNAME EXISTS OR 0 IF NOT, AS INTEGER(MAYBE). 'collate nocase'= CASE INSENSITIVE, IT'S OPTIONAL
        check=cur.execute(query,record) 
        if check.fetchone()[0]==1:
            print(f'Moment already available ' + str(record))
            continue

        print('calculating for moment', moment)
        result = calc_hedge_signature(cache, moment, hedge_params_df)

        query='INSERT OR REPLACE INTO result(moment, side, quantity, sum) VALUES(?, ?, ?, ?);'
        if result:
            record = (str(moment), side, int(result[0]), result[1])
        else:
            record = (str(moment), side, -1, -1)

        print(record)
        cur.execute(query, record)
        records.append(record)

        gc.collect()

        if len(records) % 100 == 0:
            clear_output(wait=False)
# Out:
# calculating for moment 2021-10-05 17:11:36.459400
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# LOB_1005.feather
# zone1time, zone2time
#  2021-10-05 17:11:40.459400
#  2021-10-05 17:11:48.459400
# 2021-10-05 17:11:36.459400
# we are in 1st zone
# added 3000 by 72.49
# HEDGE ended
# (3000, 217469.99999999997)
# 2021-10-05 17:11:37.459400
# we are in 1st zone
# added 3000 by 72.49
# HEDGE ended
# (3000, 217469.99999999997)
# 2021-10-05 17:11:38.459400
# we are in 1st zone
# added 3000 by 72.49
# HEDGE ended
# (3000, 217469.99999999997)
# 2021-10-05 17:11:39.459400
# we are in 1st zone
# added 1000 by 72.4925
# HEDGE ended
# (1000, 72492.5)
# ('2021-10-05 17:11:36.459400', 'B', 10000, 724902.4999999999)
# calculating for moment 2021-10-05 17:11:36.459400
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 17:11:36.459400
#  2021-10-05 17:11:36.459400
# 2021-10-05 17:11:36.459400
# we are in 1st zone
# added 3000 by 72.48
# HEDGE ended
# (3000, 217440.0)
# 2021-10-05 17:11:37.459400
# we are in 3rd zone
# added 1000 by 72.485
# HEDGE ended
# (1000, 72485.0)
# 2021-10-05 17:11:47.459400
# we are in 3rd zone
# added 1000 by 72.49
# HEDGE ended
# (1000, 72490.0)
# 2021-10-05 17:11:57.459400
# we are in 3rd zone
# added 1000 by 72.485
# HEDGE ended
# (1000, 72485.0)
# 2021-10-05 17:12:07.459400
# we are in 3rd zone
# added 1000 by 72.49
# HEDGE ended
# (1000, 72490.0)
# 2021-10-05 17:12:17.459400
# we are in 3rd zone
# added 1000 by 72.485
# HEDGE ended
# (1000, 72485.0)
# 2021-10-05 17:12:27.459400
# we are in 3rd zone
# added 1000 by 72.485
# HEDGE ended
# (1000, 72485.0)
# 2021-10-05 17:12:37.459400
# we are in 3rd zone
# added 1000 by 72.4925
# HEDGE ended
# (1000, 72492.5)
# ('2021-10-05 17:11:36.459400', 'S', 10000, 724852.5)
# calculating for moment 2021-10-05 17:21:32.271286
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 17:21:20.064328
#  2021-10-05 17:21:32.271286
# 2021-10-05 17:21:32.271286
# we are in 2nd zone
# added 2000 by 72.5275
# HEDGE ended
# (2000, 145055.0)
# 2021-10-05 17:21:37.271286
# we are in 3rd zone
# added 1000 by 72.52
# HEDGE ended
# (1000, 72520.0)
# 2021-10-05 17:21:47.271286
# we are in 3rd zone
# added 1000 by 72.5325
# HEDGE ended
# (1000, 72532.5)
# 2021-10-05 17:21:57.271286
# we are in 3rd zone
# added 1000 by 72.5325
# HEDGE ended
# (1000, 72532.5)
# 2021-10-05 17:22:07.271286
# we are in 3rd zone
# added 1000 by 72.53
# HEDGE ended
# (1000, 72530.0)
# 2021-10-05 17:22:17.271286
# we are in 3rd zone
# added 1000 by 72.53
# HEDGE ended
# (1000, 72530.0)
# 2021-10-05 17:22:27.271286
# we are in 3rd zone
# added 1000 by 72.5275
# HEDGE ended
# (1000, 72527.5)
# 2021-10-05 17:22:37.271286
# we are in 3rd zone
# added 1000 by 72.5275
# HEDGE ended
# (1000, 72527.5)
# 2021-10-05 17:22:47.271286
# we are in 3rd zone
# added 1000 by 72.5225
# HEDGE ended
# (1000, 72522.5)
# ('2021-10-05 17:21:32.271286', 'B', 10000, 725277.5)
# calculating for moment 2021-10-05 17:21:32.271286
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 17:21:11.438865
#  2021-10-05 17:21:11.438865
# 2021-10-05 17:21:32.271286
# we are in 3rd zone
# added 1000 by 72.515
# HEDGE ended
# (1000, 72515.0)
# 2021-10-05 17:21:42.271286
# we are in 3rd zone
# added 1000 by 72.525
# HEDGE ended
# (1000, 72525.0)
# 2021-10-05 17:21:52.271286
# we are in 3rd zone
# added 1000 by 72.525
# HEDGE ended
# (1000, 72525.0)
# 2021-10-05 17:22:02.271286
# we are in 3rd zone
# added 1000 by 72.5225
# HEDGE ended
# (1000, 72522.5)
# 2021-10-05 17:22:12.271286
# we are in 3rd zone
# added 1000 by 72.525
# HEDGE ended
# (1000, 72525.0)
# 2021-10-05 17:22:22.271286
# we are in 3rd zone
# added 1000 by 72.52
# HEDGE ended
# (1000, 72520.0)
# 2021-10-05 17:22:32.271286
# we are in 3rd zone
# added 1000 by 72.5225
# HEDGE ended
# (1000, 72522.5)
# 2021-10-05 17:22:42.271286
# we are in 3rd zone
# added 1000 by 72.5175
# HEDGE ended
# (1000, 72517.5)
# 2021-10-05 17:22:52.271286
# we are in 3rd zone
# added 1000 by 72.5225
# HEDGE ended
# (1000, 72522.5)
# 2021-10-05 17:23:02.271286
# we are in 3rd zone
# added 1000 by 72.525
# HEDGE ended
# (1000, 72525.0)
# ('2021-10-05 17:21:32.271286', 'S', 10000, 725220.0)
# calculating for moment 2021-10-05 17:32:02.973211
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 17:32:06.973211
#  2021-10-05 17:32:14.973211
# 2021-10-05 17:32:02.973211
# we are in 1st zone
# added 3000 by 72.5025
# HEDGE ended
# (3000, 217507.5)
# 2021-10-05 17:32:03.973211
# we are in 1st zone
# added 3000 by 72.5
# HEDGE ended
# (3000, 217500.0)
# 2021-10-05 17:32:04.973211
# we are in 1st zone
# added 3000 by 72.5
# HEDGE ended
# (3000, 217500.0)
# 2021-10-05 17:32:05.973211
# we are in 1st zone
# added 1000 by 72.4975
# HEDGE ended
# (1000, 72497.5)
# ('2021-10-05 17:32:02.973211', 'B', 10000, 725005.0)
# calculating for moment 2021-10-05 17:32:02.973211
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 17:32:02.973211
#  2021-10-05 17:32:02.973211
# 2021-10-05 17:32:02.973211
# we are in 1st zone
# added 3000 by 72.4925
# HEDGE ended
# (3000, 217477.50000000003)
# 2021-10-05 17:32:03.973211
# we are in 3rd zone
# added 1000 by 72.4925
# HEDGE ended
# (1000, 72492.5)
# 2021-10-05 17:32:13.973211
# we are in 3rd zone
# added 1000 by 72.4975
# HEDGE ended
# (1000, 72497.5)
# 2021-10-05 17:32:23.973211
# we are in 3rd zone
# added 1000 by 72.5075
# HEDGE ended
# (1000, 72507.5)
# 2021-10-05 17:32:33.973211
# we are in 3rd zone
# added 1000 by 72.505
# HEDGE ended
# (1000, 72505.0)
# 2021-10-05 17:32:43.973211
# we are in 3rd zone
# added 1000 by 72.5075
# HEDGE ended
# (1000, 72507.5)
# 2021-10-05 17:32:53.973211
# we are in 3rd zone
# added 1000 by 72.5175
# HEDGE ended
# (1000, 72517.5)
# 2021-10-05 17:33:03.973211
# we are in 3rd zone
# added 1000 by 72.52
# HEDGE ended
# (1000, 72520.0)
# ('2021-10-05 17:32:02.973211', 'S', 10000, 725025.0)
# calculating for moment 2021-10-05 18:11:23.744493
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 18:11:07.230841
#  2021-10-05 18:11:22.245449
# 2021-10-05 18:11:23.744493
# we are in 3rd zone
# added 1000 by 72.35
# HEDGE ended
# (1000, 72350.0)
# 2021-10-05 18:11:33.744493
# we are in 3rd zone
# added 1000 by 72.35
# HEDGE ended
# (1000, 72350.0)
# 2021-10-05 18:11:43.744493
# we are in 3rd zone
# added 1000 by 72.36
# HEDGE ended
# (1000, 72360.0)
# 2021-10-05 18:11:53.744493
# we are in 3rd zone
# added 1000 by 72.3675
# HEDGE ended
# (1000, 72367.5)
# 2021-10-05 18:12:03.744493
# we are in 3rd zone
# added 1000 by 72.3575
# HEDGE ended
# (1000, 72357.5)
# 2021-10-05 18:12:13.744493
# we are in 3rd zone
# added 1000 by 72.3625
# HEDGE ended
# (1000, 72362.5)
# 2021-10-05 18:12:23.744493
# we are in 3rd zone
# added 1000 by 72.365
# HEDGE ended
# (1000, 72365.0)
# 2021-10-05 18:12:33.744493
# we are in 3rd zone
# added 1000 by 72.36
# HEDGE ended
# (1000, 72360.0)
# 2021-10-05 18:12:43.744493
# we are in 3rd zone
# added 1000 by 72.36
# HEDGE ended
# (1000, 72360.0)
# 2021-10-05 18:12:53.744493
# we are in 3rd zone
# added 1000 by 72.3475
# HEDGE ended
# (1000, 72347.5)
# ('2021-10-05 18:11:23.744493', 'B', 10000, 723580.0)
# calculating for moment 2021-10-05 18:11:23.744493
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 18:11:03.684724
#  2021-10-05 18:11:03.684724
# 2021-10-05 18:11:23.744493
# we are in 3rd zone
# added 1000 by 72.3475
# HEDGE ended
# (1000, 72347.5)
# 2021-10-05 18:11:33.744493
# we are in 3rd zone
# added 1000 by 72.345
# HEDGE ended
# (1000, 72345.0)
# 2021-10-05 18:11:43.744493
# we are in 3rd zone
# added 1000 by 72.3525
# HEDGE ended
# (1000, 72352.5)
# 2021-10-05 18:11:53.744493
# we are in 3rd zone
# added 1000 by 72.36
# HEDGE ended
# (1000, 72360.0)
# 2021-10-05 18:12:03.744493
# we are in 3rd zone
# added 1000 by 72.3525
# HEDGE ended
# (1000, 72352.5)
# 2021-10-05 18:12:13.744493
# we are in 3rd zone
# added 1000 by 72.355
# HEDGE ended
# (1000, 72355.0)
# 2021-10-05 18:12:23.744493
# we are in 3rd zone
# added 1000 by 72.3575
# HEDGE ended
# (1000, 72357.5)
# 2021-10-05 18:12:33.744493
# we are in 3rd zone
# added 1000 by 72.3525
# HEDGE ended
# (1000, 72352.5)
# 2021-10-05 18:12:43.744493
# we are in 3rd zone
# added 1000 by 72.355
# HEDGE ended
# (1000, 72355.0)
# 2021-10-05 18:12:53.744493
# we are in 3rd zone
# added 1000 by 72.3425
# HEDGE ended
# (1000, 72342.5)
# ('2021-10-05 18:11:23.744493', 'S', 10000, 723520.0)
# calculating for moment 2021-10-05 18:34:32.742440
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 18:34:12.665335
#  2021-10-05 18:34:12.665335
# 2021-10-05 18:34:32.742440
# we are in 3rd zone
# added 1000 by 72.325
# HEDGE ended
# (1000, 72325.0)
# 2021-10-05 18:34:42.742440
# we are in 3rd zone
# added 1000 by 72.3225
# HEDGE ended
# (1000, 72322.5)
# 2021-10-05 18:34:52.742440
# we are in 3rd zone
# added 1000 by 72.3225
# HEDGE ended
# (1000, 72322.5)
# 2021-10-05 18:35:02.742440
# we are in 3rd zone
# added 1000 by 72.3125
# HEDGE ended
# (1000, 72312.5)
# 2021-10-05 18:35:12.742440
# we are in 3rd zone
# added 1000 by 72.31
# HEDGE ended
# (1000, 72310.0)
# 2021-10-05 18:35:22.742440
# we are in 3rd zone
# added 1000 by 72.31
# HEDGE ended
# (1000, 72310.0)
# 2021-10-05 18:35:32.742440
# we are in 3rd zone
# added 1000 by 72.305
# HEDGE ended
# (1000, 72305.0)
# 2021-10-05 18:35:42.742440
# we are in 3rd zone
# added 1000 by 72.3075
# HEDGE ended
# (1000, 72307.5)
# 2021-10-05 18:35:52.742440
# we are in 3rd zone
# added 1000 by 72.305
# HEDGE ended
# (1000, 72305.0)
# 2021-10-05 18:36:02.742440
# we are in 3rd zone
# added 1000 by 72.305
# HEDGE ended
# (1000, 72305.0)
# ('2021-10-05 18:34:32.742440', 'B', 10000, 723125.0)
# calculating for moment 2021-10-05 18:34:32.742440
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 18:34:31.814013
#  2021-10-05 18:34:31.873986
# 2021-10-05 18:34:32.742440
# we are in 3rd zone
# added 1000 by 72.3175
# HEDGE ended
# (1000, 72317.5)
# 2021-10-05 18:34:42.742440
# we are in 3rd zone
# added 1000 by 72.3175
# HEDGE ended
# (1000, 72317.5)
# 2021-10-05 18:34:52.742440
# we are in 3rd zone
# added 1000 by 72.3175
# HEDGE ended
# (1000, 72317.5)
# 2021-10-05 18:35:02.742440
# we are in 3rd zone
# added 1000 by 72.3075
# HEDGE ended
# (1000, 72307.5)
# 2021-10-05 18:35:12.742440
# we are in 3rd zone
# added 1000 by 72.305
# HEDGE ended
# (1000, 72305.0)
# 2021-10-05 18:35:22.742440
# we are in 3rd zone
# added 1000 by 72.305
# HEDGE ended
# (1000, 72305.0)
# 2021-10-05 18:35:32.742440
# we are in 3rd zone
# added 1000 by 72.3
# HEDGE ended
# (1000, 72300.0)
# 2021-10-05 18:35:42.742440
# we are in 3rd zone
# added 1000 by 72.3025
# HEDGE ended
# (1000, 72302.5)
# 2021-10-05 18:35:52.742440
# we are in 3rd zone
# added 1000 by 72.3
# HEDGE ended
# (1000, 72300.0)
# 2021-10-05 18:36:02.742440
# we are in 3rd zone
# added 1000 by 72.3
# HEDGE ended
# (1000, 72300.0)
# ('2021-10-05 18:34:32.742440', 'S', 10000, 723072.5)
# calculating for moment 2021-10-05 14:11:45.975550
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 14:11:31.178504
#  2021-10-05 14:11:45.975550
# 2021-10-05 14:11:45.975550
# we are in 2nd zone
# added 2000 by 72.6525
# HEDGE ended
# (2000, 145305.0)
# 2021-10-05 14:11:50.975550
# we are in 3rd zone
# added 1000 by 72.65
# HEDGE ended
# (1000, 72650.0)
# 2021-10-05 14:12:00.975550
# we are in 3rd zone
# added 1000 by 72.65
# HEDGE ended
# (1000, 72650.0)
# 2021-10-05 14:12:10.975550
# we are in 3rd zone
# added 1000 by 72.65
# HEDGE ended
# (1000, 72650.0)
# 2021-10-05 14:12:20.975550
# we are in 3rd zone
# added 1000 by 72.65
# HEDGE ended
# (1000, 72650.0)
# 2021-10-05 14:12:30.975550
# we are in 3rd zone
# added 1000 by 72.65
# HEDGE ended
# (1000, 72650.0)
# 2021-10-05 14:12:40.975550
# we are in 3rd zone
# added 1000 by 72.655
# HEDGE ended
# (1000, 72655.0)
# 2021-10-05 14:12:50.975550
# we are in 3rd zone
# added 1000 by 72.65
# HEDGE ended
# (1000, 72650.0)
# 2021-10-05 14:13:00.975550
# we are in 3rd zone
# added 1000 by 72.65
# HEDGE ended
# (1000, 72650.0)
# ('2021-10-05 14:11:45.975550', 'B', 10000, 726510.0)
# calculating for moment 2021-10-05 14:11:45.975550
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 14:11:20.518488
#  2021-10-05 14:11:20.518488
# 2021-10-05 14:11:45.975550
# we are in 3rd zone
# added 1000 by 72.64
# HEDGE ended
# (1000, 72640.0)
# 2021-10-05 14:11:55.975550
# we are in 3rd zone
# added 1000 by 72.645
# HEDGE ended
# (1000, 72645.0)
# 2021-10-05 14:12:05.975550
# we are in 3rd zone
# added 1000 by 72.6425
# HEDGE ended
# (1000, 72642.5)
# 2021-10-05 14:12:15.975550
# we are in 3rd zone
# added 1000 by 72.6425
# HEDGE ended
# (1000, 72642.5)
# 2021-10-05 14:12:25.975550
# we are in 3rd zone
# added 1000 by 72.645
# HEDGE ended
# (1000, 72645.0)
# 2021-10-05 14:12:35.975550
# we are in 3rd zone
# added 1000 by 72.645
# HEDGE ended
# (1000, 72645.0)
# 2021-10-05 14:12:45.975550
# we are in 3rd zone
# added 1000 by 72.645
# HEDGE ended
# (1000, 72645.0)
# 2021-10-05 14:12:55.975550
# we are in 3rd zone
# added 1000 by 72.645
# HEDGE ended
# (1000, 72645.0)
# 2021-10-05 14:13:05.975550
# we are in 3rd zone
# added 1000 by 72.6475
# HEDGE ended
# (1000, 72647.5)
# 2021-10-05 14:13:15.975550
# we are in 3rd zone
# added 1000 by 72.6475
# HEDGE ended
# (1000, 72647.5)
# ('2021-10-05 14:11:45.975550', 'S', 10000, 726445.0)
# calculating for moment 2021-10-05 14:21:55.678531
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 14:21:30.001510
#  2021-10-05 14:21:55.678531
# 2021-10-05 14:21:55.678531
# we are in 2nd zone
# added 2000 by 72.665
# HEDGE ended
# (2000, 145330.0)
# 2021-10-05 14:22:00.678531
# we are in 3rd zone
# added 1000 by 72.66
# HEDGE ended
# (1000, 72660.0)
# 2021-10-05 14:22:10.678531
# we are in 3rd zone
# added 1000 by 72.6625
# HEDGE ended
# (1000, 72662.5)
# 2021-10-05 14:22:20.678531
# we are in 3rd zone
# added 1000 by 72.6625
# HEDGE ended
# (1000, 72662.5)
# 2021-10-05 14:22:30.678531
# we are in 3rd zone
# added 1000 by 72.655
# HEDGE ended
# (1000, 72655.0)
# 2021-10-05 14:22:40.678531
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 14:22:50.678531
# we are in 3rd zone
# added 1000 by 72.66
# HEDGE ended
# (1000, 72660.0)
# 2021-10-05 14:23:00.678531
# we are in 3rd zone
# added 1000 by 72.66
# HEDGE ended
# (1000, 72660.0)
# 2021-10-05 14:23:10.678531
# we are in 3rd zone
# added 1000 by 72.66
# HEDGE ended
# (1000, 72660.0)
# ('2021-10-05 14:21:55.678531', 'B', 10000, 726607.5)
# calculating for moment 2021-10-05 14:21:55.678531
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 14:21:26.568054
#  2021-10-05 14:21:26.568054
# 2021-10-05 14:21:55.678531
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 14:22:05.678531
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 14:22:15.678531
# we are in 3rd zone
# added 1000 by 72.655
# HEDGE ended
# (1000, 72655.0)
# 2021-10-05 14:22:25.678531
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 14:22:35.678531
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 14:22:45.678531
# we are in 3rd zone
# added 1000 by 72.65
# HEDGE ended
# (1000, 72650.0)
# 2021-10-05 14:22:55.678531
# we are in 3rd zone
# added 1000 by 72.655
# HEDGE ended
# (1000, 72655.0)
# 2021-10-05 14:23:05.678531
# we are in 3rd zone
# added 1000 by 72.65
# HEDGE ended
# (1000, 72650.0)
# 2021-10-05 14:23:15.678531
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 14:23:25.678531
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# ('2021-10-05 14:21:55.678531', 'S', 10000, 726525.0)
# calculating for moment 2021-10-05 14:31:44.596418
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 14:31:37.552498
#  2021-10-05 14:31:44.596418
# 2021-10-05 14:31:44.596418
# we are in 2nd zone
# added 2000 by 72.6375
# HEDGE ended
# (2000, 145275.0)
# 2021-10-05 14:31:49.596418
# we are in 3rd zone
# added 1000 by 72.635
# HEDGE ended
# (1000, 72635.0)
# 2021-10-05 14:31:59.596418
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# 2021-10-05 14:32:09.596418
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# 2021-10-05 14:32:19.596418
# we are in 3rd zone
# added 1000 by 72.635
# HEDGE ended
# (1000, 72635.0)
# 2021-10-05 14:32:29.596418
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# 2021-10-05 14:32:39.596418
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# 2021-10-05 14:32:49.596418
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# 2021-10-05 14:32:59.596418
# we are in 3rd zone
# added 1000 by 72.63
# HEDGE ended
# (1000, 72630.0)
# ('2021-10-05 14:31:44.596418', 'B', 10000, 726337.5)
# calculating for moment 2021-10-05 14:31:44.596418
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 14:31:15.004545
#  2021-10-05 14:31:15.004545
# 2021-10-05 14:31:44.596418
# we are in 3rd zone
# added 1000 by 72.625
# HEDGE ended
# (1000, 72625.0)
# 2021-10-05 14:31:54.596418
# we are in 3rd zone
# added 1000 by 72.625
# HEDGE ended
# (1000, 72625.0)
# 2021-10-05 14:32:04.596418
# we are in 3rd zone
# added 1000 by 72.625
# HEDGE ended
# (1000, 72625.0)
# 2021-10-05 14:32:14.596418
# we are in 3rd zone
# added 1000 by 72.6275
# HEDGE ended
# (1000, 72627.5)
# 2021-10-05 14:32:24.596418
# we are in 3rd zone
# added 1000 by 72.63
# HEDGE ended
# (1000, 72630.0)
# 2021-10-05 14:32:34.596418
# we are in 3rd zone
# added 1000 by 72.6225
# HEDGE ended
# (1000, 72622.5)
# 2021-10-05 14:32:44.596418
# we are in 3rd zone
# added 1000 by 72.625
# HEDGE ended
# (1000, 72625.0)
# 2021-10-05 14:32:54.596418
# we are in 3rd zone
# added 1000 by 72.6225
# HEDGE ended
# (1000, 72622.5)
# 2021-10-05 14:33:04.596418
# we are in 3rd zone
# added 1000 by 72.62
# HEDGE ended
# (1000, 72620.0)
# 2021-10-05 14:33:14.596418
# we are in 3rd zone
# added 1000 by 72.6225
# HEDGE ended
# (1000, 72622.5)
# ('2021-10-05 14:31:44.596418', 'S', 10000, 726245.0)
# calculating for moment 2021-10-05 13:12:30.185190
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 13:12:34.185190
#  2021-10-05 13:12:42.185190
# 2021-10-05 13:12:30.185190
# we are in 1st zone
# added 3000 by 72.63
# HEDGE ended
# (3000, 217890.0)
# 2021-10-05 13:12:31.185190
# we are in 1st zone
# added 3000 by 72.63
# HEDGE ended
# (3000, 217890.0)
# 2021-10-05 13:12:32.185190
# we are in 1st zone
# added 3000 by 72.63
# HEDGE ended
# (3000, 217890.0)
# 2021-10-05 13:12:33.185190
# we are in 1st zone
# added 1000 by 72.63
# HEDGE ended
# (1000, 72630.0)
# ('2021-10-05 13:12:30.185190', 'B', 10000, 726300.0)
# calculating for moment 2021-10-05 13:12:30.185190
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 13:12:30.185190
#  2021-10-05 13:12:30.185190
# 2021-10-05 13:12:30.185190
# we are in 1st zone
# added 3000 by 72.6275
# HEDGE ended
# (3000, 217882.5)
# 2021-10-05 13:12:31.185190
# we are in 3rd zone
# added 1000 by 72.6275
# HEDGE ended
# (1000, 72627.5)
# 2021-10-05 13:12:41.185190
# we are in 3rd zone
# added 1000 by 72.625
# HEDGE ended
# (1000, 72625.0)
# 2021-10-05 13:12:51.185190
# we are in 3rd zone
# added 1000 by 72.6275
# HEDGE ended
# (1000, 72627.5)
# 2021-10-05 13:13:01.185190
# we are in 3rd zone
# added 1000 by 72.625
# HEDGE ended
# (1000, 72625.0)
# 2021-10-05 13:13:11.185190
# we are in 3rd zone
# added 1000 by 72.625
# HEDGE ended
# (1000, 72625.0)
# 2021-10-05 13:13:21.185190
# we are in 3rd zone
# added 1000 by 72.6225
# HEDGE ended
# (1000, 72622.5)
# 2021-10-05 13:13:31.185190
# we are in 3rd zone
# added 1000 by 72.6225
# HEDGE ended
# (1000, 72622.5)
# ('2021-10-05 13:12:30.185190', 'S', 10000, 726257.5)
# calculating for moment 2021-10-05 13:20:10.150098
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 13:20:08.460088
#  2021-10-05 13:20:10.143732
# 2021-10-05 13:20:10.150098
# we are in 3rd zone
# added 1000 by 72.62
# HEDGE ended
# (1000, 72620.0)
# 2021-10-05 13:20:20.150098
# we are in 3rd zone
# added 1000 by 72.635
# HEDGE ended
# (1000, 72635.0)
# 2021-10-05 13:20:30.150098
# we are in 3rd zone
# added 1000 by 72.64
# HEDGE ended
# (1000, 72640.0)
# 2021-10-05 13:20:40.150098
# we are in 3rd zone
# added 1000 by 72.6375
# HEDGE ended
# (1000, 72637.5)
# 2021-10-05 13:20:50.150098
# we are in 3rd zone
# added 1000 by 72.6375
# HEDGE ended
# (1000, 72637.5)
# 2021-10-05 13:21:00.150098
# we are in 3rd zone
# added 1000 by 72.6375
# HEDGE ended
# (1000, 72637.5)
# 2021-10-05 13:21:10.150098
# we are in 3rd zone
# added 1000 by 72.6375
# HEDGE ended
# (1000, 72637.5)
# 2021-10-05 13:21:20.150098
# we are in 3rd zone
# added 1000 by 72.6375
# HEDGE ended
# (1000, 72637.5)
# 2021-10-05 13:21:30.150098
# we are in 3rd zone
# added 1000 by 72.6375
# HEDGE ended
# (1000, 72637.5)
# 2021-10-05 13:21:40.150098
# we are in 3rd zone
# added 1000 by 72.6375
# HEDGE ended
# (1000, 72637.5)
# ('2021-10-05 13:20:10.150098', 'B', 10000, 726357.5)
# calculating for moment 2021-10-05 13:20:10.150098
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 13:19:57.422005
#  2021-10-05 13:19:57.422005
# 2021-10-05 13:20:10.150098
# we are in 3rd zone
# added 1000 by 72.6175
# HEDGE ended
# (1000, 72617.5)
# 2021-10-05 13:20:20.150098
# we are in 3rd zone
# added 1000 by 72.63
# HEDGE ended
# (1000, 72630.0)
# 2021-10-05 13:20:30.150098
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# 2021-10-05 13:20:40.150098
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# 2021-10-05 13:20:50.150098
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# 2021-10-05 13:21:00.150098
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# 2021-10-05 13:21:10.150098
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# 2021-10-05 13:21:20.150098
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# 2021-10-05 13:21:30.150098
# we are in 3rd zone
# added 1000 by 72.635
# HEDGE ended
# (1000, 72635.0)
# 2021-10-05 13:21:40.150098
# we are in 3rd zone
# added 1000 by 72.635
# HEDGE ended
# (1000, 72635.0)
# ('2021-10-05 13:20:10.150098', 'S', 10000, 726312.5)
# calculating for moment 2021-10-05 13:32:24.471945
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 13:32:08.295183
#  2021-10-05 13:32:08.935791
# 2021-10-05 13:32:24.471945
# we are in 3rd zone
# added 1000 by 72.655
# HEDGE ended
# (1000, 72655.0)
# 2021-10-05 13:32:34.471945
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 13:32:44.471945
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 13:32:54.471945
# we are in 3rd zone
# added 1000 by 72.66
# HEDGE ended
# (1000, 72660.0)
# 2021-10-05 13:33:04.471945
# we are in 3rd zone
# added 1000 by 72.66
# HEDGE ended
# (1000, 72660.0)
# 2021-10-05 13:33:14.471945
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 13:33:24.471945
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 13:33:34.471945
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 13:33:44.471945
# we are in 3rd zone
# added 1000 by 72.655
# HEDGE ended
# (1000, 72655.0)
# 2021-10-05 13:33:54.471945
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# ('2021-10-05 13:32:24.471945', 'B', 10000, 726575.0)
# calculating for moment 2021-10-05 13:32:24.471945
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 13:31:57.420938
#  2021-10-05 13:31:57.420938
# 2021-10-05 13:32:24.471945
# we are in 3rd zone
# added 1000 by 72.6475
# HEDGE ended
# (1000, 72647.5)
# 2021-10-05 13:32:34.471945
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 13:32:44.471945
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 13:32:54.471945
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 13:33:04.471945
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 13:33:14.471945
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 13:33:24.471945
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 13:33:34.471945
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 13:33:44.471945
# we are in 3rd zone
# added 1000 by 72.65
# HEDGE ended
# (1000, 72650.0)
# 2021-10-05 13:33:54.471945
# we are in 3rd zone
# added 1000 by 72.65
# HEDGE ended
# (1000, 72650.0)
# ('2021-10-05 13:32:24.471945', 'S', 10000, 726515.0)
# calculating for moment 2021-10-05 11:10:04.392347
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 11:09:59.754778
#  2021-10-05 11:09:59.754778
# 2021-10-05 11:10:04.392347
# we are in 3rd zone
# added 1000 by 72.6075
# HEDGE ended
# (1000, 72607.5)
# 2021-10-05 11:10:14.392347
# we are in 3rd zone
# added 1000 by 72.6075
# HEDGE ended
# (1000, 72607.5)
# 2021-10-05 11:10:24.392347
# we are in 3rd zone
# added 1000 by 72.615
# HEDGE ended
# (1000, 72615.0)
# 2021-10-05 11:10:34.392347
# we are in 3rd zone
# added 1000 by 72.615
# HEDGE ended
# (1000, 72615.0)
# 2021-10-05 11:10:44.392347
# we are in 3rd zone
# added 1000 by 72.62
# HEDGE ended
# (1000, 72620.0)
# 2021-10-05 11:10:54.392347
# we are in 3rd zone
# added 1000 by 72.62
# HEDGE ended
# (1000, 72620.0)
# 2021-10-05 11:11:04.392347
# we are in 3rd zone
# added 1000 by 72.625
# HEDGE ended
# (1000, 72625.0)
# 2021-10-05 11:11:14.392347
# we are in 3rd zone
# added 1000 by 72.62
# HEDGE ended
# (1000, 72620.0)
# 2021-10-05 11:11:24.392347
# we are in 3rd zone
# added 1000 by 72.62
# HEDGE ended
# (1000, 72620.0)
# 2021-10-05 11:11:34.392347
# we are in 3rd zone
# added 1000 by 72.6325
# HEDGE ended
# (1000, 72632.5)
# ('2021-10-05 11:10:04.392347', 'B', 10000, 726182.5)
# calculating for moment 2021-10-05 11:10:04.392347
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 11:09:53.942678
#  2021-10-05 11:09:53.942678
# 2021-10-05 11:10:04.392347
# we are in 3rd zone
# added 1000 by 72.6
# HEDGE ended
# (1000, 72600.0)
# 2021-10-05 11:10:14.392347
# we are in 3rd zone
# added 1000 by 72.6025
# HEDGE ended
# (1000, 72602.5)
# 2021-10-05 11:10:24.392347
# we are in 3rd zone
# added 1000 by 72.61
# HEDGE ended
# (1000, 72610.0)
# 2021-10-05 11:10:34.392347
# we are in 3rd zone
# added 1000 by 72.6075
# HEDGE ended
# (1000, 72607.5)
# 2021-10-05 11:10:44.392347
# we are in 3rd zone
# added 1000 by 72.615
# HEDGE ended
# (1000, 72615.0)
# 2021-10-05 11:10:54.392347
# we are in 3rd zone
# added 1000 by 72.615
# HEDGE ended
# (1000, 72615.0)
# 2021-10-05 11:11:04.392347
# we are in 3rd zone
# added 1000 by 72.62
# HEDGE ended
# (1000, 72620.0)
# 2021-10-05 11:11:14.392347
# we are in 3rd zone
# added 1000 by 72.6125
# HEDGE ended
# (1000, 72612.5)
# 2021-10-05 11:11:24.392347
# we are in 3rd zone
# added 1000 by 72.61
# HEDGE ended
# (1000, 72610.0)
# 2021-10-05 11:11:34.392347
# we are in 3rd zone
# added 1000 by 72.6275
# HEDGE ended
# (1000, 72627.5)
# ('2021-10-05 11:10:04.392347', 'S', 10000, 726120.0)
# calculating for moment 2021-10-05 11:19:25.132498
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  None
#  None
# ('2021-10-05 11:19:25.132498', 'B', -2, -2.0)
# calculating for moment 2021-10-05 11:19:25.132498
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  None
#  None
# ('2021-10-05 11:19:25.132498', 'S', -2, -2.0)
# calculating for moment 2021-10-05 11:33:56.758242
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 11:33:53.512172
#  2021-10-05 11:33:56.758242
# 2021-10-05 11:33:56.758242
# we are in 2nd zone
# added 2000 by 72.6
# HEDGE ended
# (2000, 145200.0)
# 2021-10-05 11:34:01.758242
# we are in 3rd zone
# added 1000 by 72.605
# HEDGE ended
# (1000, 72605.0)
# 2021-10-05 11:34:11.758242
# we are in 3rd zone
# added 1000 by 72.61
# HEDGE ended
# (1000, 72610.0)
# 2021-10-05 11:34:21.758242
# we are in 3rd zone
# added 1000 by 72.61
# HEDGE ended
# (1000, 72610.0)
# 2021-10-05 11:34:31.758242
# we are in 3rd zone
# added 1000 by 72.605
# HEDGE ended
# (1000, 72605.0)
# 2021-10-05 11:34:41.758242
# we are in 3rd zone
# added 1000 by 72.6075
# HEDGE ended
# (1000, 72607.5)
# 2021-10-05 11:34:51.758242
# we are in 3rd zone
# added 1000 by 72.6025
# HEDGE ended
# (1000, 72602.5)
# 2021-10-05 11:35:01.758242
# we are in 3rd zone
# added 1000 by 72.6025
# HEDGE ended
# (1000, 72602.5)
# 2021-10-05 11:35:11.758242
# we are in 3rd zone
# added 1000 by 72.6
# HEDGE ended
# (1000, 72600.0)
# ('2021-10-05 11:33:56.758242', 'B', 10000, 726042.5)
# calculating for moment 2021-10-05 11:33:56.758242
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 11:33:42.620732
#  2021-10-05 11:33:42.620732
# 2021-10-05 11:33:56.758242
# we are in 3rd zone
# added 1000 by 72.595
# HEDGE ended
# (1000, 72595.0)
# 2021-10-05 11:34:06.758242
# we are in 3rd zone
# added 1000 by 72.6
# HEDGE ended
# (1000, 72600.0)
# 2021-10-05 11:34:16.758242
# we are in 3rd zone
# added 1000 by 72.6025
# HEDGE ended
# (1000, 72602.5)
# 2021-10-05 11:34:26.758242
# we are in 3rd zone
# added 1000 by 72.605
# HEDGE ended
# (1000, 72605.0)
# 2021-10-05 11:34:36.758242
# we are in 3rd zone
# added 1000 by 72.6025
# HEDGE ended
# (1000, 72602.5)
# 2021-10-05 11:34:46.758242
# we are in 3rd zone
# added 1000 by 72.6025
# HEDGE ended
# (1000, 72602.5)
# 2021-10-05 11:34:56.758242
# we are in 3rd zone
# added 1000 by 72.5925
# HEDGE ended
# (1000, 72592.5)
# 2021-10-05 11:35:06.758242
# we are in 3rd zone
# added 1000 by 72.59
# HEDGE ended
# (1000, 72590.0)
# 2021-10-05 11:35:16.758242
# we are in 3rd zone
# added 1000 by 72.5925
# HEDGE ended
# (1000, 72592.5)
# 2021-10-05 11:35:26.758242
# we are in 3rd zone
# added 1000 by 72.59
# HEDGE ended
# (1000, 72590.0)
# ('2021-10-05 11:33:56.758242', 'S', 10000, 725972.5)
# calculating for moment 2021-10-05 10:11:32.950335
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 10:11:05.253161
#  2021-10-05 10:11:05.253161
# 2021-10-05 10:11:32.950335
# we are in 3rd zone
# added 1000 by 72.55
# HEDGE ended
# (1000, 72550.0)
# 2021-10-05 10:11:42.950335
# we are in 3rd zone
# added 1000 by 72.535
# HEDGE ended
# (1000, 72535.0)
# 2021-10-05 10:11:52.950335
# we are in 3rd zone
# added 1000 by 72.54
# HEDGE ended
# (1000, 72540.0)
# 2021-10-05 10:12:02.950335
# we are in 3rd zone
# added 1000 by 72.545
# HEDGE ended
# (1000, 72545.0)
# 2021-10-05 10:12:12.950335
# we are in 3rd zone
# added 1000 by 72.55
# HEDGE ended
# (1000, 72550.0)
# 2021-10-05 10:12:22.950335
# we are in 3rd zone
# added 1000 by 72.5525
# HEDGE ended
# (1000, 72552.5)
# 2021-10-05 10:12:32.950335
# we are in 3rd zone
# added 1000 by 72.55
# HEDGE ended
# (1000, 72550.0)
# 2021-10-05 10:12:42.950335
# we are in 3rd zone
# added 1000 by 72.5475
# HEDGE ended
# (1000, 72547.5)
# 2021-10-05 10:12:52.950335
# we are in 3rd zone
# added 1000 by 72.55
# HEDGE ended
# (1000, 72550.0)
# 2021-10-05 10:13:02.950335
# we are in 3rd zone
# added 1000 by 72.5525
# HEDGE ended
# (1000, 72552.5)
# ('2021-10-05 10:11:32.950335', 'B', 10000, 725472.5)
# calculating for moment 2021-10-05 10:11:32.950335
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 10:11:17.035670
#  2021-10-05 10:11:17.361279
# 2021-10-05 10:11:32.950335
# we are in 3rd zone
# added 1000 by 72.545
# HEDGE ended
# (1000, 72545.0)
# 2021-10-05 10:11:42.950335
# we are in 3rd zone
# added 1000 by 72.5325
# HEDGE ended
# (1000, 72532.5)
# 2021-10-05 10:11:52.950335
# we are in 3rd zone
# added 1000 by 72.5325
# HEDGE ended
# (1000, 72532.5)
# 2021-10-05 10:12:02.950335
# we are in 3rd zone
# added 1000 by 72.5375
# HEDGE ended
# (1000, 72537.5)
# 2021-10-05 10:12:12.950335
# we are in 3rd zone
# added 1000 by 72.545
# HEDGE ended
# (1000, 72545.0)
# 2021-10-05 10:12:22.950335
# we are in 3rd zone
# added 1000 by 72.5475
# HEDGE ended
# (1000, 72547.5)
# 2021-10-05 10:12:32.950335
# we are in 3rd zone
# added 1000 by 72.5425
# HEDGE ended
# (1000, 72542.5)
# 2021-10-05 10:12:42.950335
# we are in 3rd zone
# added 1000 by 72.5425
# HEDGE ended
# (1000, 72542.5)
# 2021-10-05 10:12:52.950335
# we are in 3rd zone
# added 1000 by 72.5425
# HEDGE ended
# (1000, 72542.5)
# 2021-10-05 10:13:02.950335
# we are in 3rd zone
# added 1000 by 72.545
# HEDGE ended
# (1000, 72545.0)
# ('2021-10-05 10:11:32.950335', 'S', 10000, 725412.5)
# calculating for moment 2021-10-05 10:21:00.949414
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 10:21:00.602858
#  2021-10-05 10:21:00.604347
# 2021-10-05 10:21:00.949414
# we are in 3rd zone
# added 1000 by 72.5075
# HEDGE ended
# (1000, 72507.5)
# 2021-10-05 10:21:10.949414
# we are in 3rd zone
# added 1000 by 72.51
# HEDGE ended
# (1000, 72510.0)
# 2021-10-05 10:21:20.949414
# we are in 3rd zone
# added 1000 by 72.5075
# HEDGE ended
# (1000, 72507.5)
# 2021-10-05 10:21:30.949414
# we are in 3rd zone
# added 1000 by 72.515
# HEDGE ended
# (1000, 72515.0)
# 2021-10-05 10:21:40.949414
# we are in 3rd zone
# added 1000 by 72.5025
# HEDGE ended
# (1000, 72502.5)
# 2021-10-05 10:21:50.949414
# we are in 3rd zone
# added 1000 by 72.5125
# HEDGE ended
# (1000, 72512.5)
# 2021-10-05 10:22:00.949414
# we are in 3rd zone
# added 1000 by 72.5125
# HEDGE ended
# (1000, 72512.5)
# 2021-10-05 10:22:10.949414
# we are in 3rd zone
# added 1000 by 72.515
# HEDGE ended
# (1000, 72515.0)
# 2021-10-05 10:22:20.949414
# we are in 3rd zone
# added 1000 by 72.515
# HEDGE ended
# (1000, 72515.0)
# 2021-10-05 10:22:30.949414
# we are in 3rd zone
# added 1000 by 72.515
# HEDGE ended
# (1000, 72515.0)
# ('2021-10-05 10:21:00.949414', 'B', 10000, 725112.5)
# calculating for moment 2021-10-05 10:21:00.949414
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 10:20:37.974287
#  2021-10-05 10:20:37.974287
# 2021-10-05 10:21:00.949414
# we are in 3rd zone
# added 1000 by 72.495
# HEDGE ended
# (1000, 72495.0)
# 2021-10-05 10:21:10.949414
# we are in 3rd zone
# added 1000 by 72.505
# HEDGE ended
# (1000, 72505.0)
# 2021-10-05 10:21:20.949414
# we are in 3rd zone
# added 1000 by 72.505
# HEDGE ended
# (1000, 72505.0)
# 2021-10-05 10:21:30.949414
# we are in 3rd zone
# added 1000 by 72.51
# HEDGE ended
# (1000, 72510.0)
# 2021-10-05 10:21:40.949414
# we are in 3rd zone
# added 1000 by 72.495
# HEDGE ended
# (1000, 72495.0)
# 2021-10-05 10:21:50.949414
# we are in 3rd zone
# added 1000 by 72.505
# HEDGE ended
# (1000, 72505.0)
# 2021-10-05 10:22:00.949414
# we are in 3rd zone
# added 1000 by 72.5075
# HEDGE ended
# (1000, 72507.5)
# 2021-10-05 10:22:10.949414
# we are in 3rd zone
# added 1000 by 72.5075
# HEDGE ended
# (1000, 72507.5)
# 2021-10-05 10:22:20.949414
# we are in 3rd zone
# added 1000 by 72.5075
# HEDGE ended
# (1000, 72507.5)
# 2021-10-05 10:22:30.949414
# we are in 3rd zone
# added 1000 by 72.5125
# HEDGE ended
# (1000, 72512.5)
# ('2021-10-05 10:21:00.949414', 'S', 10000, 725050.0)
# calculating for moment 2021-10-05 10:32:28.273113
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 10:32:14.498147
#  2021-10-05 10:32:14.970696
# 2021-10-05 10:32:28.273113
# we are in 3rd zone
# added 1000 by 72.5675
# HEDGE ended
# (1000, 72567.5)
# 2021-10-05 10:32:38.273113
# we are in 3rd zone
# added 1000 by 72.57
# HEDGE ended
# (1000, 72570.0)
# 2021-10-05 10:32:48.273113
# we are in 3rd zone
# added 1000 by 72.57
# HEDGE ended
# (1000, 72570.0)
# 2021-10-05 10:32:58.273113
# we are in 3rd zone
# added 1000 by 72.5725
# HEDGE ended
# (1000, 72572.5)
# 2021-10-05 10:33:08.273113
# we are in 3rd zone
# added 1000 by 72.5725
# HEDGE ended
# (1000, 72572.5)
# 2021-10-05 10:33:18.273113
# we are in 3rd zone
# added 1000 by 72.57
# HEDGE ended
# (1000, 72570.0)
# 2021-10-05 10:33:28.273113
# we are in 3rd zone
# added 1000 by 72.57
# HEDGE ended
# (1000, 72570.0)
# 2021-10-05 10:33:38.273113
# we are in 3rd zone
# added 1000 by 72.575
# HEDGE ended
# (1000, 72575.0)
# 2021-10-05 10:33:48.273113
# we are in 3rd zone
# added 1000 by 72.575
# HEDGE ended
# (1000, 72575.0)
# 2021-10-05 10:33:58.273113
# we are in 3rd zone
# added 1000 by 72.5675
# HEDGE ended
# (1000, 72567.5)
# ('2021-10-05 10:32:28.273113', 'B', 10000, 725710.0)
# calculating for moment 2021-10-05 10:32:28.273113
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 10:31:58.363347
#  2021-10-05 10:31:58.363347
# 2021-10-05 10:32:28.273113
# we are in 3rd zone
# added 1000 by 72.56
# HEDGE ended
# (1000, 72560.0)
# 2021-10-05 10:32:38.273113
# we are in 3rd zone
# added 1000 by 72.5625
# HEDGE ended
# (1000, 72562.5)
# 2021-10-05 10:32:48.273113
# we are in 3rd zone
# added 1000 by 72.5625
# HEDGE ended
# (1000, 72562.5)
# 2021-10-05 10:32:58.273113
# we are in 3rd zone
# added 1000 by 72.565
# HEDGE ended
# (1000, 72565.0)
# 2021-10-05 10:33:08.273113
# we are in 3rd zone
# added 1000 by 72.5675
# HEDGE ended
# (1000, 72567.5)
# 2021-10-05 10:33:18.273113
# we are in 3rd zone
# added 1000 by 72.5675
# HEDGE ended
# (1000, 72567.5)
# 2021-10-05 10:33:28.273113
# we are in 3rd zone
# added 1000 by 72.5625
# HEDGE ended
# (1000, 72562.5)
# 2021-10-05 10:33:38.273113
# we are in 3rd zone
# added 1000 by 72.5675
# HEDGE ended
# (1000, 72567.5)
# 2021-10-05 10:33:48.273113
# we are in 3rd zone
# added 1000 by 72.57
# HEDGE ended
# (1000, 72570.0)
# 2021-10-05 10:33:58.273113
# we are in 3rd zone
# added 1000 by 72.565
# HEDGE ended
# (1000, 72565.0)
# ('2021-10-05 10:32:28.273113', 'S', 10000, 725650.0)
# calculating for moment 2021-10-05 12:11:16.811240
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 12:10:52.800864
#  2021-10-05 12:10:52.801552
# 2021-10-05 12:11:16.811240
# we are in 3rd zone
# added 1000 by 72.6725
# HEDGE ended
# (1000, 72672.5)
# 2021-10-05 12:11:26.811240
# we are in 3rd zone
# added 1000 by 72.665
# HEDGE ended
# (1000, 72665.0)
# 2021-10-05 12:11:36.811240
# we are in 3rd zone
# added 1000 by 72.665
# HEDGE ended
# (1000, 72665.0)
# 2021-10-05 12:11:46.811240
# we are in 3rd zone
# added 1000 by 72.66
# HEDGE ended
# (1000, 72660.0)
# 2021-10-05 12:11:56.811240
# we are in 3rd zone
# added 1000 by 72.665
# HEDGE ended
# (1000, 72665.0)
# 2021-10-05 12:12:06.811240
# we are in 3rd zone
# added 1000 by 72.665
# HEDGE ended
# (1000, 72665.0)
# 2021-10-05 12:12:16.811240
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 12:12:26.811240
# we are in 3rd zone
# added 1000 by 72.6625
# HEDGE ended
# (1000, 72662.5)
# 2021-10-05 12:12:36.811240
# we are in 3rd zone
# added 1000 by 72.6625
# HEDGE ended
# (1000, 72662.5)
# 2021-10-05 12:12:46.811240
# we are in 3rd zone
# added 1000 by 72.6625
# HEDGE ended
# (1000, 72662.5)
# ('2021-10-05 12:11:16.811240', 'B', 10000, 726637.5)
# calculating for moment 2021-10-05 12:11:16.811240
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 12:10:52.800864
#  2021-10-05 12:11:13.044543
# 2021-10-05 12:11:16.811240
# we are in 3rd zone
# added 1000 by 72.665
# HEDGE ended
# (1000, 72665.0)
# 2021-10-05 12:11:26.811240
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 12:11:36.811240
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 12:11:46.811240
# we are in 3rd zone
# added 1000 by 72.655
# HEDGE ended
# (1000, 72655.0)
# 2021-10-05 12:11:56.811240
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 12:12:06.811240
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 12:12:16.811240
# we are in 3rd zone
# added 1000 by 72.6525
# HEDGE ended
# (1000, 72652.5)
# 2021-10-05 12:12:26.811240
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 12:12:36.811240
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# 2021-10-05 12:12:46.811240
# we are in 3rd zone
# added 1000 by 72.6575
# HEDGE ended
# (1000, 72657.5)
# ('2021-10-05 12:11:16.811240', 'S', 10000, 726575.0)
# calculating for moment 2021-10-05 12:23:18.441034
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 12:22:55.631935
#  2021-10-05 12:22:55.631935
# 2021-10-05 12:23:18.441034
# we are in 3rd zone
# added 1000 by 72.64
# HEDGE ended
# (1000, 72640.0)
# 2021-10-05 12:23:28.441034
# we are in 3rd zone
# added 1000 by 72.64
# HEDGE ended
# (1000, 72640.0)
# 2021-10-05 12:23:38.441034
# we are in 3rd zone
# added 1000 by 72.63
# HEDGE ended
# (1000, 72630.0)
# 2021-10-05 12:23:48.441034
# we are in 3rd zone
# added 1000 by 72.64
# HEDGE ended
# (1000, 72640.0)
# 2021-10-05 12:23:58.441034
# we are in 3rd zone
# added 1000 by 72.64
# HEDGE ended
# (1000, 72640.0)
# 2021-10-05 12:24:08.441034
# we are in 3rd zone
# added 1000 by 72.64
# HEDGE ended
# (1000, 72640.0)
# 2021-10-05 12:24:18.441034
# we are in 3rd zone
# added 1000 by 72.64
# HEDGE ended
# (1000, 72640.0)
# 2021-10-05 12:24:28.441034
# we are in 3rd zone
# added 1000 by 72.64
# HEDGE ended
# (1000, 72640.0)
# 2021-10-05 12:24:38.441034
# we are in 3rd zone
# added 1000 by 72.6425
# HEDGE ended
# (1000, 72642.5)
# 2021-10-05 12:24:48.441034
# we are in 3rd zone
# added 1000 by 72.6425
# HEDGE ended
# (1000, 72642.5)
# ('2021-10-05 12:23:18.441034', 'B', 10000, 726395.0)
# calculating for moment 2021-10-05 12:23:18.441034
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 12:22:55.704024
#  2021-10-05 12:23:18.440433
# 2021-10-05 12:23:18.441034
# we are in 3rd zone
# added 1000 by 72.6375
# HEDGE ended
# (1000, 72637.5)
# 2021-10-05 12:23:28.441034
# we are in 3rd zone
# added 1000 by 72.6375
# HEDGE ended
# (1000, 72637.5)
# 2021-10-05 12:23:38.441034
# we are in 3rd zone
# added 1000 by 72.625
# HEDGE ended
# (1000, 72625.0)
# 2021-10-05 12:23:48.441034
# we are in 3rd zone
# added 1000 by 72.635
# HEDGE ended
# (1000, 72635.0)
# 2021-10-05 12:23:58.441034
# we are in 3rd zone
# added 1000 by 72.635
# HEDGE ended
# (1000, 72635.0)
# 2021-10-05 12:24:08.441034
# we are in 3rd zone
# added 1000 by 72.635
# HEDGE ended
# (1000, 72635.0)
# 2021-10-05 12:24:18.441034
# we are in 3rd zone
# added 1000 by 72.635
# HEDGE ended
# (1000, 72635.0)
# 2021-10-05 12:24:28.441034
# we are in 3rd zone
# added 1000 by 72.635
# HEDGE ended
# (1000, 72635.0)
# 2021-10-05 12:24:38.441034
# we are in 3rd zone
# added 1000 by 72.64
# HEDGE ended
# (1000, 72640.0)
# 2021-10-05 12:24:48.441034
# we are in 3rd zone
# added 1000 by 72.64
# HEDGE ended
# (1000, 72640.0)
# ('2021-10-05 12:23:18.441034', 'S', 10000, 726355.0)
# calculating for moment 2021-10-05 12:34:06.655953
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 12:34:10.655953
#  2021-10-05 12:34:18.655953
# 2021-10-05 12:34:06.655953
# we are in 1st zone
# added 3000 by 72.6575
# HEDGE ended
# (3000, 217972.5)
# 2021-10-05 12:34:07.655953
# we are in 1st zone
# added 3000 by 72.6525
# HEDGE ended
# (3000, 217957.5)
# 2021-10-05 12:34:08.655953
# we are in 1st zone
# added 3000 by 72.6525
# HEDGE ended
# (3000, 217957.5)
# 2021-10-05 12:34:09.655953
# we are in 1st zone
# added 1000 by 72.655
# HEDGE ended
# (1000, 72655.0)
# ('2021-10-05 12:34:06.655953', 'B', 10000, 726542.5)
# calculating for moment 2021-10-05 12:34:06.655953
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 12:34:06.655953
#  2021-10-05 12:34:06.655953
# 2021-10-05 12:34:06.655953
# we are in 1st zone
# added 3000 by 72.6425
# HEDGE ended
# (3000, 217927.5)
# 2021-10-05 12:34:07.655953
# we are in 3rd zone
# added 1000 by 72.6475
# HEDGE ended
# (1000, 72647.5)
# 2021-10-05 12:34:17.655953
# we are in 3rd zone
# added 1000 by 72.6475
# HEDGE ended
# (1000, 72647.5)
# 2021-10-05 12:34:27.655953
# we are in 3rd zone
# added 1000 by 72.6475
# HEDGE ended
# (1000, 72647.5)
# 2021-10-05 12:34:37.655953
# we are in 3rd zone
# added 1000 by 72.6475
# HEDGE ended
# (1000, 72647.5)
# 2021-10-05 12:34:47.655953
# we are in 3rd zone
# added 1000 by 72.645
# HEDGE ended
# (1000, 72645.0)
# 2021-10-05 12:34:57.655953
# we are in 3rd zone
# added 1000 by 72.6425
# HEDGE ended
# (1000, 72642.5)
# 2021-10-05 12:35:07.655953
# we are in 3rd zone
# added 1000 by 72.645
# HEDGE ended
# (1000, 72645.0)
# ('2021-10-05 12:34:06.655953', 'S', 10000, 726450.0)
# calculating for moment 2021-10-05 15:11:41.056651
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 15:11:37.597481
#  2021-10-05 15:11:41.056651
# 2021-10-05 15:11:41.056651
# we are in 2nd zone
# added 2000 by 72.5175
# HEDGE ended
# (2000, 145035.0)
# 2021-10-05 15:11:46.056651
# we are in 3rd zone
# added 1000 by 72.51
# HEDGE ended
# (1000, 72510.0)
# 2021-10-05 15:11:56.056651
# we are in 3rd zone
# added 1000 by 72.51
# HEDGE ended
# (1000, 72510.0)
# 2021-10-05 15:12:06.056651
# we are in 3rd zone
# added 1000 by 72.515
# HEDGE ended
# (1000, 72515.0)
# 2021-10-05 15:12:16.056651
# we are in 3rd zone
# added 1000 by 72.515
# HEDGE ended
# (1000, 72515.0)
# 2021-10-05 15:12:26.056651
# we are in 3rd zone
# added 1000 by 72.5175
# HEDGE ended
# (1000, 72517.5)
# 2021-10-05 15:12:36.056651
# we are in 3rd zone
# added 1000 by 72.5175
# HEDGE ended
# (1000, 72517.5)
# 2021-10-05 15:12:46.056651
# we are in 3rd zone
# added 1000 by 72.52
# HEDGE ended
# (1000, 72520.0)
# 2021-10-05 15:12:56.056651
# we are in 3rd zone
# added 1000 by 72.5225
# HEDGE ended
# (1000, 72522.5)
# ('2021-10-05 15:11:41.056651', 'B', 10000, 725162.5)
# calculating for moment 2021-10-05 15:11:41.056651
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-05 15:11:12.428090
#  2021-10-05 15:11:12.428090
# 2021-10-05 15:11:41.056651
# we are in 3rd zone
# added 1000 by 72.5075
# HEDGE ended
# (1000, 72507.5)
# 2021-10-05 15:11:51.056651
# we are in 3rd zone
# added 1000 by 72.5025
# HEDGE ended
# (1000, 72502.5)
# 2021-10-05 15:12:01.056651
# we are in 3rd zone
# added 1000 by 72.5075
# HEDGE ended
# (1000, 72507.5)
# 2021-10-05 15:12:11.056651
# we are in 3rd zone
# added 1000 by 72.51
# HEDGE ended
# (1000, 72510.0)
# 2021-10-05 15:12:21.056651
# we are in 3rd zone
# added 1000 by 72.5075
# HEDGE ended
# (1000, 72507.5)
# 2021-10-05 15:12:31.056651
# we are in 3rd zone
# added 1000 by 72.515
# HEDGE ended
# (1000, 72515.0)
# 2021-10-05 15:12:41.056651
# we are in 3rd zone
# added 1000 by 72.5125
# HEDGE ended
# (1000, 72512.5)
# 2021-10-05 15:12:51.056651
# ...
# we are in 3rd zone
# added 1000 by 72.58
# HEDGE ended
# (1000, 72580.0)
# 2021-10-06 12:32:24.951635
# we are in 3rd zone
# added 1000 by 72.5775
# HEDGE ended
# (1000, 72577.5)
# 2021-10-06 12:32:34.951635
# we are in 3rd zone
# added 1000 by 72.5775
# HEDGE ended
# (1000, 72577.5)
# 2021-10-06 12:32:44.951635
# we are in 3rd zone
# added 1000 by 72.575
# HEDGE ended
# (1000, 72575.0)
# 2021-10-06 12:32:54.951635
# we are in 3rd zone
# added 1000 by 72.5625
# HEDGE ended
# (1000, 72562.5)
# 2021-10-06 12:33:04.951635
# we are in 3rd zone
# added 1000 by 72.565
# HEDGE ended
# (1000, 72565.0)
# 2021-10-06 12:33:14.951635
# we are in 3rd zone
# added 1000 by 72.57
# HEDGE ended
# (1000, 72570.0)
# 2021-10-06 12:33:24.951635
# we are in 3rd zone
# added 1000 by 72.5875
# HEDGE ended
# (1000, 72587.5)
# ('2021-10-06 12:31:54.951635', 'S', 10000, 725755.0)
# calculating for moment 2021-10-06 16:11:45.281590
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 16:11:45.281590
#  2021-10-06 16:11:45.281590
# 2021-10-06 16:11:45.281590
# we are in 1st zone
# added 3000 by 72.4075
# HEDGE ended
# (3000, 217222.5)
# 2021-10-06 16:11:46.281590
# we are in 3rd zone
# added 1000 by 72.4075
# HEDGE ended
# (1000, 72407.5)
# 2021-10-06 16:11:56.281590
# we are in 3rd zone
# added 1000 by 72.4075
# HEDGE ended
# (1000, 72407.5)
# 2021-10-06 16:12:06.281590
# we are in 3rd zone
# added 1000 by 72.405
# HEDGE ended
# (1000, 72405.0)
# 2021-10-06 16:12:16.281590
# we are in 3rd zone
# added 1000 by 72.4125
# HEDGE ended
# (1000, 72412.5)
# 2021-10-06 16:12:26.281590
# we are in 3rd zone
# added 1000 by 72.41
# HEDGE ended
# (1000, 72410.0)
# 2021-10-06 16:12:36.281590
# we are in 3rd zone
# added 1000 by 72.405
# HEDGE ended
# (1000, 72405.0)
# 2021-10-06 16:12:46.281590
# we are in 3rd zone
# added 1000 by 72.4075
# HEDGE ended
# (1000, 72407.5)
# ('2021-10-06 16:11:45.281590', 'B', 10000, 724077.5)
# calculating for moment 2021-10-06 16:11:45.281590
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 16:11:42.996751
#  2021-10-06 16:11:42.996751
# 2021-10-06 16:11:45.281590
# we are in 3rd zone
# added 1000 by 72.395
# HEDGE ended
# (1000, 72395.0)
# 2021-10-06 16:11:55.281590
# we are in 3rd zone
# added 1000 by 72.4025
# HEDGE ended
# (1000, 72402.5)
# 2021-10-06 16:12:05.281590
# we are in 3rd zone
# added 1000 by 72.3975
# HEDGE ended
# (1000, 72397.5)
# 2021-10-06 16:12:15.281590
# we are in 3rd zone
# added 1000 by 72.4
# HEDGE ended
# (1000, 72400.0)
# 2021-10-06 16:12:25.281590
# we are in 3rd zone
# added 1000 by 72.4025
# HEDGE ended
# (1000, 72402.5)
# 2021-10-06 16:12:35.281590
# we are in 3rd zone
# added 1000 by 72.4
# HEDGE ended
# (1000, 72400.0)
# 2021-10-06 16:12:45.281590
# we are in 3rd zone
# added 1000 by 72.4
# HEDGE ended
# (1000, 72400.0)
# 2021-10-06 16:12:55.281590
# we are in 3rd zone
# added 1000 by 72.405
# HEDGE ended
# (1000, 72405.0)
# 2021-10-06 16:13:05.281590
# we are in 3rd zone
# added 1000 by 72.405
# HEDGE ended
# (1000, 72405.0)
# 2021-10-06 16:13:15.281590
# we are in 3rd zone
# added 1000 by 72.405
# HEDGE ended
# (1000, 72405.0)
# ('2021-10-06 16:11:45.281590', 'S', 10000, 724012.5)
# calculating for moment 2021-10-06 16:22:34.587892
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 16:22:24.758185
#  2021-10-06 16:22:30.436805
# 2021-10-06 16:22:34.587892
# we are in 3rd zone
# added 1000 by 72.4075
# HEDGE ended
# (1000, 72407.5)
# 2021-10-06 16:22:44.587892
# we are in 3rd zone
# added 1000 by 72.4075
# HEDGE ended
# (1000, 72407.5)
# 2021-10-06 16:22:54.587892
# we are in 3rd zone
# added 1000 by 72.4075
# HEDGE ended
# (1000, 72407.5)
# 2021-10-06 16:23:04.587892
# we are in 3rd zone
# added 1000 by 72.41
# HEDGE ended
# (1000, 72410.0)
# 2021-10-06 16:23:14.587892
# we are in 3rd zone
# added 1000 by 72.4125
# HEDGE ended
# (1000, 72412.5)
# 2021-10-06 16:23:24.587892
# we are in 3rd zone
# added 1000 by 72.42
# HEDGE ended
# (1000, 72420.0)
# 2021-10-06 16:23:34.587892
# we are in 3rd zone
# added 1000 by 72.425
# HEDGE ended
# (1000, 72425.0)
# 2021-10-06 16:23:44.587892
# we are in 3rd zone
# added 1000 by 72.4275
# HEDGE ended
# (1000, 72427.5)
# 2021-10-06 16:23:54.587892
# we are in 3rd zone
# added 1000 by 72.425
# HEDGE ended
# (1000, 72425.0)
# 2021-10-06 16:24:04.587892
# we are in 3rd zone
# added 1000 by 72.43
# HEDGE ended
# (1000, 72430.0)
# ('2021-10-06 16:22:34.587892', 'B', 10000, 724172.5)
# calculating for moment 2021-10-06 16:22:34.587892
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 16:22:13.512881
#  2021-10-06 16:22:13.512881
# 2021-10-06 16:22:34.587892
# we are in 3rd zone
# added 1000 by 72.3975
# HEDGE ended
# (1000, 72397.5)
# 2021-10-06 16:22:44.587892
# we are in 3rd zone
# added 1000 by 72.4
# HEDGE ended
# (1000, 72400.0)
# 2021-10-06 16:22:54.587892
# we are in 3rd zone
# added 1000 by 72.4
# HEDGE ended
# (1000, 72400.0)
# 2021-10-06 16:23:04.587892
# we are in 3rd zone
# added 1000 by 72.405
# HEDGE ended
# (1000, 72405.0)
# 2021-10-06 16:23:14.587892
# we are in 3rd zone
# added 1000 by 72.41
# HEDGE ended
# (1000, 72410.0)
# 2021-10-06 16:23:24.587892
# we are in 3rd zone
# added 1000 by 72.415
# HEDGE ended
# (1000, 72415.0)
# 2021-10-06 16:23:34.587892
# we are in 3rd zone
# added 1000 by 72.42
# HEDGE ended
# (1000, 72420.0)
# 2021-10-06 16:23:44.587892
# we are in 3rd zone
# added 1000 by 72.42
# HEDGE ended
# (1000, 72420.0)
# 2021-10-06 16:23:54.587892
# we are in 3rd zone
# added 1000 by 72.4175
# HEDGE ended
# (1000, 72417.5)
# 2021-10-06 16:24:04.587892
# we are in 3rd zone
# added 1000 by 72.4225
# HEDGE ended
# (1000, 72422.5)
# ('2021-10-06 16:22:34.587892', 'S', 10000, 724107.5)
# calculating for moment 2021-10-06 16:32:02.367660
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 16:31:32.837794
#  2021-10-06 16:31:32.837794
# 2021-10-06 16:32:02.367660
# we are in 3rd zone
# added 1000 by 72.43
# HEDGE ended
# (1000, 72430.0)
# 2021-10-06 16:32:12.367660
# we are in 3rd zone
# added 1000 by 72.4075
# HEDGE ended
# (1000, 72407.5)
# 2021-10-06 16:32:22.367660
# we are in 3rd zone
# added 1000 by 72.4075
# HEDGE ended
# (1000, 72407.5)
# 2021-10-06 16:32:32.367660
# we are in 3rd zone
# added 1000 by 72.4
# HEDGE ended
# (1000, 72400.0)
# 2021-10-06 16:32:42.367660
# we are in 3rd zone
# added 1000 by 72.385
# HEDGE ended
# (1000, 72385.0)
# 2021-10-06 16:32:52.367660
# we are in 3rd zone
# added 1000 by 72.385
# HEDGE ended
# (1000, 72385.0)
# 2021-10-06 16:33:02.367660
# we are in 3rd zone
# added 1000 by 72.3825
# HEDGE ended
# (1000, 72382.5)
# 2021-10-06 16:33:12.367660
# we are in 3rd zone
# added 1000 by 72.3775
# HEDGE ended
# (1000, 72377.5)
# 2021-10-06 16:33:22.367660
# we are in 3rd zone
# added 1000 by 72.37
# HEDGE ended
# (1000, 72370.0)
# 2021-10-06 16:33:32.367660
# we are in 3rd zone
# added 1000 by 72.3725
# HEDGE ended
# (1000, 72372.5)
# ('2021-10-06 16:32:02.367660', 'B', 10000, 723917.5)
# calculating for moment 2021-10-06 16:32:02.367660
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 16:32:00.071807
#  2021-10-06 16:32:00.072245
# 2021-10-06 16:32:02.367660
# we are in 3rd zone
# added 1000 by 72.4175
# HEDGE ended
# (1000, 72417.5)
# 2021-10-06 16:32:12.367660
# we are in 3rd zone
# added 1000 by 72.4
# HEDGE ended
# (1000, 72400.0)
# 2021-10-06 16:32:22.367660
# we are in 3rd zone
# added 1000 by 72.4025
# HEDGE ended
# (1000, 72402.5)
# 2021-10-06 16:32:32.367660
# we are in 3rd zone
# added 1000 by 72.3975
# HEDGE ended
# (1000, 72397.5)
# 2021-10-06 16:32:42.367660
# we are in 3rd zone
# added 1000 by 72.38
# HEDGE ended
# (1000, 72380.0)
# 2021-10-06 16:32:52.367660
# we are in 3rd zone
# added 1000 by 72.3775
# HEDGE ended
# (1000, 72377.5)
# 2021-10-06 16:33:02.367660
# we are in 3rd zone
# added 1000 by 72.3775
# HEDGE ended
# (1000, 72377.5)
# 2021-10-06 16:33:12.367660
# we are in 3rd zone
# added 1000 by 72.375
# HEDGE ended
# (1000, 72375.0)
# 2021-10-06 16:33:22.367660
# we are in 3rd zone
# added 1000 by 72.365
# HEDGE ended
# (1000, 72365.0)
# 2021-10-06 16:33:32.367660
# we are in 3rd zone
# added 1000 by 72.365
# HEDGE ended
# (1000, 72365.0)
# ('2021-10-06 16:32:02.367660', 'S', 10000, 723857.5)
# calculating for moment 2021-10-06 15:11:23.178082
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 15:10:55.086456
#  2021-10-06 15:10:55.086456
# 2021-10-06 15:11:23.178082
# we are in 3rd zone
# added 1000 by 72.49
# HEDGE ended
# (1000, 72490.0)
# 2021-10-06 15:11:33.178082
# we are in 3rd zone
# added 1000 by 72.4825
# HEDGE ended
# (1000, 72482.5)
# 2021-10-06 15:11:43.178082
# we are in 3rd zone
# added 1000 by 72.48
# HEDGE ended
# (1000, 72480.0)
# 2021-10-06 15:11:53.178082
# we are in 3rd zone
# added 1000 by 72.4825
# HEDGE ended
# (1000, 72482.5)
# 2021-10-06 15:12:03.178082
# we are in 3rd zone
# added 1000 by 72.4775
# HEDGE ended
# (1000, 72477.5)
# 2021-10-06 15:12:13.178082
# we are in 3rd zone
# added 1000 by 72.4775
# HEDGE ended
# (1000, 72477.5)
# 2021-10-06 15:12:23.178082
# we are in 3rd zone
# added 1000 by 72.4775
# HEDGE ended
# (1000, 72477.5)
# 2021-10-06 15:12:33.178082
# we are in 3rd zone
# added 1000 by 72.4775
# HEDGE ended
# (1000, 72477.5)
# 2021-10-06 15:12:43.178082
# we are in 3rd zone
# added 1000 by 72.485
# HEDGE ended
# (1000, 72485.0)
# 2021-10-06 15:12:53.178082
# we are in 3rd zone
# added 1000 by 72.49
# HEDGE ended
# (1000, 72490.0)
# ('2021-10-06 15:11:23.178082', 'B', 10000, 724820.0)
# calculating for moment 2021-10-06 15:11:23.178082
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 15:11:02.086456
#  2021-10-06 15:11:11.791775
# 2021-10-06 15:11:23.178082
# we are in 3rd zone
# added 1000 by 72.4775
# HEDGE ended
# (1000, 72477.5)
# 2021-10-06 15:11:33.178082
# we are in 3rd zone
# added 1000 by 72.475
# HEDGE ended
# (1000, 72475.0)
# 2021-10-06 15:11:43.178082
# we are in 3rd zone
# added 1000 by 72.4725
# HEDGE ended
# (1000, 72472.5)
# 2021-10-06 15:11:53.178082
# we are in 3rd zone
# added 1000 by 72.475
# HEDGE ended
# (1000, 72475.0)
# 2021-10-06 15:12:03.178082
# we are in 3rd zone
# added 1000 by 72.4675
# HEDGE ended
# (1000, 72467.5)
# 2021-10-06 15:12:13.178082
# we are in 3rd zone
# added 1000 by 72.47
# HEDGE ended
# (1000, 72470.0)
# 2021-10-06 15:12:23.178082
# we are in 3rd zone
# added 1000 by 72.47
# HEDGE ended
# (1000, 72470.0)
# 2021-10-06 15:12:33.178082
# we are in 3rd zone
# added 1000 by 72.47
# HEDGE ended
# (1000, 72470.0)
# 2021-10-06 15:12:43.178082
# we are in 3rd zone
# added 1000 by 72.48
# HEDGE ended
# (1000, 72480.0)
# 2021-10-06 15:12:53.178082
# we are in 3rd zone
# added 1000 by 72.4825
# HEDGE ended
# (1000, 72482.5)
# ('2021-10-06 15:11:23.178082', 'S', 10000, 724740.0)
# calculating for moment 2021-10-06 15:22:44.063087
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 15:22:14.273151
#  2021-10-06 15:22:14.273151
# 2021-10-06 15:22:44.063087
# we are in 3rd zone
# added 1000 by 72.4975
# HEDGE ended
# (1000, 72497.5)
# 2021-10-06 15:22:54.063087
# we are in 3rd zone
# added 1000 by 72.4775
# HEDGE ended
# (1000, 72477.5)
# 2021-10-06 15:23:04.063087
# we are in 3rd zone
# added 1000 by 72.475
# HEDGE ended
# (1000, 72475.0)
# 2021-10-06 15:23:14.063087
# we are in 3rd zone
# added 1000 by 72.4775
# HEDGE ended
# (1000, 72477.5)
# 2021-10-06 15:23:24.063087
# we are in 3rd zone
# added 1000 by 72.4775
# HEDGE ended
# (1000, 72477.5)
# 2021-10-06 15:23:34.063087
# we are in 3rd zone
# added 1000 by 72.4625
# HEDGE ended
# (1000, 72462.5)
# 2021-10-06 15:23:44.063087
# we are in 3rd zone
# added 1000 by 72.4675
# HEDGE ended
# (1000, 72467.5)
# 2021-10-06 15:23:54.063087
# we are in 3rd zone
# added 1000 by 72.47
# HEDGE ended
# (1000, 72470.0)
# 2021-10-06 15:24:04.063087
# we are in 3rd zone
# added 1000 by 72.4825
# HEDGE ended
# (1000, 72482.5)
# 2021-10-06 15:24:14.063087
# we are in 3rd zone
# added 1000 by 72.465
# HEDGE ended
# (1000, 72465.0)
# ('2021-10-06 15:22:44.063087', 'B', 10000, 724752.5)
# calculating for moment 2021-10-06 15:22:44.063087
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 15:22:28.673527
#  2021-10-06 15:22:44.062181
# 2021-10-06 15:22:44.063087
# we are in 3rd zone
# added 1000 by 72.495
# HEDGE ended
# (1000, 72495.0)
# 2021-10-06 15:22:54.063087
# we are in 3rd zone
# added 1000 by 72.4725
# HEDGE ended
# (1000, 72472.5)
# 2021-10-06 15:23:04.063087
# we are in 3rd zone
# added 1000 by 72.4675
# HEDGE ended
# (1000, 72467.5)
# 2021-10-06 15:23:14.063087
# we are in 3rd zone
# added 1000 by 72.4725
# HEDGE ended
# (1000, 72472.5)
# 2021-10-06 15:23:24.063087
# we are in 3rd zone
# added 1000 by 72.4725
# HEDGE ended
# (1000, 72472.5)
# 2021-10-06 15:23:34.063087
# we are in 3rd zone
# added 1000 by 72.4575
# HEDGE ended
# (1000, 72457.5)
# 2021-10-06 15:23:44.063087
# we are in 3rd zone
# added 1000 by 72.4625
# HEDGE ended
# (1000, 72462.5)
# 2021-10-06 15:23:54.063087
# we are in 3rd zone
# added 1000 by 72.465
# HEDGE ended
# (1000, 72465.0)
# 2021-10-06 15:24:04.063087
# we are in 3rd zone
# added 1000 by 72.475
# HEDGE ended
# (1000, 72475.0)
# 2021-10-06 15:24:14.063087
# we are in 3rd zone
# added 1000 by 72.4625
# HEDGE ended
# (1000, 72462.5)
# ('2021-10-06 15:22:44.063087', 'S', 10000, 724702.5)
# calculating for moment 2021-10-06 15:34:35.640399
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 15:34:10.978301
#  2021-10-06 15:34:10.978301
# 2021-10-06 15:34:35.640399
# we are in 3rd zone
# added 1000 by 72.3975
# HEDGE ended
# (1000, 72397.5)
# 2021-10-06 15:34:45.640399
# we are in 3rd zone
# added 1000 by 72.3825
# HEDGE ended
# (1000, 72382.5)
# 2021-10-06 15:34:55.640399
# we are in 3rd zone
# added 1000 by 72.3825
# HEDGE ended
# (1000, 72382.5)
# 2021-10-06 15:35:05.640399
# we are in 3rd zone
# added 1000 by 72.3725
# HEDGE ended
# (1000, 72372.5)
# 2021-10-06 15:35:15.640399
# we are in 3rd zone
# added 1000 by 72.3825
# HEDGE ended
# (1000, 72382.5)
# 2021-10-06 15:35:25.640399
# we are in 3rd zone
# added 1000 by 72.39
# HEDGE ended
# (1000, 72390.0)
# 2021-10-06 15:35:35.640399
# we are in 3rd zone
# added 1000 by 72.395
# HEDGE ended
# (1000, 72395.0)
# 2021-10-06 15:35:45.640399
# we are in 3rd zone
# added 1000 by 72.395
# HEDGE ended
# (1000, 72395.0)
# 2021-10-06 15:35:55.640399
# we are in 3rd zone
# added 1000 by 72.3975
# HEDGE ended
# (1000, 72397.5)
# 2021-10-06 15:36:05.640399
# we are in 3rd zone
# added 1000 by 72.4
# HEDGE ended
# (1000, 72400.0)
# ('2021-10-06 15:34:35.640399', 'B', 10000, 723895.0)
# calculating for moment 2021-10-06 15:34:35.640399
#    zone_number  distance  proportion
# 0            1         1         0.3
# 1            2         5         0.2
# 2            3        10         0.1
# zone1time, zone2time
#  2021-10-06 15:34:25.805567
#  2021-10-06 15:34:35.592023
# 2021-10-06 15:34:35.640399
# we are in 3rd zone
# added 1000 by 72.3875
# HEDGE ended
# (1000, 72387.5)
# 2021-10-06 15:34:45.640399
# we are in 3rd zone
# added 1000 by 72.3775
# HEDGE ended
# (1000, 72377.5)
# 2021-10-06 15:34:55.640399
# we are in 3rd zone
# added 1000 by 72.3775
# HEDGE ended
# (1000, 72377.5)
# 2021-10-06 15:35:05.640399
# we are in 3rd zone
# added 1000 by 72.37
# HEDGE ended
# (1000, 72370.0)
# 2021-10-06 15:35:15.640399
# we are in 3rd zone
# added 1000 by 72.3775
# HEDGE ended
# (1000, 72377.5)
# 2021-10-06 15:35:25.640399
# we are in 3rd zone
# added 1000 by 72.3825
# HEDGE ended
# (1000, 72382.5)
# 2021-10-06 15:35:35.640399
# we are in 3rd zone
# added 1000 by 72.3875
# HEDGE ended
# (1000, 72387.5)
# 2021-10-06 15:35:45.640399
# we are in 3rd zone
# added 1000 by 72.3875
# HEDGE ended
# (1000, 72387.5)
# 2021-10-06 15:35:55.640399
# we are in 3rd zone
# added 1000 by 72.39
# HEDGE ended
# (1000, 72390.0)
# 2021-10-06 15:36:05.640399
# we are in 3rd zone
# added 1000 by 72.3925
# HEDGE ended
# (1000, 72392.5)
# ('2021-10-06 15:34:35.640399', 'S', 10000, 723830.0)

# %%
sign_sql.commit()

# %%
cur.close()
sign_sql.close()
